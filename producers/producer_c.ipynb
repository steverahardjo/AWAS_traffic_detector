# %%
from util import kafkaProducer

# %%
csv_path="data/camera_event_c.csv"
#ip address is the zookeeper & port to the kafka port
kafka_server="172.17.0.1:9092"
producer_id="producer_c"
topic="camera_event_c"
batch_interval=5

producer = kafkaProducer(csv_path, kafka_server, producer_id, topic, batch_interval)
producer.produce_batches()
# Out:
# [INFO] Successfully loaded data from data/camera_event_c.csv
# print 172.17.0.1:9092
# 172.17.0.1:9092
# [INFO] Publishing batch #1 (1 records)...
# [INFO] Batch #1 sent. Sleeping 5s...
# [DATA] Batch #1:
#                                event_id  batch_id car_plate  camera_id  \
# 0  d86e8cdb-c387-4ccb-b35a-346302238824         1   UTT 229          3
#
#                    timestamp  speed_reading
# 0 2024-01-01 08:00:54.958092          130.8
#
# [INFO] Publishing batch #2 (1 records)...
# [INFO] Batch #2 sent. Sleeping 5s...
# [DATA] Batch #2:
#                                event_id  batch_id car_plate  camera_id  \
# 1  f804c4e8-022d-4243-b43e-9ec0860ce6ff         2   CJW 924          3
#
#                    timestamp  speed_reading
# 1 2024-01-01 08:00:47.168827          164.5
#
# [INFO] Publishing batch #3 (2 records)...
# [INFO] Batch #3 sent. Sleeping 5s...
# [DATA] Batch #3:
#                                event_id  batch_id car_plate  camera_id  \
# 2  a246b391-fb7c-44a3-8f8b-ddf40bba3d05         3   WA 0712          3
# 3  e0dae388-6036-4b7d-ba58-bed0808c1611         3     KZE 5          3
#
#                    timestamp  speed_reading
# 2 2024-01-01 08:00:53.815270          134.4
# 3 2024-01-01 08:00:57.613888          125.3
#
# [INFO] Publishing batch #4 (2 records)...
# [INFO] Batch #4 sent. Sleeping 5s...
# [DATA] Batch #4:
#                                event_id  batch_id car_plate  camera_id  \
# 4  55a60e1c-818e-4e55-bc02-0627765629b2         4     ICE 8          3
# 5  daafd000-91fa-4ff7-a9bf-896ee74b35ad         4     WC 89          3
#
#                    timestamp  speed_reading
# 4 2024-01-01 08:01:16.405088          108.0
# 5 2024-01-01 08:01:18.835653           94.5
#
# [INFO] Publishing batch #5 (1 records)...
# [INFO] Batch #5 sent. Sleeping 5s...
# [DATA] Batch #5:
#                                event_id  batch_id car_plate  camera_id  \
# 6  8d6827a6-5ca3-49ac-8d67-f01b64a31c4f         5     KRN 7          3
#
#                    timestamp  speed_reading
# 6 2024-01-01 08:01:42.077427           76.2
#
# [INFO] Publishing batch #6 (1 records)...
# [INFO] Batch #6 sent. Sleeping 5s...
# [DATA] Batch #6:
#                                event_id  batch_id car_plate  camera_id  \
# 7  052e725b-3098-4f7d-9670-ebcdf30f022c         6   QE 1820          3
#
#                    timestamp  speed_reading
# 7 2024-01-01 08:01:50.367291           65.6
#
# [INFO] Publishing batch #7 (2 records)...
# [INFO] Batch #7 sent. Sleeping 5s...
# [DATA] Batch #7:
#                                event_id  batch_id car_plate  camera_id  \
# 8  cc084bd6-f680-43cf-9d6e-15bc481038b2         7  PKH 8115          3
# 9  676fa9f2-4a5b-4d1b-a63e-a59b1f2e5c26         7      PI 9          3
#
#                    timestamp  speed_reading
# 8 2024-01-01 08:08:52.583094          153.8
# 9 2024-01-01 08:08:53.620450          134.3
#
# [INFO] Publishing batch #8 (1 records)...
# [INFO] Batch #8 sent. Sleeping 5s...
# [DATA] Batch #8:
#                                 event_id  batch_id car_plate  camera_id  \
# 10  3f49174b-d0fe-4dd6-8cca-cab50d37a21f         8   EZ 6277          3
#
#                     timestamp  speed_reading
# 10 2024-01-01 08:09:18.931021           89.8
#
# [INFO] Publishing batch #9 (2 records)...
# [INFO] Batch #9 sent. Sleeping 5s...
# [DATA] Batch #9:
#                                 event_id  batch_id car_plate  camera_id  \
# 11  65cf39ff-73dc-4873-9a4d-aa0626848af9         9     KV 17          3
# 12  94fd563d-0df1-4b35-a89c-db72f3874b30         9     QJ 53          3
#
#                     timestamp  speed_reading
# 11 2024-01-01 08:09:25.802177           86.0
# 12 2024-01-01 08:09:29.843998           82.6
#
# [INFO] Publishing batch #10 (2 records)...
# [INFO] Batch #10 sent. Sleeping 5s...
# [DATA] Batch #10:
#                                 event_id  batch_id car_plate  camera_id  \
# 13  2f38e970-5042-4d91-8ef3-f8e4bed9908f        10    CZ 592          3
# 14  fa9e3b2a-de4e-48be-b97b-1c01e95e437a        10      AH 8          3
#
#                     timestamp  speed_reading
# 13 2024-01-01 08:00:47.453301          161.4
# 14 2024-01-01 08:00:49.247531          165.5
#
# [INFO] Publishing batch #11 (1 records)...
# [INFO] Batch #11 sent. Sleeping 5s...
# [DATA] Batch #11:
#                                 event_id  batch_id car_plate  camera_id  \
# 15  9a22f424-6c61-4e38-ad58-40c4bde9dfea        11    FZ 766          3
#
#                     timestamp  speed_reading
# 15 2024-01-01 08:01:00.555089          143.2
#
# [INFO] Publishing batch #12 (1 records)...
# [INFO] Batch #12 sent. Sleeping 5s...
# [DATA] Batch #12:
#                                 event_id  batch_id car_plate  camera_id  \
# 16  033183dc-45d4-4cab-98cf-a4f05088c76b        12    ZPG 90          3
#
#                     timestamp  speed_reading
# 16 2024-01-01 08:01:16.062056          101.4
#
# [INFO] Publishing batch #13 (1 records)...
# [INFO] Batch #13 sent. Sleeping 5s...
# [DATA] Batch #13:
#                                 event_id  batch_id car_plate  camera_id  \
# 17  49500aa0-39b9-4dc2-8e4d-69c8519b5983        13     JEJ 6          3
#
#                     timestamp  speed_reading
# 17 2024-01-01 08:09:06.369311          109.3
#
# [INFO] Publishing batch #14 (1 records)...
# [INFO] Batch #14 sent. Sleeping 5s...
# [DATA] Batch #14:
#                                 event_id  batch_id car_plate  camera_id  \
# 18  dfc12ef9-a6d4-48ab-8dab-47eae3e90e1c        14    IFY 23          3
#
#                     timestamp  speed_reading
# 18 2024-01-01 08:09:12.383098          115.7
#
# [INFO] Publishing batch #15 (1 records)...
# [INFO] Batch #15 sent. Sleeping 5s...
# [DATA] Batch #15:
#                                 event_id  batch_id car_plate  camera_id  \
# 19  645454f9-4d9e-4cc9-accc-7048fe7c010a        15     YRV 3          3
#
#                     timestamp  speed_reading
# 19 2024-01-01 08:09:53.655566           65.3
#
# [INFO] Publishing batch #16 (1 records)...
# [INFO] Batch #16 sent. Sleeping 5s...
# [DATA] Batch #16:
#                                 event_id  batch_id car_plate  camera_id  \
# 20  97f44470-dbf6-4c9c-94e9-5fb5b4a9bfb0        16   KWO 421          3
#
#                     timestamp  speed_reading
# 20 2024-01-01 08:14:17.095156          118.9
#
# [INFO] Publishing batch #17 (1 records)...
# [INFO] Batch #17 sent. Sleeping 5s...
# [DATA] Batch #17:
#                                 event_id  batch_id car_plate  camera_id  \
# 21  a012900c-1624-41f9-ae9d-c4ce3f07f061        17   ZV 2619          3
#
#                     timestamp  speed_reading
# 21 2024-01-01 08:14:27.485637           93.6
#
# [INFO] Publishing batch #18 (2 records)...
# [INFO] Batch #18 sent. Sleeping 5s...
# [DATA] Batch #18:
#                                 event_id  batch_id car_plate  camera_id  \
# 22  0a5c01b4-7019-4ab3-86fb-1b10bef30e8f        18    EOT 00          3
# 23  9cd09f0f-7c06-46db-b91e-683b7b9e7547        18      HP 1          3
#
#                     timestamp  speed_reading
# 22 2024-01-01 08:00:54.302613          137.8
# 23 2024-01-01 08:00:54.634856          144.3
#
# [INFO] Publishing batch #19 (1 records)...
# [INFO] Batch #19 sent. Sleeping 5s...
# [DATA] Batch #19:
#                                 event_id  batch_id car_plate  camera_id  \
# 24  9f0d72a2-a98b-4053-b65c-d88baf2571ff        19   CJP 278          3
#
#                     timestamp  speed_reading
# 24 2024-01-01 08:01:02.795526          118.6
#
# [INFO] Publishing batch #20 (1 records)...
# [INFO] Batch #20 sent. Sleeping 5s...
# [DATA] Batch #20:
#                                 event_id  batch_id car_plate  camera_id  \
# 25  283f4049-e9e6-46aa-8f25-94107f08f888        20   CX 6145          3
#
#                     timestamp  speed_reading
# 25 2024-01-01 08:01:11.368657          105.0
#
# [INFO] Publishing batch #21 (1 records)...
# [INFO] Batch #21 sent. Sleeping 5s...
# [DATA] Batch #21:
#                                 event_id  batch_id car_plate  camera_id  \
# 26  332a8fb7-77d6-44c2-a52b-b37b2f3777d2        21     WJX 2          3
#
#                     timestamp  speed_reading
# 26 2024-01-01 08:01:17.876767           99.2
#
# [INFO] Publishing batch #22 (1 records)...
# [INFO] Batch #22 sent. Sleeping 5s...
# [DATA] Batch #22:
#                                 event_id  batch_id car_plate  camera_id  \
# 27  250a7caf-f858-4a3b-8553-ce3ff0dd2c2b        22     FA 35          3
#
#                     timestamp  speed_reading
# 27 2024-01-01 08:01:29.666333           86.3
#
# [INFO] Publishing batch #23 (2 records)...
# [INFO] Batch #23 sent. Sleeping 5s...
# [DATA] Batch #23:
#                                 event_id  batch_id car_plate  camera_id  \
# 28  4154c60d-205c-4b9a-b6f5-3fce0de4602f        23    WB 418          3
# 29  81b00cc5-6329-4799-a1ef-90084142d5c7        23   UQV 232          3
#
#                     timestamp  speed_reading
# 28 2024-01-01 08:08:49.468866          135.5
# 29 2024-01-01 08:08:49.576904          169.8
#
# [INFO] Publishing batch #24 (2 records)...
# [INFO] Batch #24 sent. Sleeping 5s...
# [DATA] Batch #24:
#                                 event_id  batch_id car_plate  camera_id  \
# 30  6929adcc-9074-432d-b802-2bff7bc183eb        24   DWT 789          3
# 31  a47f07b1-cf3e-45a5-8ce9-fe6457c4d960        24    VWM 13          3
#
#                     timestamp  speed_reading
# 30 2024-01-01 08:09:00.148574          130.4
# 31 2024-01-01 08:09:01.054869          110.9
#
# [INFO] Publishing batch #25 (2 records)...
# [INFO] Batch #25 sent. Sleeping 5s...
# [DATA] Batch #25:
#                                 event_id  batch_id car_plate  camera_id  \
# 32  91189d3c-380e-4797-8fde-46c4431d7265        25    XYG 05          3
# 33  949e891a-4559-4589-9087-9314df3dc1a0        25   DSD 320          3
#
#                     timestamp  speed_reading
# 32 2024-01-01 08:09:07.354396          103.0
# 33 2024-01-01 08:09:08.960588          121.3
#
# [INFO] Publishing batch #26 (1 records)...
# [INFO] Batch #26 sent. Sleeping 5s...
# [DATA] Batch #26:
#                                 event_id  batch_id car_plate  camera_id  \
# 34  1ecf1920-14b1-4607-bc4f-a09f1c1c7a2f        26     BS 03          3
#
#                     timestamp  speed_reading
# 34 2024-01-01 08:09:13.293701           98.3
#
# [INFO] Publishing batch #27 (1 records)...
# [INFO] Batch #27 sent. Sleeping 5s...
# [DATA] Batch #27:
#                                 event_id  batch_id car_plate  camera_id  \
# 35  7973c256-0f8e-49cc-bf1d-76b4711e1ef7        27  WPV 1456          3
#
#                     timestamp  speed_reading
# 35 2024-01-01 08:09:32.626411           73.6
#
# [INFO] Publishing batch #28 (2 records)...
# [INFO] Batch #28 sent. Sleeping 5s...
# [DATA] Batch #28:
#                                 event_id  batch_id car_plate  camera_id  \
# 36  2d30d12f-21a9-4f9e-ba8a-96e535da6a0c        28   CIY 810          3
# 37  96d81dd6-ed32-403d-a3e4-4c3f4a2194a6        28     EC 40          3
#
#                     timestamp  speed_reading
# 36 2024-01-01 08:13:59.546855          135.4
# 37 2024-01-01 08:14:03.495092          154.7
#
# [INFO] Publishing batch #29 (2 records)...
# [INFO] Batch #29 sent. Sleeping 5s...
# [DATA] Batch #29:
#                                 event_id  batch_id car_plate  camera_id  \
# 38  1e68bb1d-f6e3-40a8-b24b-6c733061409d        29     QBF 1          3
# 39  12b0a280-758f-42e5-b616-550f7bae7fd2        29    NGP 66          3
#
#                     timestamp  speed_reading
# 38 2024-01-01 08:14:08.709918          128.9
# 39 2024-01-01 08:14:11.741826          109.8
#
# [INFO] Publishing batch #30 (1 records)...
# [INFO] Batch #30 sent. Sleeping 5s...
# [DATA] Batch #30:
#                                 event_id  batch_id car_plate  camera_id  \
# 40  f03b097a-462e-4963-996e-8e38994e61ce        30  VKZ 5377          3
#
#                     timestamp  speed_reading
# 40 2024-01-01 08:14:43.211632           75.4
#
# [INFO] Publishing batch #31 (2 records)...
# [INFO] Batch #31 sent. Sleeping 5s...
# [DATA] Batch #31:
#                                 event_id  batch_id car_plate  camera_id  \
# 41  b939fa8b-5abe-478f-b225-d3a541465d0b        31  YXA 7534          3
# 42  53002012-0061-401e-83a3-553a78035867        31    XY 025          3
#
#                     timestamp  speed_reading
# 41 2024-01-01 08:20:33.121746          164.9
# 42 2024-01-01 08:20:35.773241          138.1
#
# [INFO] Publishing batch #32 (1 records)...
# [INFO] Batch #32 sent. Sleeping 5s...
# [DATA] Batch #32:
#                                 event_id  batch_id car_plate  camera_id  \
# 43  43c9bb24-b749-46f4-9f5e-b6d5191e038a        32    QK 270          3
#
#                     timestamp  speed_reading
# 43 2024-01-01 08:20:54.851073          101.2
#
# [INFO] Publishing batch #33 (1 records)...
# [INFO] Batch #33 sent. Sleeping 5s...
# [DATA] Batch #33:
#                                 event_id  batch_id car_plate  camera_id  \
# 44  ce1a7295-709c-4788-99f2-0f89cc4ba580        33     KC 82          3
#
#                     timestamp  speed_reading
# 44 2024-01-01 08:21:05.725636           90.1
#
# [INFO] Publishing batch #34 (1 records)...
# [INFO] Batch #34 sent. Sleeping 5s...
# [DATA] Batch #34:
#                                 event_id  batch_id car_plate  camera_id  \
# 45  3390b101-e2e8-41d1-b262-e406911086e1        34    KKE 15          3
#
#                     timestamp  speed_reading
# 45 2024-01-01 08:00:50.542651          141.3
#
# [INFO] Publishing batch #35 (1 records)...
# [INFO] Batch #35 sent. Sleeping 5s...
# [DATA] Batch #35:
#                                 event_id  batch_id car_plate  camera_id  \
# 46  f0be3539-15eb-45e4-85cc-320d4db50d8d        35     FO 32          3
#
#                     timestamp  speed_reading
# 46 2024-01-01 08:01:15.640881           95.8
#
# [INFO] Publishing batch #36 (1 records)...
# [INFO] Batch #36 sent. Sleeping 5s...
# [DATA] Batch #36:
#                                 event_id  batch_id car_plate  camera_id  \
# 47  64f98c41-88b7-49d1-b956-b7772c30b8fa        36     WZ 24          3
#
#                     timestamp  speed_reading
# 47 2024-01-01 08:08:48.526751          150.7
#
# [INFO] Publishing batch #37 (1 records)...
# [INFO] Batch #37 sent. Sleeping 5s...
# [DATA] Batch #37:
#                                 event_id  batch_id car_plate  camera_id  \
# 48  01a4864b-46ad-4eb2-a911-43727c6c9c36        37   VM 4837          3
#
#                     timestamp  speed_reading
# 48 2024-01-01 08:09:11.510265           97.0
#
# [INFO] Publishing batch #38 (2 records)...
# [INFO] Batch #38 sent. Sleeping 5s...
# [DATA] Batch #38:
#                                 event_id  batch_id car_plate  camera_id  \
# 49  fe6c7545-0844-492d-a0ae-6e1ba9ba45fe        38     QZ 81          3
# 50  a4ef0b9a-0a3a-4ed5-86c7-83c83f7848b3        38  AJB 6689          3
#
#                     timestamp  speed_reading
# 49 2024-01-01 08:09:58.988288           63.3
# 50 2024-01-01 08:09:59.513428           62.5
#
# [INFO] Publishing batch #39 (2 records)...
# [INFO] Batch #39 sent. Sleeping 5s...
# [DATA] Batch #39:
#                                 event_id  batch_id car_plate  camera_id  \
# 51  0d3b2edd-a679-4aba-8812-ff8645204071        39     RK 76          3
# 52  b67f032a-4a8f-4886-aa70-8f0a85bad105        39    XCC 09          3
#
#                     timestamp  speed_reading
# 51 2024-01-01 08:14:00.882270          132.7
# 52 2024-01-01 08:14:03.976783          144.8
#
# [INFO] Publishing batch #40 (2 records)...
# [INFO] Batch #40 sent. Sleeping 5s...
# [DATA] Batch #40:
#                                 event_id  batch_id car_plate  camera_id  \
# 53  ca4fcb17-29db-4e74-a1c7-0b4293c925eb        40      GL 4          3
# 54  b53daf92-a04b-470b-b7f6-a664986fec12        40     ZQ 22          3
#
#                     timestamp  speed_reading
# 53 2024-01-01 08:14:08.564138          114.5
# 54 2024-01-01 08:14:09.023200          111.4
#
# [INFO] Publishing batch #41 (1 records)...
# [INFO] Batch #41 sent. Sleeping 5s...
# [DATA] Batch #41:
#                                 event_id  batch_id car_plate  camera_id  \
# 55  1a77d4c1-63fa-4ca9-b599-af0f9f6e106e        41      VZ 8          3
#
#                     timestamp  speed_reading
# 55 2024-01-01 08:14:23.762903           95.7
#
# [INFO] Publishing batch #42 (1 records)...
# [INFO] Batch #42 sent. Sleeping 5s...
# [DATA] Batch #42:
#                                 event_id  batch_id car_plate  camera_id  \
# 56  f81d9f5b-5ba9-407c-9809-612de212c06a        42  ZEA 3530          3
#
#                     timestamp  speed_reading
# 56 2024-01-01 08:20:35.365308          143.5
#
# [INFO] Publishing batch #43 (1 records)...
# [INFO] Batch #43 sent. Sleeping 5s...
# [DATA] Batch #43:
#                                 event_id  batch_id car_plate  camera_id  \
# 57  91a3bab8-fa70-4613-852c-634bce2984b6        43     DOR 6          3
#
#                     timestamp  speed_reading
# 57 2024-01-01 08:20:48.867512          110.1
#
# [INFO] Publishing batch #44 (1 records)...
# [INFO] Batch #44 sent. Sleeping 5s...
# [DATA] Batch #44:
#                                 event_id  batch_id car_plate  camera_id  \
# 58  78858d73-7233-4d39-8c20-2891278930a9        44      BU 9          3
#
#                     timestamp  speed_reading
# 58 2024-01-01 08:21:01.968054           92.8
#
# [INFO] Publishing batch #45 (2 records)...
# [INFO] Batch #45 sent. Sleeping 5s...
# [DATA] Batch #45:
#                                 event_id  batch_id car_plate  camera_id  \
# 59  b4cba9e5-4be3-4a81-a70f-f78372052199        45    VLY 61          3
# 60  f7791bb7-92e6-4842-9c83-0512cda7f529        45  HLZ 1649          3
#
#                     timestamp  speed_reading
# 59 2024-01-01 08:21:08.699219           80.9
# 60 2024-01-01 08:21:10.109678           89.3
#
# [INFO] Publishing batch #46 (1 records)...
# [INFO] Batch #46 sent. Sleeping 5s...
# [DATA] Batch #46:
#                                 event_id  batch_id car_plate  camera_id  \
# 61  b1a191f8-65e5-4284-8eaf-e1358240c9c8        46     WX 49          3
#
#                     timestamp  speed_reading
# 61 2024-01-01 08:21:14.975844           74.4
#
# [INFO] Publishing batch #47 (1 records)...
# [INFO] Batch #47 sent. Sleeping 5s...
# [DATA] Batch #47:
#                                 event_id  batch_id car_plate  camera_id  \
# 62  320bc122-d866-487e-9267-2f804ff939fa        47    BQN 88          3
#
#                     timestamp  speed_reading
# 62 2024-01-01 08:21:43.579488           61.7
#
# [INFO] Publishing batch #48 (1 records)...
# [INFO] Batch #48 sent. Sleeping 5s...
# [DATA] Batch #48:
#                                 event_id  batch_id car_plate  camera_id  \
# 63  0f30aa31-610b-4df0-9215-4789735d0bfa        48    DGT 19          3
#
#                     timestamp  speed_reading
# 63 2024-01-01 08:26:19.150336          130.6
#
# [INFO] Publishing batch #49 (1 records)...
# [INFO] Batch #49 sent. Sleeping 5s...
# [DATA] Batch #49:
#                                 event_id  batch_id car_plate  camera_id  \
# 64  9a5d0e8b-24af-44a9-bc31-d01c354fada8        49    MZ 242          3
#
#                     timestamp  speed_reading
# 64 2024-01-01 08:13:56.886282          160.8
#
# [INFO] Publishing batch #50 (2 records)...
# [INFO] Batch #50 sent. Sleeping 5s...
# [DATA] Batch #50:
#                                 event_id  batch_id car_plate  camera_id  \
# 65  a3d27ed2-acff-4e77-b209-d939d423d0d2        50     VJX 7          3
# 66  bcbc2400-fea4-4f4e-aa9f-285ebee4ca2b        50   WVV 824          3
#
#                     timestamp  speed_reading
# 65 2024-01-01 08:14:14.721078          119.7
# 66 2024-01-01 08:14:16.669783          110.2
#
# [INFO] Publishing batch #51 (1 records)...
# [INFO] Batch #51 sent. Sleeping 5s...
# [DATA] Batch #51:
#                                 event_id  batch_id car_plate  camera_id  \
# 67  937d55b5-e7e9-4d6f-989d-6502f2bf2b37        51      DJ 9          3
#
#                     timestamp  speed_reading
# 67 2024-01-01 08:14:32.755618           89.9
#
# [INFO] Publishing batch #52 (1 records)...
# [INFO] Batch #52 sent. Sleeping 5s...
# [DATA] Batch #52:
#                                 event_id  batch_id car_plate  camera_id  \
# 68  b01a3186-9681-4421-bd87-904464098c1d        52    GI 029          3
#
#                     timestamp  speed_reading
# 68 2024-01-01 08:15:09.338907           64.4
#
# [INFO] Publishing batch #53 (1 records)...
# [INFO] Batch #53 sent. Sleeping 5s...
# [DATA] Batch #53:
#                                 event_id  batch_id car_plate  camera_id  \
# 69  9da0f30a-11f3-4842-b592-0091d4bdb015        53  CDC 5769          3
#
#                     timestamp  speed_reading
# 69 2024-01-01 08:20:34.333003          150.4
#
# [INFO] Publishing batch #54 (1 records)...
# [INFO] Batch #54 sent. Sleeping 5s...
# [DATA] Batch #54:
#                                 event_id  batch_id car_plate  camera_id  \
# 70  a6217585-a405-42d4-8360-eb460a9f2965        54    XYE 28          3
#
#                     timestamp  speed_reading
# 70 2024-01-01 08:21:23.023195           69.9
#
# [INFO] Publishing batch #55 (1 records)...
# [INFO] Batch #55 sent. Sleeping 5s...
# [DATA] Batch #55:
#                                 event_id  batch_id car_plate  camera_id  \
# 71  e8570ab2-9230-41de-ac4e-dfe458a092e2        55     WOQ 4          3
#
#                     timestamp  speed_reading
# 71 2024-01-01 08:21:30.700352           66.6
#
# [INFO] Publishing batch #56 (3 records)...
# [INFO] Batch #56 sent. Sleeping 5s...
# [DATA] Batch #56:
#                                 event_id  batch_id car_plate  camera_id  \
# 72  60ac0119-8850-4f4a-afe1-0f39c4838e63        56      FQ 3          3
# 73  d20390fc-13ee-40c7-bf2f-259a069fdec0        56    JYA 82          3
# 74  28036b0a-ff82-402e-9a4c-24e9e1aef377        56     AFS 0          3
#
#                     timestamp  speed_reading
# 72 2024-01-01 08:26:10.164546          161.2
# 73 2024-01-01 08:26:12.117064          133.6
# 74 2024-01-01 08:26:12.806842          133.1
#
# [INFO] Publishing batch #57 (1 records)...
# [INFO] Batch #57 sent. Sleeping 5s...
# [DATA] Batch #57:
#                                 event_id  batch_id car_plate  camera_id  \
# 75  a7189a79-e587-4581-89cc-49b86e9d3323        57     VC 45          3
#
#                     timestamp  speed_reading
# 75 2024-01-01 08:26:48.172857           79.4
#
# [INFO] Publishing batch #58 (1 records)...
# [INFO] Batch #58 sent. Sleeping 5s...
# [DATA] Batch #58:
#                                 event_id  batch_id car_plate  camera_id  \
# 76  6d4a9e15-f7c1-468c-b4bf-c68706564508        58    KOB 22          3
#
#                     timestamp  speed_reading
# 76 2024-01-01 08:27:02.016169           73.7
#
# [INFO] Publishing batch #59 (1 records)...
# [INFO] Batch #59 sent. Sleeping 5s...
# [DATA] Batch #59:
#                                 event_id  batch_id car_plate  camera_id  \
# 77  3681f1d0-76ba-4cfa-826b-6b8bd8795b0f        59  SAL 1597          3
#
#                     timestamp  speed_reading
# 77 2024-01-01 08:36:15.462498          140.6
#
# [INFO] Publishing batch #60 (1 records)...
# [INFO] Batch #60 sent. Sleeping 5s...
# [DATA] Batch #60:
#                                 event_id  batch_id car_plate  camera_id  \
# 78  d210762b-9d89-416b-99d6-e731aadbe91b        60     KSH 1          3
#
#                     timestamp  speed_reading
# 78 2024-01-01 08:36:33.967150           96.9
#
# [INFO] Publishing batch #61 (1 records)...
# [INFO] Batch #61 sent. Sleeping 5s...
# [DATA] Batch #61:
#                                 event_id  batch_id car_plate  camera_id  \
# 79  59f8916d-f925-44fb-ad26-907e580ab804        61   SS 1621          3
#
#                     timestamp  speed_reading
# 79 2024-01-01 08:13:59.866147          132.4
#
# [INFO] Publishing batch #62 (1 records)...
# [INFO] Batch #62 sent. Sleeping 5s...
# [DATA] Batch #62:
#                                 event_id  batch_id car_plate  camera_id  \
# 80  0fde7d8a-4501-40ff-8c51-4257bbb94e81        62  ARX 7573          3
#
#                     timestamp  speed_reading
# 80 2024-01-01 08:14:08.836936          113.9
#
# [INFO] Publishing batch #63 (1 records)...
# [INFO] Batch #63 sent. Sleeping 5s...
# [DATA] Batch #63:
#                                 event_id  batch_id car_plate  camera_id  \
# 81  6d2f1ae3-30b5-41cc-9a01-d41a32510f04        63      ZZ 8          3
#
#                     timestamp  speed_reading
# 81 2024-01-01 08:15:05.585777           61.5
#
# [INFO] Publishing batch #64 (2 records)...
# [INFO] Batch #64 sent. Sleeping 5s...
# [DATA] Batch #64:
#                                 event_id  batch_id car_plate  camera_id  \
# 82  19b11b99-dd36-44c9-90bc-f5e362794739        64  TZQ 7586          3
# 83  a2abfcca-70ef-4f1b-ac75-3f81c5d11cbf        64     SJ 15          3
#
#                     timestamp  speed_reading
# 82 2024-01-01 08:20:38.975244          138.1
# 83 2024-01-01 08:20:39.104756          140.5
#
# [INFO] Publishing batch #65 (1 records)...
# [INFO] Batch #65 sent. Sleeping 5s...
# [DATA] Batch #65:
#                                 event_id  batch_id car_plate  camera_id  \
# 84  4ea72cb9-3a69-4854-a2d9-d172d306036c        65   CI 9861          3
#
#                     timestamp  speed_reading
# 84 2024-01-01 08:20:44.871113          118.7
#
# [INFO] Publishing batch #66 (1 records)...
# [INFO] Batch #66 sent. Sleeping 5s...
# [DATA] Batch #66:
#                                 event_id  batch_id car_plate  camera_id  \
# 85  c67cb41c-8833-4659-89f5-04b6371a6e27        66     ZCL 3          3
#
#                     timestamp  speed_reading
# 85 2024-01-01 08:20:58.947057           97.7
#
# [INFO] Publishing batch #67 (1 records)...
# [INFO] Batch #67 sent. Sleeping 5s...
# [DATA] Batch #67:
#                                 event_id  batch_id car_plate  camera_id  \
# 86  a401558c-8b47-4ae4-be2e-cee442b8c1a8        67    YY 765          3
#
#                     timestamp  speed_reading
# 86 2024-01-01 08:21:24.142692           74.2
#
# [INFO] Publishing batch #68 (1 records)...
# [INFO] Batch #68 sent. Sleeping 5s...
# [DATA] Batch #68:
#                                 event_id  batch_id car_plate  camera_id  \
# 87  c4f51ed4-c925-4889-9a2f-8c3e34d93aa2        68    ZLY 15          3
#
#                     timestamp  speed_reading
# 87 2024-01-01 08:26:10.741019          153.5
#
# [INFO] Publishing batch #69 (1 records)...
# [INFO] Batch #69 sent. Sleeping 5s...
# [DATA] Batch #69:
#                                 event_id  batch_id car_plate  camera_id  \
# 88  9b85a771-6ae5-4b31-9c86-78131ec2ae88        69   YE 6517          3
#
#                     timestamp  speed_reading
# 88 2024-01-01 08:26:20.939769          119.7
#
# [INFO] Publishing batch #70 (1 records)...
# [INFO] Batch #70 sent. Sleeping 5s...
# [DATA] Batch #70:
#                                 event_id  batch_id car_plate  camera_id  \
# 89  162d4fe5-9519-4fd9-857a-0204ba11532a        70  TAD 5898          3
#
#                     timestamp  speed_reading
# 89 2024-01-01 08:26:29.495112          112.7
#
# [INFO] Publishing batch #71 (1 records)...
# [INFO] Batch #71 sent. Sleeping 5s...
# [DATA] Batch #71:
#                                 event_id  batch_id car_plate  camera_id  \
# 90  835c8eb6-6f3c-4675-8b7d-3fba15c58d78        71      PW 7          3
#
#                     timestamp  speed_reading
# 90 2024-01-01 08:26:49.807145           90.2
#
# [INFO] Publishing batch #72 (1 records)...
# [INFO] Batch #72 sent. Sleeping 5s...
# [DATA] Batch #72:
#                                 event_id  batch_id car_plate  camera_id  \
# 91  73569120-03b1-41d8-9478-8eb147bc986c        72   DAW 165          3
#
#                     timestamp  speed_reading
# 91 2024-01-01 08:26:55.452108           77.0
#
# [INFO] Publishing batch #73 (2 records)...
# [INFO] Batch #73 sent. Sleeping 5s...
# [DATA] Batch #73:
#                                 event_id  batch_id car_plate  camera_id  \
# 92  d1173857-9c2a-43f9-a037-65fdc0c21788        73   TB 5190          3
# 93  d5ebe15b-552f-4a4e-81c5-93f957ff6a54        73  KNT 8153          3
#
#                     timestamp  speed_reading
# 92 2024-01-01 08:36:08.660079          150.7
# 93 2024-01-01 08:36:10.877278          137.8
#
# [INFO] Publishing batch #74 (2 records)...
# [INFO] Batch #74 sent. Sleeping 5s...
# [DATA] Batch #74:
#                                 event_id  batch_id car_plate  camera_id  \
# 94  e1438907-28e7-485d-af2b-76b5b4f38423        74    ZVK 10          3
# 95  3e258aa7-dfb3-4e3c-a77e-5a7909e6d389        74   IF 7805          3
#
#                     timestamp  speed_reading
# 94 2024-01-01 08:36:17.444047          132.7
# 95 2024-01-01 08:36:18.903653          131.6
#
# [INFO] Publishing batch #75 (1 records)...
# [INFO] Batch #75 sent. Sleeping 5s...
# [DATA] Batch #75:
#                                 event_id  batch_id car_plate  camera_id  \
# 96  92ceedc7-3976-49cb-bd35-7ba605c77b04        75     WX 31          3
#
#                     timestamp  speed_reading
# 96 2024-01-01 08:36:23.356819          119.6
#
# [INFO] Publishing batch #76 (1 records)...
# [INFO] Batch #76 sent. Sleeping 5s...
# [DATA] Batch #76:
#                                 event_id  batch_id car_plate  camera_id  \
# 97  0f04d3f0-887d-4cee-a295-f473095f2be2        76    FFG 22          3
#
#                     timestamp  speed_reading
# 97 2024-01-01 08:36:39.434087           92.8
#
# [INFO] Publishing batch #77 (1 records)...
# [INFO] Batch #77 sent. Sleeping 5s...
# [DATA] Batch #77:
#                                 event_id  batch_id car_plate  camera_id  \
# 98  de3ebe2f-70ef-4b9e-9721-bea237283069        77   XWC 903          3
#
#                     timestamp  speed_reading
# 98 2024-01-01 08:43:32.867932          123.0
#
# [INFO] Publishing batch #78 (1 records)...
# [INFO] Batch #78 sent. Sleeping 5s...
# [DATA] Batch #78:
#                                 event_id  batch_id car_plate  camera_id  \
# 99  455273e3-489e-46b1-9be6-73bcfa2e8bcf        78  YTE 8888          3
#
#                     timestamp  speed_reading
# 99 2024-01-01 08:43:58.345666           91.8
#
# [INFO] Publishing batch #79 (1 records)...
# [INFO] Batch #79 sent. Sleeping 5s...
# [DATA] Batch #79:
#                                  event_id  batch_id car_plate  camera_id  \
# 100  8d54c0fd-5554-4b90-97d1-b5c2952a323b        79    CU 131          3
#
#                      timestamp  speed_reading
# 100 2024-01-01 08:44:05.714894           80.3
#
# [INFO] Publishing batch #80 (2 records)...
# [INFO] Batch #80 sent. Sleeping 5s...
# [DATA] Batch #80:
#                                  event_id  batch_id car_plate  camera_id  \
# 101  de2b3e1d-d253-4d8b-a7e6-029e46394851        80   BUB 647          3
# 102  d2edbfb2-e181-4657-a58a-b05c60758703        80   DBF 451          3
#
#                      timestamp  speed_reading
# 101 2024-01-01 08:44:40.862263           61.7
# 102 2024-01-01 08:44:42.096650           61.5
#
# [INFO] Publishing batch #81 (1 records)...
# [INFO] Batch #81 sent. Sleeping 5s...
# [DATA] Batch #81:
#                                  event_id  batch_id car_plate  camera_id  \
# 103  27b6759f-2c2a-4103-a668-037aba98695f        81     PB 55          3
#
#                      timestamp  speed_reading
# 103 2024-01-01 08:20:54.685198          101.9
#
# [INFO] Publishing batch #82 (3 records)...
# [INFO] Batch #82 sent. Sleeping 5s...
# [DATA] Batch #82:
#                                  event_id  batch_id car_plate  camera_id  \
# 104  d73c82f8-8405-4353-85a9-4b2b2b4d31fd        82   QQ 6161          3
# 105  b9de14df-b361-4379-83f1-d7c1afd80bd7        82     ZBR 9          3
# 106  6b887dcb-176b-415d-abe7-5b4871ef8bea        82    AW 965          3
#
#                      timestamp  speed_reading
# 104 2024-01-01 08:26:15.929559          117.5
# 105 2024-01-01 08:26:17.373922          130.1
# 106 2024-01-01 08:26:19.638669          126.7
#
# [INFO] Publishing batch #83 (2 records)...
# [INFO] Batch #83 sent. Sleeping 5s...
# [DATA] Batch #83:
#                                  event_id  batch_id car_plate  camera_id  \
# 107  263f1397-838e-47cf-a644-68225d5a4d88        83   HMU 040          3
# 108  4b8cca7a-c904-4891-b9f0-66d7c747f5c3        83   ZCO 026          3
#
#                      timestamp  speed_reading
# 107 2024-01-01 08:36:22.076749          124.4
# 108 2024-01-01 08:36:25.107988          113.5
#
# [INFO] Publishing batch #84 (1 records)...
# [INFO] Batch #84 sent. Sleeping 5s...
# [DATA] Batch #84:
#                                  event_id  batch_id car_plate  camera_id  \
# 109  6bec04b8-b838-449d-9e47-2cf6a41fa1e6        84   XSG 781          3
#
#                      timestamp  speed_reading
# 109 2024-01-01 08:37:03.846482           68.9
#
# [INFO] Publishing batch #85 (1 records)...
# [INFO] Batch #85 sent. Sleeping 5s...
# [DATA] Batch #85:
#                                  event_id  batch_id car_plate  camera_id  \
# 110  f5f20484-0d83-48dc-ac7d-97b7b7624b97        85    ZG 714          3
#
#                      timestamp  speed_reading
# 110 2024-01-01 08:43:29.603145          129.8
#
# [INFO] Publishing batch #86 (1 records)...
# [INFO] Batch #86 sent. Sleeping 5s...
# [DATA] Batch #86:
#                                  event_id  batch_id car_plate  camera_id  \
# 111  6f63ddb9-068c-43e6-a4dc-54564ffb469e        86   YO 3272          3
#
#                      timestamp  speed_reading
# 111 2024-01-01 08:43:46.765307          102.3
#
# [INFO] Publishing batch #87 (1 records)...
# [INFO] Batch #87 sent. Sleeping 5s...
# [DATA] Batch #87:
#                                  event_id  batch_id car_plate  camera_id  \
# 112  035e86de-1faf-4009-bb4d-404ef291c8bd        87  IMC 6788          3
#
#                      timestamp  speed_reading
# 112 2024-01-01 08:44:01.782430           91.3
#
# [INFO] Publishing batch #88 (1 records)...
# [INFO] Batch #88 sent. Sleeping 5s...
# [DATA] Batch #88:
#                                  event_id  batch_id car_plate  camera_id  \
# 113  b91ba6fb-7903-419e-8628-71744fd8d276        88  BPV 0250          3
#
#                      timestamp  speed_reading
# 113 2024-01-01 08:44:10.723828           76.5
#
# [INFO] Publishing batch #89 (1 records)...
# [INFO] Batch #89 sent. Sleeping 5s...
# [DATA] Batch #89:
#                                  event_id  batch_id car_plate  camera_id  \
# 114  41e79aa9-bb6b-4d9a-99e2-5562ee7b1870        89   MC 2760          3
#
#                      timestamp  speed_reading
# 114 2024-01-01 08:44:20.522451           72.3
#
# [INFO] Publishing batch #90 (1 records)...
# [INFO] Batch #90 sent. Sleeping 5s...
# [DATA] Batch #90:
#                                  event_id  batch_id car_plate  camera_id  \
# 115  120640ea-e7b2-48df-8074-0eb34fe320b4        90    BCZ 29          3
#
#                      timestamp  speed_reading
# 115 2024-01-01 08:52:19.516028          165.1
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# [INFO] Publishing batch #91 (1 records)...
# [INFO] Batch #91 sent. Sleeping 5s...
# [DATA] Batch #91:
#                                  event_id  batch_id car_plate  camera_id  \
# 116  5f26c7e0-11ad-4364-81b4-1d803666d21a        91   NQ 0051          3
#
#                      timestamp  speed_reading
# 116 2024-01-01 08:52:51.320876           96.4
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# [INFO] Publishing batch #92 (4 records)...
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 batch_interval=5
#       8 producer = kafkaProducer(csv_path, kafka_server, producer_id, topic, batch_interval)
# ----> 9 producer.produce_batches()
#
# File ~/util.py:85, in kafkaProducer.produce_batches(self)
#      82         print(f"[WARN] Failed to send event {event['event_id']}: {e}")
#      84 # Force all buffered messages out
# ---> 85 self.producer.flush()
#      86 print(f"[INFO] Batch #{batch_id} sent. Sleeping {self.batch_interval}s...")
#      87 print(f"[DATA] Batch #{batch_id}:\n{batch_df}\n")
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/producer/kafka.py:652, in KafkaProducer.flush(self, timeout)
#     650 self._accumulator.begin_flush()
#     651 self._sender.wakeup()
# --> 652 self._accumulator.await_flush_completion(timeout=timeout)
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/producer/record_accumulator.py:528, in RecordAccumulator.await_flush_completion(self, timeout)
#     525 for batch in self._incomplete.all():
#     526     log.debug('Waiting on produce to %s',
#     527               batch.produce_future.topic_partition)
# --> 528     if not batch.produce_future.wait(timeout=timeout):
#     529         raise Errors.KafkaTimeoutError('Timeout waiting for future')
#     530     if not batch.produce_future.is_done:
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/producer/future.py:28, in FutureProduceResult.wait(self, timeout)
#      26 def wait(self, timeout=None):
#      27     # wait() on python2.6 returns None instead of the flag value
# ---> 28     return self._latch.wait(timeout) or self._latch.is_set()
#
# File /opt/conda/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     556 signaled = self._flag
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File /opt/conda/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:
