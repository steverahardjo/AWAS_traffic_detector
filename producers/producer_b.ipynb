# %%
from util import kafkaProducer

# %%
csv_path="data/camera_event_b.csv"
#ip address is the zookeeper & port to the kafka port
kafka_server="172.17.0.1:9092"
producer_id="producer_b"
topic="camera_event_b"
batch_interval=5

producer = kafkaProducer(csv_path, kafka_server, producer_id, topic, batch_interval)
producer.produce_batches()
# Out:
# [INFO] Successfully loaded data from data/camera_event_b.csv
# print 172.17.0.1:9092
# 172.17.0.1:9092
# [INFO] Publishing batch #1 (5 records)...
# [INFO] Batch #1 sent. Sleeping 5s...
# [DATA] Batch #1:
#                                event_id  batch_id car_plate  camera_id  \
# 0  b5b7dae7-3bf9-4f75-aea8-398d3bde3a41         1   CJW 924          2
# 1  1649c03b-cd6f-47bd-b4f2-c44fcf60524d         1    CZ 592          2
# 2  a9c6a4b7-a6b6-4bd7-9719-88bd895814f4         1   UTT 229          2
# 3  4e13ec51-02db-442c-b7aa-3a2050dd1ad1         1   WA 0712          2
# 4  74248dd9-c9f8-48d2-94fb-dc5610a0f735         1      AH 8          2
#
#                    timestamp  speed_reading
# 0 2024-01-01 08:00:26.029536          156.8
# 1 2024-01-01 08:00:26.729115          163.9
# 2 2024-01-01 08:00:26.887170          134.1
# 3 2024-01-01 08:00:27.601617          133.8
# 4 2024-01-01 08:00:28.125701          158.9
#
# [INFO] Publishing batch #2 (1 records)...
# [INFO] Batch #2 sent. Sleeping 5s...
# [DATA] Batch #2:
#                                event_id  batch_id car_plate  camera_id  \
# 5  c14b050b-9319-4705-9adc-74c99eff0791         2    FZ 766          2
#
#                    timestamp  speed_reading
# 5 2024-01-01 08:00:33.114696          136.0
#
# [INFO] Publishing batch #3 (1 records)...
# [INFO] Batch #3 sent. Sleeping 5s...
# [DATA] Batch #3:
#                                event_id  batch_id car_plate  camera_id  \
# 6  e5ae9cab-569c-45e0-b31f-9e6f07d55838         3     WC 89          2
#
#                    timestamp  speed_reading
# 6 2024-01-01 08:00:41.774758           93.5
#
# [INFO] Publishing batch #4 (4 records)...
# [INFO] Batch #4 sent. Sleeping 5s...
# [DATA] Batch #4:
#                                 event_id  batch_id car_plate  camera_id  \
# 7   9f2e4a15-24fb-4879-9129-5800338088fa         4    EOT 00          2
# 8   ee787113-eb0d-49d6-9cf9-054569625449         4      HP 1          2
# 9   cada35fc-33a8-4bf0-a640-e0d6fc2a73df         4     KZE 5          2
# 10  ac84bb22-32be-4993-a655-49874adeecc4         4   CJP 278          2
#
#                     timestamp  speed_reading
# 7  2024-01-01 08:00:28.290929          138.8
# 8  2024-01-01 08:00:28.740321          142.8
# 9  2024-01-01 08:00:29.186382          135.2
# 10 2024-01-01 08:00:31.515912          117.6
#
# [INFO] Publishing batch #5 (4 records)...
# [INFO] Batch #5 sent. Sleeping 5s...
# [DATA] Batch #5:
#                                 event_id  batch_id car_plate  camera_id  \
# 11  68ffa68c-a083-4a30-a123-9464521462bb         5     WJX 2          2
# 12  0fac4c5a-7793-4993-97b3-169d41b57680         5    ZPG 90          2
# 13  2b797755-2cb6-449f-b580-1dd691334076         5   CX 6145          2
# 14  7b90e93f-714a-46c9-b6b7-9bbcf07cceb1         5     ICE 8          2
#
#                     timestamp  speed_reading
# 11 2024-01-01 08:00:38.751677           94.8
# 12 2024-01-01 08:00:39.898370           98.4
# 13 2024-01-01 08:00:40.382453          110.5
# 14 2024-01-01 08:00:40.838661          103.2
#
# [INFO] Publishing batch #6 (2 records)...
# [INFO] Batch #6 sent. Sleeping 5s...
# [DATA] Batch #6:
#                                 event_id  batch_id car_plate  camera_id  \
# 15  8916338e-f0f5-4fac-8d8d-cdb6c03d1d07         6     KRN 7          2
# 16  6626efb2-32f3-4bda-8a34-d79eedf615c8         6   QE 1820          2
#
#                     timestamp  speed_reading
# 15 2024-01-01 08:00:52.541902           75.5
# 16 2024-01-01 08:00:57.368642           66.1
#
# [INFO] Publishing batch #7 (3 records)...
# [INFO] Batch #7 sent. Sleeping 5s...
# [DATA] Batch #7:
#                                 event_id  batch_id car_plate  camera_id  \
# 17  7dff112a-d3ce-4ebb-841f-ea3e03662ead         7    WB 418          2
# 18  1f739fcb-8e46-4c92-a69b-9a18533cb646         7      PI 9          2
# 19  756a47f3-7f81-4e17-88fa-b2bbed9aa29e         7  PKH 8115          2
#
#                     timestamp  speed_reading
# 17 2024-01-01 08:08:24.091422          138.8
# 18 2024-01-01 08:08:26.478501          140.9
# 19 2024-01-01 08:08:28.027669          143.8
#
# [INFO] Publishing batch #8 (1 records)...
# [INFO] Batch #8 sent. Sleeping 5s...
# [DATA] Batch #8:
#                                 event_id  batch_id car_plate  camera_id  \
# 20  eb9614ad-ee22-4001-835f-4242e362be01         8     JEJ 6          2
#
#                     timestamp  speed_reading
# 20 2024-01-01 08:08:34.116409          111.2
#
# [INFO] Publishing batch #9 (2 records)...
# [INFO] Batch #9 sent. Sleeping 5s...
# [DATA] Batch #9:
#                                 event_id  batch_id car_plate  camera_id  \
# 21  be049d21-395f-4d4d-9b6d-b9abf442219b         9   EZ 6277          2
# 22  ac68fd91-60d4-4120-8f5a-2a0f2984549f         9     KV 17          2
#
#                     timestamp  speed_reading
# 21 2024-01-01 08:08:39.920072           94.3
# 22 2024-01-01 08:08:44.552593           86.9
#
# [INFO] Publishing batch #10 (2 records)...
# [INFO] Batch #10 sent. Sleeping 5s...
# [DATA] Batch #10:
#                                 event_id  batch_id car_plate  camera_id  \
# 23  58588fd9-1fd6-4b52-929b-406731bbce2b        10  WPV 1456          2
# 24  274dffed-ed69-4f56-8a2e-5c017d27adc1        10     QJ 53          2
#
#                     timestamp  speed_reading
# 23 2024-01-01 08:08:45.845657           75.1
# 24 2024-01-01 08:08:46.302895           82.8
#
# [INFO] Publishing batch #11 (1 records)...
# [INFO] Batch #11 sent. Sleeping 5s...
# [DATA] Batch #11:
#                                 event_id  batch_id car_plate  camera_id  \
# 25  7012857e-8060-4291-8c2d-0a8601c258d8        11     YRV 3          2
#
#                     timestamp  speed_reading
# 25 2024-01-01 08:08:58.749711           63.8
#
# [INFO] Publishing batch #12 (1 records)...
# [INFO] Batch #12 sent. Sleeping 5s...
# [DATA] Batch #12:
#                                 event_id  batch_id car_plate  camera_id  \
# 26  42b0938d-6524-40b5-99cc-b71e26aa30f3        12    KKE 15          2
#
#                     timestamp  speed_reading
# 26 2024-01-01 08:00:23.896476          138.3
#
# [INFO] Publishing batch #13 (1 records)...
# [INFO] Batch #13 sent. Sleeping 5s...
# [DATA] Batch #13:
#                                 event_id  batch_id car_plate  camera_id  \
# 27  7dba46aa-77b5-47f5-9801-d30e5ddff0d7        13     FO 32          2
#
#                     timestamp  speed_reading
# 27 2024-01-01 08:00:39.240776           94.8
#
# [INFO] Publishing batch #14 (1 records)...
# [INFO] Batch #14 sent. Sleeping 5s...
# [DATA] Batch #14:
#                                 event_id  batch_id car_plate  camera_id  \
# 28  3f9d8d31-718b-4021-b3f0-1f5aed75009b        14     FA 35          2
#
#                     timestamp  speed_reading
# 28 2024-01-01 08:00:48.370527           84.2
#
# [INFO] Publishing batch #15 (2 records)...
# [INFO] Batch #15 sent. Sleeping 5s...
# [DATA] Batch #15:
#                                 event_id  batch_id car_plate  camera_id  \
# 29  cbafd132-a61f-4713-b2f9-76f08141c70e        15     WZ 24          2
# 30  9dd51204-9367-4369-8575-611b817ce296        15   UQV 232          2
#
#                     timestamp  speed_reading
# 29 2024-01-01 08:08:25.481310          160.2
# 30 2024-01-01 08:08:25.620770          157.6
#
# [INFO] Publishing batch #16 (2 records)...
# [INFO] Batch #16 sent. Sleeping 5s...
# [DATA] Batch #16:
#                                 event_id  batch_id car_plate  camera_id  \
# 31  340aef07-48be-44d0-aeb8-b08df2023f7e        16    VWM 13          2
# 32  d3051697-4d90-4d15-8802-b34bd9436732        16    XYG 05          2
#
#                     timestamp  speed_reading
# 31 2024-01-01 08:08:31.623998          117.3
# 32 2024-01-01 08:08:33.906703          109.6
#
# [INFO] Publishing batch #17 (1 records)...
# [INFO] Batch #17 sent. Sleeping 5s...
# [DATA] Batch #17:
#                                 event_id  batch_id car_plate  camera_id  \
# 33  d33a1a67-4f54-47d9-a3c1-f9fbcd5751a9        17    IFY 23          2
#
#                     timestamp  speed_reading
# 33 2024-01-01 08:08:38.633820          111.1
#
# [INFO] Publishing batch #18 (1 records)...
# [INFO] Batch #18 sent. Sleeping 5s...
# [DATA] Batch #18:
#                                 event_id  batch_id car_plate  camera_id  \
# 34  b8762345-0b31-4cc6-b35c-e99e5168c7b7        18     QZ 81          2
#
#                     timestamp  speed_reading
# 34 2024-01-01 08:09:01.211939           62.0
#
# [INFO] Publishing batch #19 (4 records)...
# [INFO] Batch #19 sent. Sleeping 5s...
# [DATA] Batch #19:
#                                 event_id  batch_id car_plate  camera_id  \
# 35  315c64ac-0f96-4a67-98c4-7d7b85cfa455        19   CIY 810          2
# 36  d40dc066-ba11-4d44-a4e5-48f7038544a7        19     ZQ 22          2
# 37  40d72911-cdde-4af8-9a18-68aa908a46a5        19     EC 40          2
# 38  1622ac4e-d0d1-4713-85fe-e5b5f01d1c28        19    NGP 66          2
#
#                     timestamp  speed_reading
# 35 2024-01-01 08:13:34.334415          136.3
# 36 2024-01-01 08:13:36.902545          113.0
# 37 2024-01-01 08:13:37.027065          144.7
# 38 2024-01-01 08:13:38.833509          107.2
#
# [INFO] Publishing batch #20 (2 records)...
# [INFO] Batch #20 sent. Sleeping 5s...
# [DATA] Batch #20:
#                                 event_id  batch_id car_plate  camera_id  \
# 39  2ae298d2-5496-4732-95ef-82f4b57ef4b7        20   KWO 421          2
# 40  61ffc37e-73c0-4fa9-a604-e2596e8f6289        20   ZV 2619          2
#
#                     timestamp  speed_reading
# 39 2024-01-01 08:13:44.248324          115.4
# 40 2024-01-01 08:13:48.703774           96.8
#
# [INFO] Publishing batch #21 (1 records)...
# [INFO] Batch #21 sent. Sleeping 5s...
# [DATA] Batch #21:
#                                 event_id  batch_id car_plate  camera_id  \
# 41  b8bea07f-235c-4ce0-9b27-fb2f524fb331        21  VKZ 5377          2
#
#                     timestamp  speed_reading
# 41 2024-01-01 08:13:57.545422           75.9
#
# [INFO] Publishing batch #22 (3 records)...
# [INFO] Batch #22 sent. Sleeping 5s...
# [DATA] Batch #22:
#                                 event_id  batch_id car_plate  camera_id  \
# 42  3d5110f0-2eb0-4ff6-8319-53677a95fb5c        22   DWT 789          2
# 43  a5cea7f7-ffa2-497d-9ae2-305343afa884        22   VM 4837          2
# 44  6eff696a-810d-40ab-99b0-860b8eb43e97        22   DSD 320          2
#
#                     timestamp  speed_reading
# 42 2024-01-01 08:08:34.407062          135.4
# 43 2024-01-01 08:08:34.840158          101.6
# 44 2024-01-01 08:08:36.677773          117.8
#
# [INFO] Publishing batch #23 (1 records)...
# [INFO] Batch #23 sent. Sleeping 5s...
# [DATA] Batch #23:
#                                 event_id  batch_id car_plate  camera_id  \
# 45  60aca271-dd79-410e-9ca5-2bac6057b293        23     BS 03          2
#
#                     timestamp  speed_reading
# 45 2024-01-01 08:08:40.094285          104.1
#
# [INFO] Publishing batch #24 (1 records)...
# [INFO] Batch #24 sent. Sleeping 5s...
# [DATA] Batch #24:
#                                 event_id  batch_id car_plate  camera_id  \
# 46  f1a7e4bc-e95f-45a3-87f2-bb62bff7b3e1        24  AJB 6689          2
#
#                     timestamp  speed_reading
# 46 2024-01-01 08:09:01.958624           62.8
#
# [INFO] Publishing batch #25 (2 records)...
# [INFO] Batch #25 sent. Sleeping 5s...
# [DATA] Batch #25:
#                                 event_id  batch_id car_plate  camera_id  \
# 47  c6a47514-5b97-4347-adfd-ba7a756615d5        25    MZ 242          2
# 48  9f2babdd-5d6d-4d44-a682-0bd264135fb2        25    XCC 09          2
#
#                     timestamp  speed_reading
# 47 2024-01-01 08:13:34.452533          152.6
# 48 2024-01-01 08:13:37.428884          138.7
#
# [INFO] Publishing batch #26 (2 records)...
# [INFO] Batch #26 sent. Sleeping 5s...
# [DATA] Batch #26:
#                                 event_id  batch_id car_plate  camera_id  \
# 49  97de7ab2-ba78-4c85-9606-2529a89c37d2        26     QBF 1          2
# 50  ab8a8200-a871-4c97-8728-e3a4affdec46        26     VJX 7          2
#
#                     timestamp  speed_reading
# 49 2024-01-01 08:13:40.716844          123.4
# 50 2024-01-01 08:13:42.566126          116.8
#
# [INFO] Publishing batch #27 (1 records)...
# [INFO] Batch #27 sent. Sleeping 5s...
# [DATA] Batch #27:
#                                 event_id  batch_id car_plate  camera_id  \
# 51  de1adf7e-7e71-4bc2-bef4-5eed33d8843f        27      VZ 8          2
#
#                     timestamp  speed_reading
# 51 2024-01-01 08:13:48.051570          100.3
#
# [INFO] Publishing batch #28 (1 records)...
# [INFO] Batch #28 sent. Sleeping 5s...
# [DATA] Batch #28:
#                                 event_id  batch_id car_plate  camera_id  \
# 52  d0bd79a8-7091-4805-9033-c7c1d0129fa2        28      DJ 9          2
#
#                     timestamp  speed_reading
# 52 2024-01-01 08:13:53.160817           88.0
#
# [INFO] Publishing batch #29 (1 records)...
# [INFO] Batch #29 sent. Sleeping 5s...
# [DATA] Batch #29:
#                                 event_id  batch_id car_plate  camera_id  \
# 53  a78c2f5c-209e-476f-bcd1-a27fd3bb9363        29    GI 029          2
#
#                     timestamp  speed_reading
# 53 2024-01-01 08:14:11.002081           62.8
#
# [INFO] Publishing batch #30 (2 records)...
# [INFO] Batch #30 sent. Sleeping 5s...
# [DATA] Batch #30:
#                                 event_id  batch_id car_plate  camera_id  \
# 54  ab220781-1fa1-446d-b53f-b6d55309adbf        30  YXA 7534          2
# 55  62c94001-08b5-4ccf-904a-b75306211865        30    XY 025          2
#
#                     timestamp  speed_reading
# 54 2024-01-01 08:20:09.042838          156.8
# 55 2024-01-01 08:20:09.810937          144.2
#
# [INFO] Publishing batch #31 (3 records)...
# [INFO] Batch #31 sent. Sleeping 5s...
# [DATA] Batch #31:
#                                 event_id  batch_id car_plate  camera_id  \
# 56  cb6c805f-0ed3-41c3-83ea-e6deb90630b4        31    QK 270          2
# 57  472bc017-baed-4051-817f-c02656ab8923        31      BU 9          2
# 58  d673c20c-e6dc-4aa0-836e-ce3b7ccca966        31     KC 82          2
#
#                     timestamp  speed_reading
# 56 2024-01-01 08:20:22.366226          105.0
# 57 2024-01-01 08:20:24.564142           93.4
# 58 2024-01-01 08:20:25.681283           88.8
#
# [INFO] Publishing batch #32 (1 records)...
# [INFO] Batch #32 sent. Sleeping 5s...
# [DATA] Batch #32:
#                                 event_id  batch_id car_plate  camera_id  \
# 59  70c995cb-d00e-44f0-a199-d8d15248da6d        32    VLY 61          2
#
#                     timestamp  speed_reading
# 59 2024-01-01 08:20:27.488349           84.4
#
# [INFO] Publishing batch #33 (1 records)...
# [INFO] Batch #33 sent. Sleeping 5s...
# [DATA] Batch #33:
#                                 event_id  batch_id car_plate  camera_id  \
# 60  6d8d4c6d-5ee2-456e-9c82-f5042a1dd3a0        33     WOQ 4          2
#
#                     timestamp  speed_reading
# 60 2024-01-01 08:20:36.101765           67.2
#
# [INFO] Publishing batch #34 (2 records)...
# [INFO] Batch #34 sent. Sleeping 5s...
# [DATA] Batch #34:
#                                 event_id  batch_id car_plate  camera_id  \
# 61  39c0ebcf-64ce-433c-a01b-02feb51ef9b2        34   SS 1621          2
# 62  249a31d7-c3d8-4734-977c-73cacf0b76ab        34     RK 76          2
#
#                     timestamp  speed_reading
# 61 2024-01-01 08:13:32.038795          139.2
# 62 2024-01-01 08:13:35.098357          135.7
#
# [INFO] Publishing batch #35 (3 records)...
# [INFO] Batch #35 sent. Sleeping 5s...
# [DATA] Batch #35:
#                                 event_id  batch_id car_plate  camera_id  \
# 63  c6d66aa7-cdf3-4715-acbe-4874548d30ad        35      GL 4          2
# 64  e0a30a32-2019-48f1-8cf1-ec91419b6b44        35  ARX 7573          2
# 65  94bf1e7e-7e6e-47bd-9378-094a39af7a96        35   WVV 824          2
#
#                     timestamp  speed_reading
# 63 2024-01-01 08:13:39.596807          116.3
# 64 2024-01-01 08:13:39.870679          120.4
# 65 2024-01-01 08:13:43.941688          109.0
#
# [INFO] Publishing batch #36 (1 records)...
# [INFO] Batch #36 sent. Sleeping 5s...
# [DATA] Batch #36:
#                                 event_id  batch_id car_plate  camera_id  \
# 66  11238bd0-c006-4bfa-8c6f-c8064e0d06a9        36      ZZ 8          2
#
#                     timestamp  speed_reading
# 66 2024-01-01 08:14:06.169494           61.3
#
# [INFO] Publishing batch #37 (4 records)...
# [INFO] Batch #37 sent. Sleeping 5s...
# [DATA] Batch #37:
#                                 event_id  batch_id car_plate  camera_id  \
# 67  e01aeb58-806f-4635-931b-1429a618a34d        37     SJ 15          2
# 68  007926df-1bc5-40b0-b851-409d11c56013        37  ZEA 3530          2
# 69  1766270c-3293-4b56-9fef-8b16250fe1c3        37     DOR 6          2
# 70  7a0ed97c-8aeb-413b-831e-bf10dc172ada        37   CI 9861          2
#
#                     timestamp  speed_reading
# 67 2024-01-01 08:20:10.735632          135.5
# 68 2024-01-01 08:20:11.726340          148.7
# 69 2024-01-01 08:20:15.232184          106.1
# 70 2024-01-01 08:20:15.304029          118.8
#
# [INFO] Publishing batch #38 (1 records)...
# [INFO] Batch #38 sent. Sleeping 5s...
# [DATA] Batch #38:
#                                 event_id  batch_id car_plate  camera_id  \
# 71  84d8dbf6-322d-422f-ad4e-72fbcbefc63a        38     ZCL 3          2
#
#                     timestamp  speed_reading
# 71 2024-01-01 08:20:23.108400          101.1
#
# [INFO] Publishing batch #39 (2 records)...
# [INFO] Batch #39 sent. Sleeping 5s...
# [DATA] Batch #39:
#                                 event_id  batch_id car_plate  camera_id  \
# 72  686f079d-3e40-4e3f-80a7-3b450f9a2e86        39     WX 49          2
# 73  9160a62b-341c-4c59-937c-381ba9c45765        39  HLZ 1649          2
#
#                     timestamp  speed_reading
# 72 2024-01-01 08:20:29.626095           77.7
# 73 2024-01-01 08:20:29.641873           85.8
#
# [INFO] Publishing batch #40 (1 records)...
# [INFO] Batch #40 sent. Sleeping 5s...
# [DATA] Batch #40:
#                                 event_id  batch_id car_plate  camera_id  \
# 74  31f0d1d0-876a-4994-b3f1-66dc5de1bd95        40    YY 765          2
#
#                     timestamp  speed_reading
# 74 2024-01-01 08:20:36.853489           76.4
#
# [INFO] Publishing batch #41 (1 records)...
# [INFO] Batch #41 sent. Sleeping 5s...
# [DATA] Batch #41:
#                                 event_id  batch_id car_plate  camera_id  \
# 75  597976de-5886-477d-895b-0f9e1e355c83        41    BQN 88          2
#
#                     timestamp  speed_reading
# 75 2024-01-01 08:20:46.885893           61.9
#
# [INFO] Publishing batch #42 (4 records)...
# [INFO] Batch #42 sent. Sleeping 5s...
# [DATA] Batch #42:
#                                 event_id  batch_id car_plate  camera_id  \
# 76  25f89334-492a-43a8-9149-7e48566dff38        42     AFS 0          2
# 77  9fcd88c7-0936-4d2f-a1fc-b84626615008        42    ZLY 15          2
# 78  2378fdc8-efb2-4053-873e-9216523f8f06        42    JYA 82          2
# 79  4083acd5-d65b-4ef7-a122-8f277d57635d        42    DGT 19          2
#
#                     timestamp  speed_reading
# 76 2024-01-01 08:25:46.040096          126.8
# 77 2024-01-01 08:25:46.822689          150.5
# 78 2024-01-01 08:25:47.987095          145.0
# 79 2024-01-01 08:25:49.140729          126.5
#
# [INFO] Publishing batch #43 (1 records)...
# [INFO] Batch #43 sent. Sleeping 5s...
# [DATA] Batch #43:
#                                 event_id  batch_id car_plate  camera_id  \
# 80  988064e2-5e43-434b-868a-c201ca32240a        43  TAD 5898          2
#
#                     timestamp  speed_reading
# 80 2024-01-01 08:25:55.623224          110.0
#
# [INFO] Publishing batch #44 (1 records)...
# [INFO] Batch #44 sent. Sleeping 5s...
# [DATA] Batch #44:
#                                 event_id  batch_id car_plate  camera_id  \
# 81  070b3acc-a3b4-4f8d-a9ab-9f038d4019e0        44     VC 45          2
#
#                     timestamp  speed_reading
# 81 2024-01-01 08:26:04.266939           81.2
#
# [INFO] Publishing batch #45 (2 records)...
# [INFO] Batch #45 sent. Sleeping 5s...
# [DATA] Batch #45:
#                                 event_id  batch_id car_plate  camera_id  \
# 82  94ef728f-729e-4203-a193-114c2bc5a4ba        45  CDC 5769          2
# 83  f1cf9949-cdef-445d-97f1-ea11d7fca232        45  TZQ 7586          2
#
#                     timestamp  speed_reading
# 82 2024-01-01 08:20:07.980001          142.6
# 83 2024-01-01 08:20:11.973492          134.4
#
# [INFO] Publishing batch #46 (1 records)...
# [INFO] Batch #46 sent. Sleeping 5s...
# [DATA] Batch #46:
#                                 event_id  batch_id car_plate  camera_id  \
# 84  79697b94-8b50-405c-b206-83eb8753d03e        46     PB 55          2
#
#                     timestamp  speed_reading
# 84 2024-01-01 08:20:20.722993          106.3
#
# [INFO] Publishing batch #47 (1 records)...
# [INFO] Batch #47 sent. Sleeping 5s...
# [DATA] Batch #47:
#                                 event_id  batch_id car_plate  camera_id  \
# 85  f85b16f0-2fbd-485a-bf1c-52c3bd0b1631        47    XYE 28          2
#
#                     timestamp  speed_reading
# 85 2024-01-01 08:20:33.362601           70.1
#
# [INFO] Publishing batch #48 (3 records)...
# [INFO] Batch #48 sent. Sleeping 5s...
# [DATA] Batch #48:
#                                 event_id  batch_id car_plate  camera_id  \
# 86  14a74806-d1ce-4c84-a2f1-ea2132bf2e04        48      FQ 3          2
# 87  d344d812-84d6-4c47-a920-50f7381028f9        48    AW 965          2
# 88  83e6886c-ac32-4e31-a7bd-72e7122efb3a        48   YE 6517          2
#
#                     timestamp  speed_reading
# 86 2024-01-01 08:25:48.220423          171.8
# 87 2024-01-01 08:25:49.011255          120.4
# 88 2024-01-01 08:25:52.211400          121.0
#
# [INFO] Publishing batch #49 (3 records)...
# [INFO] Batch #49 sent. Sleeping 5s...
# [DATA] Batch #49:
#                                 event_id  batch_id car_plate  camera_id  \
# 89  199b6211-f467-4e9b-998f-12afcbb0b754        49   DAW 165          2
# 90  0651f0b6-6036-443e-8aec-db3da2697402        49      PW 7          2
# 91  c74d0ca9-d126-49a9-83a8-6dcdf498d5a1        49    KOB 22          2
#
#                     timestamp  speed_reading
# 89 2024-01-01 08:26:06.940647           74.7
# 90 2024-01-01 08:26:08.091496           86.7
# 91 2024-01-01 08:26:11.487707           73.1
#
# [INFO] Publishing batch #50 (4 records)...
# [INFO] Batch #50 sent. Sleeping 5s...
# [DATA] Batch #50:
#                                 event_id  batch_id car_plate  camera_id  \
# 92  4747d3e1-3f6a-4c76-8705-747276c52c35        50  SAL 1597          2
# 93  d5bae299-29ae-464f-89c5-c7492be45668        50    ZVK 10          2
# 94  75a5c4c1-eb0b-4f66-a61a-8edd3383743f        50     WX 31          2
# 95  129cb37d-a63b-4fd4-80d0-219ca72453ef        50   IF 7805          2
#
#                     timestamp  speed_reading
# 92 2024-01-01 08:35:49.319244          139.1
# 93 2024-01-01 08:35:50.299663          127.3
# 94 2024-01-01 08:35:50.307887          113.3
# 95 2024-01-01 08:35:53.965569          135.7
#
# [INFO] Publishing batch #51 (2 records)...
# [INFO] Batch #51 sent. Sleeping 5s...
# [DATA] Batch #51:
#                                 event_id  batch_id car_plate  camera_id  \
# 96  a51c2fe2-cd12-421d-a758-9ee2c9ec37ed        51     KSH 1          2
# 97  fee48261-1bbb-408f-ad68-eadb1ea2f056        51    FFG 22          2
#
#                     timestamp  speed_reading
# 96 2024-01-01 08:35:56.825927           99.9
# 97 2024-01-01 08:35:59.290498           93.9
#
# [INFO] Publishing batch #52 (6 records)...
# [INFO] Batch #52 sent. Sleeping 5s...
# [DATA] Batch #52:
#                                  event_id  batch_id car_plate  camera_id  \
# 98   1a665370-9eab-4066-8801-c41ed75e342f        52     GPR 4          2
# 99   6d8286aa-6178-4f00-978a-98238c94f452        52    REP 98          2
# 100  077287f1-0ebb-40a9-8e76-69951bcb9980        52   QQ 6161          2
# 101  c19ae57d-181a-4b68-8c42-b1a26bc67480        52   IMU 122          2
# 102  ea0d6207-e626-4ce7-bf1f-fb72678c7911        52      OW 5          2
# 103  d01bcc6c-1c6e-4132-ab8c-aef2e2b91136        52     ZBR 9          2
#
#                      timestamp  speed_reading
# 98  2024-01-01 08:25:46.819880          149.0
# 99  2024-01-01 08:25:47.052618          132.1
# 100 2024-01-01 08:25:47.880222          123.8
# 101 2024-01-01 08:25:48.015527          133.1
# 102 2024-01-01 08:25:48.713213          132.6
# 103 2024-01-01 08:25:51.273648          129.0
#
# [INFO] Publishing batch #53 (1 records)...
# [INFO] Batch #53 sent. Sleeping 5s...
# [DATA] Batch #53:
#                                  event_id  batch_id car_plate  camera_id  \
# 104  077aa2e5-9ea2-48a8-92a1-7ec2d8964a5c        53   WX 2585          2
#
#                      timestamp  speed_reading
# 104 2024-01-01 08:25:59.122112          106.1
#
# [INFO] Publishing batch #54 (1 records)...
# [INFO] Batch #54 sent. Sleeping 5s...
# [DATA] Batch #54:
#                                  event_id  batch_id car_plate  camera_id  \
# 105  59412c64-a5f7-45dc-9ab0-08332110f6d6        54    IU 033          2
#
#                      timestamp  speed_reading
# 105 2024-01-01 08:26:09.484373           80.8
#
# [INFO] Publishing batch #55 (5 records)...
# [INFO] Batch #55 sent. Sleeping 5s...
# [DATA] Batch #55:
#                                  event_id  batch_id car_plate  camera_id  \
# 106  709719ca-a6f5-4739-af0a-a53e698b68f9        55     KNZ 1          2
# 107  574ef9f7-5ca3-4e2d-a323-3f4530e0ce1d        55   TB 5190          2
# 108  9e6d33c3-f430-4585-bcf4-8844641b85d8        55  KNT 8153          2
# 109  19ab3e54-d3d0-4f39-8297-642e3c35a624        55    WK 223          2
# 110  b88daf50-dfd8-495d-ba04-0625ddccbc85        55    MFH 37          2
#
#                      timestamp  speed_reading
# 106 2024-01-01 08:35:45.146554          124.0
# 107 2024-01-01 08:35:46.256573          153.0
# 108 2024-01-01 08:35:48.119786          147.7
# 109 2024-01-01 08:35:49.092244          128.0
# 110 2024-01-01 08:35:49.688224          117.8
#
# [INFO] Publishing batch #56 (1 records)...
# [INFO] Batch #56 sent. Sleeping 5s...
# [DATA] Batch #56:
#                                  event_id  batch_id car_plate  camera_id  \
# 111  27054ac0-8854-489c-94b8-d875d2497d38        56   XSG 781          2
#
#                      timestamp  speed_reading
# 111 2024-01-01 08:36:11.656394           69.0
#
# [INFO] Publishing batch #57 (1 records)...
# [INFO] Batch #57 sent. Sleeping 5s...
# [DATA] Batch #57:
#                                  event_id  batch_id car_plate  camera_id  \
# 112  ed683f77-07e1-4d8e-b2f3-805d3ed82091        57   XWC 903          2
#
#                      timestamp  speed_reading
# 112 2024-01-01 08:43:06.117169          127.6
#
# [INFO] Publishing batch #58 (2 records)...
# [INFO] Batch #58 sent. Sleeping 5s...
# [DATA] Batch #58:
#                                  event_id  batch_id car_plate  camera_id  \
# 113  5dce6c9d-79dd-4b9e-9a74-0401e305c707        58  YTE 8888          2
# 114  22889716-c948-4d08-9d49-6275deea693e        58    CU 131          2
#
#                      timestamp  speed_reading
# 113 2024-01-01 08:43:18.777511           93.8
# 114 2024-01-01 08:43:21.733149           79.4
#
# [INFO] Publishing batch #59 (2 records)...
# [INFO] Batch #59 sent. Sleeping 5s...
# [DATA] Batch #59:
#                                  event_id  batch_id car_plate  camera_id  \
# 115  d0fbaadb-ea27-418c-acf0-c68e0ce8058b        59      OH 2          2
# 116  b247b540-f113-4120-97c8-7c05899c4646        59  BPV 0250          2
#
#                      timestamp  speed_reading
# 115 2024-01-01 08:43:24.544815           70.5
# 116 2024-01-01 08:43:25.555619           79.0
#
# [INFO] Publishing batch #60 (1 records)...
# [INFO] Batch #60 sent. Sleeping 5s...
# [DATA] Batch #60:
#                                  event_id  batch_id car_plate  camera_id  \
# 117  8e6bbfa7-9d6d-49ca-8db9-c84eb9e4a9b3        60   MC 2760          2
#
#                      timestamp  speed_reading
# 117 2024-01-01 08:43:31.121448           70.9
#
# [INFO] Publishing batch #61 (2 records)...
# [INFO] Batch #61 sent. Sleeping 5s...
# [DATA] Batch #61:
#                                  event_id  batch_id car_plate  camera_id  \
# 118  b0c6a36b-c5a4-487b-97e6-f69da611e3ee        61   BUB 647          2
# 119  a93a4ee8-c970-423c-bac9-2245579b01a0        61   DBF 451          2
#
#                      timestamp  speed_reading
# 118 2024-01-01 08:43:40.762403           60.7
# 119 2024-01-01 08:43:42.078363           62.0
#
# [INFO] Publishing batch #62 (4 records)...
# [INFO] Batch #62 sent. Sleeping 5s...
# [DATA] Batch #62:
#                                  event_id  batch_id car_plate  camera_id  \
# 120  ad09aaf0-d2cf-4280-8352-26c3778cb121        62  NJN 8189          2
# 121  3c86113d-ee96-4f1a-bdd6-c296f4d368a9        62    VH 827          2
# 122  9d03b365-b844-4566-80f0-37b662cf8d65        62   HMU 040          2
# 123  6b532fa0-42d3-4a29-9d65-0479e35e4625        62   ZCO 026          2
#
#                      timestamp  speed_reading
# 120 2024-01-01 08:35:49.130384          128.6
# 121 2024-01-01 08:35:51.117464          109.6
# 122 2024-01-01 08:35:51.949377          117.2
# 123 2024-01-01 08:35:53.034384          116.3
#
# [INFO] Publishing batch #63 (2 records)...
# [INFO] Batch #63 sent. Sleeping 5s...
# [DATA] Batch #63:
#                                  event_id  batch_id car_plate  camera_id  \
# 124  99ce030f-2b73-43fe-bcd7-4a0959e64ceb        63     PS 93          2
# 125  def44cb3-9553-4637-a9dc-5c33c6c2eab6        63   GNU 052          2
#
#                      timestamp  speed_reading
# 124 2024-01-01 08:35:54.670752          104.9
# 125 2024-01-01 08:35:55.800945          123.3
#
# [INFO] Publishing batch #64 (1 records)...
# [INFO] Batch #64 sent. Sleeping 5s...
# [DATA] Batch #64:
#                                  event_id  batch_id car_plate  camera_id  \
# 126  4193dddd-07c2-495f-abaf-8d36e0b1bd3f        64  IXF 6187          2
#
#                      timestamp  speed_reading
# 126 2024-01-01 08:36:04.621293           86.9
#
# [INFO] Publishing batch #65 (1 records)...
# [INFO] Batch #65 sent. Sleeping 5s...
# [DATA] Batch #65:
#                                  event_id  batch_id car_plate  camera_id  \
# 127  ff61a0b6-26e8-465c-ae58-8d7310cbdcfd        65     HX 98          2
#
#                      timestamp  speed_reading
# 127 2024-01-01 08:36:15.110398           66.1
#
# [INFO] Publishing batch #66 (1 records)...
# [INFO] Batch #66 sent. Sleeping 5s...
# [DATA] Batch #66:
#                                  event_id  batch_id car_plate  camera_id  \
# 128  9779f1f5-2105-48e3-8b61-200235c9f60a        66    ZG 714          2
#
#                      timestamp  speed_reading
# 128 2024-01-01 08:43:03.073409          137.5
#
# [INFO] Publishing batch #67 (1 records)...
# [INFO] Batch #67 sent. Sleeping 5s...
# [DATA] Batch #67:
#                                  event_id  batch_id car_plate  camera_id  \
# 129  52c19adb-31a1-4657-aaae-1c2f1adf2109        67   YO 3272          2
#
#                      timestamp  speed_reading
# 129 2024-01-01 08:43:13.165909          106.8
#
# [INFO] Publishing batch #68 (2 records)...
# [INFO] Batch #68 sent. Sleeping 5s...
# [DATA] Batch #68:
#                                  event_id  batch_id car_plate  camera_id  \
# 130  438f32b1-8db6-4860-baf6-4b3ef709b498        68  IMC 6788          2
# 131  a2a98d1e-fe17-484b-80cd-3a706ec3821c        68   UMZ 673          2
#
#                      timestamp  speed_reading
# 130 2024-01-01 08:43:19.942862           88.1
# 131 2024-01-01 08:43:24.814462           82.8
#
# [INFO] Publishing batch #69 (1 records)...
# [INFO] Batch #69 sent. Sleeping 5s...
# [DATA] Batch #69:
#                                  event_id  batch_id car_plate  camera_id  \
# 132  ead47447-e062-4d3d-9967-7c9febfa4c7f        69    CKI 86          2
#
#                      timestamp  speed_reading
# 132 2024-01-01 08:43:35.679775           67.4
#
# [INFO] Publishing batch #70 (2 records)...
# [INFO] Batch #70 sent. Sleeping 5s...
# [DATA] Batch #70:
#                                  event_id  batch_id car_plate  camera_id  \
# 133  f8c53bc8-ba2a-405a-83fe-3fba52fb4055        70  EBZ 5064          2
# 134  01bb358e-a946-43d6-9dbe-7824508d96ff        70    BCZ 29          2
#
#                      timestamp  speed_reading
# 133 2024-01-01 08:51:52.352273          138.3
# 134 2024-01-01 08:51:55.011053          158.0
#
# [INFO] Publishing batch #71 (1 records)...
# [INFO] Batch #71 sent. Sleeping 5s...
# [DATA] Batch #71:
#                                  event_id  batch_id car_plate  camera_id  \
# 135  2bba7a1f-e47c-47c7-84be-eb57073b406b        71     FRG 9          2
#
#                      timestamp  speed_reading
# 135 2024-01-01 08:51:58.520917          132.6
#
# [INFO] Publishing batch #72 (3 records)...
# [INFO] Batch #72 sent. Sleeping 5s...
# [DATA] Batch #72:
#                                  event_id  batch_id car_plate  camera_id  \
# 136  930fbd40-092f-47ef-b2af-ecec8a51035c        72      YO 4          2
# 137  d48168b7-e8c1-4c34-b08e-664a0b966d4d        72    DFV 91          2
# 138  3429e0c5-f75d-429f-be8c-d49b6018a6b4        72   NQ 0051          2
#
#                      timestamp  speed_reading
# 136 2024-01-01 08:52:09.356400           89.1
# 137 2024-01-01 08:52:11.414018           77.9
# 138 2024-01-01 08:52:12.469121           97.4
#
# [INFO] Publishing batch #73 (1 records)...
# [INFO] Batch #73 sent. Sleeping 5s...
# [DATA] Batch #73:
#                                  event_id  batch_id car_plate  camera_id  \
# 139  e95708e5-c66e-4acd-a96f-4aee1c145fe1        73    AL 006          2
#
#                      timestamp  speed_reading
# 139 2024-01-01 08:52:17.671103           81.6
#
# [INFO] Publishing batch #74 (3 records)...
# [INFO] Batch #74 sent. Sleeping 5s...
# [DATA] Batch #74:
#                                  event_id  batch_id car_plate  camera_id  \
# 140  73ee9929-b3cd-400a-a8d1-b88924fa0f3e        74     QAR 0          2
# 141  7c500f87-f94c-48a2-9389-cd50a5486d05        74   XY 7365          2
# 142  65905876-10f7-48aa-936f-67d022bdcb86        74     UQ 07          2
#
#                      timestamp  speed_reading
# 140 2024-01-01 08:43:00.823060          147.9
# 141 2024-01-01 08:43:01.555121          166.2
# 142 2024-01-01 08:43:03.639060          142.6
#
# [INFO] Publishing batch #75 (2 records)...
# [INFO] Batch #75 sent. Sleeping 5s...
# [DATA] Batch #75:
#                                  event_id  batch_id car_plate  camera_id  \
# 143  231a382b-fa5e-4ede-87d5-c7a7316a29dc        75      EX 2          2
# 144  ca8b7906-9f25-4e57-9490-6c3bc214319d        75     PJ 35          2
#
#                      timestamp  speed_reading
# 143 2024-01-01 08:43:10.472510          110.5
# 144 2024-01-01 08:43:11.884657          120.8
#
# [INFO] Publishing batch #76 (2 records)...
# [INFO] Batch #76 sent. Sleeping 5s...
# [DATA] Batch #76:
#                                  event_id  batch_id car_plate  camera_id  \
# 145  aa6b5f8f-b70e-41ab-9684-6916320f7002        76   ZHC 847          2
# 146  6eb70153-ddeb-4842-8da1-33589c47d8ec        76   CXD 617          2
#
#                      timestamp  speed_reading
# 145 2024-01-01 08:43:29.552456           75.7
# 146 2024-01-01 08:43:30.005101           74.6
#
# [INFO] Publishing batch #77 (3 records)...
# [INFO] Batch #77 sent. Sleeping 5s...
# [DATA] Batch #77:
#                                  event_id  batch_id car_plate  camera_id  \
# 147  8a877642-a9f0-4bed-b9be-e8338236c15b        77    VTY 24          2
# 148  9c781130-608e-4fea-bff5-ca71f836cb06        77     QY 29          2
# 149  61773450-1b67-4bd1-b56f-276baa6edd97        77  IOS 2265          2
#
#                      timestamp  speed_reading
# 147 2024-01-01 08:51:55.623123          149.7
# 148 2024-01-01 08:51:56.285941          118.6
# 149 2024-01-01 08:51:57.562661          124.5
#
# [INFO] Publishing batch #78 (1 records)...
# [INFO] Batch #78 sent. Sleeping 5s...
# [DATA] Batch #78:
#                                  event_id  batch_id car_plate  camera_id  \
# 150  35888e60-af77-46c5-8615-779a837684e6        78     JY 97          2
#
#                      timestamp  speed_reading
# 150 2024-01-01 08:52:02.858242          122.7
#
# [INFO] Publishing batch #79 (2 records)...
# [INFO] Batch #79 sent. Sleeping 5s...
# [DATA] Batch #79:
#                                  event_id  batch_id car_plate  camera_id  \
# 151  0a4da8a7-acf6-4f8b-8283-7fd6d9207dc9        79    TKL 60          2
# 152  5907dccd-da6c-4220-9909-9ff49232d007        79   KY 2578          2
#
#                      timestamp  speed_reading
# 151 2024-01-01 08:52:12.644891           88.5
# 152 2024-01-01 08:52:15.591941           92.7
#
# [INFO] Publishing batch #80 (2 records)...
# [INFO] Batch #80 sent. Sleeping 5s...
# [DATA] Batch #80:
#                                  event_id  batch_id car_plate  camera_id  \
# 153  c648561a-333f-4c53-a0df-f05e7d31fddc        80    NE 205          2
# 154  8466fd0c-7e28-4ddc-a588-2cabb0f112a8        80     NR 26          2
#
#                      timestamp  speed_reading
# 153 2024-01-01 08:52:20.488742           71.3
# 154 2024-01-01 08:52:23.696912           64.0
#
# [INFO] Publishing batch #81 (2 records)...
# [INFO] Batch #81 sent. Sleeping 5s...
# [DATA] Batch #81:
#                                  event_id  batch_id car_plate  camera_id  \
# 155  1fc4b440-38d2-4254-8cab-50ce8a170f1e        81  DLX 5534          2
# 156  6c5cc19a-d6d0-49b6-b3c3-754a5683e297        81     CPY 4          2
#
#                      timestamp  speed_reading
# 155 2024-01-01 08:58:32.506755          150.0
# 156 2024-01-01 08:58:35.011774          116.2
#
# [INFO] Publishing batch #82 (1 records)...
# [INFO] Batch #82 sent. Sleeping 5s...
# [DATA] Batch #82:
#                                  event_id  batch_id car_plate  camera_id  \
# 157  f6b5533c-06c0-4e98-81f1-b0be8793f17a        82    WQ 611          2
#
#                      timestamp  speed_reading
# 157 2024-01-01 08:58:37.984152          128.3
#
# [INFO] Publishing batch #83 (1 records)...
# [INFO] Batch #83 sent. Sleeping 5s...
# [DATA] Batch #83:
#                                  event_id  batch_id car_plate  camera_id  \
# 158  29ecb5aa-d085-47b1-8160-2a3bb144419a        83    SAR 94          2
#
#                      timestamp  speed_reading
# 158 2024-01-01 08:58:54.632836           81.7
#
# [INFO] Publishing batch #84 (3 records)...
# [INFO] Batch #84 sent. Sleeping 5s...
# [DATA] Batch #84:
#                                  event_id  batch_id car_plate  camera_id  \
# 159  cf89c9fb-6558-4460-9da8-d95081c0328b        84     KR 45          2
# 160  f085b5f4-91f4-4275-9983-515c27eb4657        84   BSJ 003          2
# 161  24177364-c789-48d4-8d30-d89de2b3e076        84    BCR 89          2
#
#                      timestamp  speed_reading
# 159 2024-01-01 08:51:57.204299          147.1
# 160 2024-01-01 08:51:59.092319          141.6
# 161 2024-01-01 08:52:01.890382          120.3
#
# [INFO] Publishing batch #85 (1 records)...
# [INFO] Batch #85 sent. Sleeping 5s...
# [DATA] Batch #85:
#                                  event_id  batch_id car_plate  camera_id  \
# 162  48153b3a-e145-44b5-906d-4627706afc58        85      CH 7          2
#
#                      timestamp  speed_reading
# 162 2024-01-01 08:52:09.852561           96.3
#
# [INFO] Publishing batch #86 (1 records)...
# [INFO] Batch #86 sent. Sleeping 5s...
# [DATA] Batch #86:
#                                  event_id  batch_id car_plate  camera_id  \
# 163  c4771278-a990-4b9a-8240-68146a33bcf4        86     NGE 1          2
#
#                      timestamp  speed_reading
# 163 2024-01-01 08:52:18.452473           72.1
#
# [INFO] Publishing batch #87 (3 records)...
# [INFO] Batch #87 sent. Sleeping 5s...
# [DATA] Batch #87:
#                                  event_id  batch_id car_plate  camera_id  \
# 164  aeddfcfd-4aed-473f-9ed7-f41da5c9a5b3        87  CIF 7716          2
# 165  899a76a4-ee17-4430-a972-469cf34a8e07        87     OMI 8          2
# 166  a6245b99-25ae-456c-8fe6-e57aea7126b5        87   QZP 764          2
#
#                      timestamp  speed_reading
# 164 2024-01-01 08:58:30.019725          161.5
# 165 2024-01-01 08:58:33.857924          136.9
# 166 2024-01-01 08:58:34.300527          124.7
#
# [INFO] Publishing batch #88 (3 records)...
# [INFO] Batch #88 sent. Sleeping 5s...
# [DATA] Batch #88:
#                                  event_id  batch_id car_plate  camera_id  \
# 167  ad4755a9-e9d2-4dfa-8dea-fc05a27f3fdc        88   HC 7579          2
# 168  58346863-18ac-4ff9-aa93-2cf670c96f2f        88      BS 4          2
# 169  6da39c1c-2609-4b35-82a1-9c68604ff97a        88  RPR 3822          2
#
#                      timestamp  speed_reading
# 167 2024-01-01 08:58:35.466762          141.5
# 168 2024-01-01 08:58:35.710792          129.1
# 169 2024-01-01 08:58:36.803351          141.3
#
# [INFO] Publishing batch #89 (2 records)...
# [INFO] Batch #89 sent. Sleeping 5s...
# [DATA] Batch #89:
#                                  event_id  batch_id car_plate  camera_id  \
# 170  daa25061-c6fe-46ff-8736-4bc124947594        89     WPR 0          2
# 171  200aff1a-434b-4c48-b2bd-ee050e5513af        89      NO 7          2
#
#                      timestamp  speed_reading
# 170 2024-01-01 08:58:47.858942          102.2
# 171 2024-01-01 08:58:50.025495           87.9
#
# [INFO] Publishing batch #90 (3 records)...
# [INFO] Batch #90 sent. Sleeping 5s...
# [DATA] Batch #90:
#                                  event_id  batch_id car_plate  camera_id  \
# 172  09e73bc0-e9d8-462a-b078-74662035565a        90  SGH 2689          2
# 173  7174581a-ff50-494f-9988-b08644e85210        90    AWP 66          2
# 174  d53001a3-8ce5-499d-b72c-97c68c328c15        90      KO 9          2
#
#                      timestamp  speed_reading
# 172 2024-01-01 08:59:00.214551           68.5
# 173 2024-01-01 08:59:02.337899           71.8
# 174 2024-01-01 08:59:04.586809           63.6
#
# [INFO] Publishing batch #91 (4 records)...
# [INFO] Batch #91 sent. Sleeping 5s...
# [DATA] Batch #91:
#                                  event_id  batch_id car_plate  camera_id  \
# 175  98208ed9-8dc8-4c37-b6ab-5062f1d70d79        91      QA 8          2
# 176  bd5f3529-194e-451b-96d8-b69f341836aa        91   GW 8232          2
# 177  f95c8696-c3af-4c0a-a82d-b0af66d9216b        91      WB 4          2
# 178  7c5552ef-e324-47e0-acff-73f89257b9f2        91      DN 1          2
#
#                      timestamp  speed_reading
# 175 2024-01-01 09:07:28.183937          141.8
# 176 2024-01-01 09:07:28.325272          162.3
# 177 2024-01-01 09:07:29.437247          149.9
# 178 2024-01-01 09:07:31.462496          146.6
#
# [INFO] Publishing batch #92 (1 records)...
# [INFO] Batch #92 sent. Sleeping 5s...
# [DATA] Batch #92:
#                                  event_id  batch_id car_plate  camera_id  \
# 179  c8685f38-0e35-48fe-b693-1069bec7f559        92   THE 567          2
#
#                      timestamp  speed_reading
# 179 2024-01-01 09:07:38.791013          110.9
#
# [INFO] Publishing batch #93 (2 records)...
# [INFO] Batch #93 sent. Sleeping 5s...
# [DATA] Batch #93:
#                                  event_id  batch_id car_plate  camera_id  \
# 180  6a711862-dfb9-4018-b645-9b7fae5cd869        93   WVU 913          2
# 181  33b28af9-b8e3-4edc-a11d-6c33ff8db568        93   GK 2663          2
#
#                      timestamp  speed_reading
# 180 2024-01-01 09:07:47.600651           85.6
# 181 2024-01-01 09:07:50.005368           79.1
#
# [INFO] Publishing batch #94 (2 records)...
# [INFO] Batch #94 sent. Sleeping 5s...
# [DATA] Batch #94:
#                                  event_id  batch_id car_plate  camera_id  \
# 182  11ebff0c-5263-43dc-bedb-8c9cbe34016c        94    UUM 52          2
# 183  8308c91d-2113-4bb4-844c-5bc5c0bfc11d        94     HXU 9          2
#
#                      timestamp  speed_reading
# 182 2024-01-01 08:58:35.642155          161.7
# 183 2024-01-01 08:58:37.538069          134.8
#
# [INFO] Publishing batch #95 (2 records)...
# [INFO] Batch #95 sent. Sleeping 5s...
# [DATA] Batch #95:
#                                  event_id  batch_id car_plate  camera_id  \
# 184  32424ccb-7ae7-4527-b34c-f863f4b4a0b0        95     XAX 4          2
# 185  d18249a5-5e97-4f50-98c8-19d683e93049        95      PA 6          2
#
#                      timestamp  speed_reading
# 184 2024-01-01 08:58:44.104114          105.3
# 185 2024-01-01 08:58:44.615706           98.9
#
# [INFO] Publishing batch #96 (1 records)...
# [INFO] Batch #96 sent. Sleeping 5s...
# [DATA] Batch #96:
#                                  event_id  batch_id car_plate  camera_id  \
# 186  6472349a-6626-4ea8-8ec3-17842e5a696d        96   MHH 217          2
#
#                      timestamp  speed_reading
# 186 2024-01-01 08:58:49.530892           92.9
#
# [INFO] Publishing batch #97 (2 records)...
# [INFO] Batch #97 sent. Sleeping 5s...
# [DATA] Batch #97:
#                                  event_id  batch_id car_plate  camera_id  \
# 187  0fc00039-83e8-47e4-abb0-eec4abd8260a        97    NA 632          2
# 188  e9cdb600-ca00-416a-b6a6-2b24dd450cd8        97    AIX 51          2
#
#                      timestamp  speed_reading
# 187 2024-01-01 09:07:28.230502          160.0
# 188 2024-01-01 09:07:29.619195          140.6
#
# [INFO] Publishing batch #98 (2 records)...
# [INFO] Batch #98 sent. Sleeping 5s...
# [DATA] Batch #98:
#                                  event_id  batch_id car_plate  camera_id  \
# 189  08cd653b-a8a7-4d26-8eac-f55e8350d84d        98      MY 4          2
# 190  36bdca78-323e-4769-8479-e6abba3c4e93        98     HJQ 8          2
#
#                      timestamp  speed_reading
# 189 2024-01-01 09:07:38.127535          107.6
# 190 2024-01-01 09:07:42.016216          116.8
#
# [INFO] Publishing batch #99 (3 records)...
# [INFO] Batch #99 sent. Sleeping 5s...
# [DATA] Batch #99:
#                                  event_id  batch_id car_plate  camera_id  \
# 191  c51eccaa-eaff-4b76-ad52-d74d1edb9c61        99    HGQ 06          2
# 192  9e0392dd-9d8e-40f5-8b0d-9659f31d2318        99    WCI 74          2
# 193  efb050ed-0137-4b1f-9101-d3391dd5c1cd        99     WLD 5          2
#
#                      timestamp  speed_reading
# 191 2024-01-01 09:07:48.019325           91.3
# 192 2024-01-01 09:07:48.537994           83.5
# 193 2024-01-01 09:07:52.198145           75.8
#
# [INFO] Publishing batch #100 (2 records)...
# [INFO] Batch #100 sent. Sleeping 5s...
# [DATA] Batch #100:
#                                  event_id  batch_id car_plate  camera_id  \
# 194  8c0999b8-53a6-449b-9e64-70be3ba96fd2       100     XO 39          2
# 195  dbc3f69e-7193-426d-a3ca-f37fec9080cd       100   EHQ 563          2
#
#                      timestamp  speed_reading
# 194 2024-01-01 09:15:15.462313          145.0
# 195 2024-01-01 09:15:17.297747          128.2
#
# [INFO] Publishing batch #101 (1 records)...
# [INFO] Batch #101 sent. Sleeping 5s...
# [DATA] Batch #101:
#                                  event_id  batch_id car_plate  camera_id  \
# 196  9772b632-5c82-4f79-8916-5d2c271300f8       101    AB 114          2
#
#                      timestamp  speed_reading
# 196 2024-01-01 09:15:20.567884          129.7
#
# [INFO] Publishing batch #102 (1 records)...
# [INFO] Batch #102 sent. Sleeping 5s...
# [DATA] Batch #102:
#                                  event_id  batch_id car_plate  camera_id  \
# 197  fb2352ae-7bb2-49ea-913a-7d1a30910463       102   WQ 2511          2
#
#                      timestamp  speed_reading
# 197 2024-01-01 09:15:26.086806          101.7
#
# [INFO] Publishing batch #103 (1 records)...
# [INFO] Batch #103 sent. Sleeping 5s...
# [DATA] Batch #103:
#                                  event_id  batch_id car_plate  camera_id  \
# 198  20a5de61-7c28-4e27-b5b7-a8877a0ff4a1       103     EJR 0          2
#
#                      timestamp  speed_reading
# 198 2024-01-01 09:15:31.278062           94.8
#
# [INFO] Publishing batch #104 (1 records)...
# [INFO] Batch #104 sent. Sleeping 5s...
# [DATA] Batch #104:
#                                  event_id  batch_id car_plate  camera_id  \
# 199  3efc1be9-6f92-457d-aa0e-0853d795587a       104    DQQ 13          2
#
#                      timestamp  speed_reading
# 199 2024-01-01 09:15:49.899839           64.0
#
# ...
#
#                      timestamp  speed_reading
# 442 2024-01-01 10:44:04.920162          113.4
# 443 2024-01-01 10:44:05.630999          111.5
# 444 2024-01-01 10:44:06.877157          113.7
#
# [INFO] Publishing batch #228 (1 records)...
# [INFO] Batch #228 sent. Sleeping 5s...
# [DATA] Batch #228:
#                                  event_id  batch_id car_plate  camera_id  \
# 445  c83faae6-36e2-4b78-ba01-db637e9963ef       228     NWJ 9          2
#
#                      timestamp  speed_reading
# 445 2024-01-01 10:44:10.843070           87.6
#
# [INFO] Publishing batch #229 (1 records)...
# [INFO] Batch #229 sent. Sleeping 5s...
# [DATA] Batch #229:
#                                  event_id  batch_id car_plate  camera_id  \
# 446  f97ed943-bcd6-4f52-a663-a02dc4110463       229   QH 4901          2
#
#                      timestamp  speed_reading
# 446 2024-01-01 10:44:22.729728           76.0
#
# [INFO] Publishing batch #230 (1 records)...
# [INFO] Batch #230 sent. Sleeping 5s...
# [DATA] Batch #230:
#                                  event_id  batch_id car_plate  camera_id  \
# 447  fb90c3ba-842b-4a7f-bae7-3cc0836a20aa       230   PQP 642          2
#
#                      timestamp  speed_reading
# 447 2024-01-01 10:44:33.726947           61.7
#
# [INFO] Publishing batch #231 (4 records)...
# [INFO] Batch #231 sent. Sleeping 5s...
# [DATA] Batch #231:
#                                  event_id  batch_id car_plate  camera_id  \
# 448  a9447283-ea83-4c3f-81ea-ff26d279cb85       231  AGC 9507          2
# 449  df0ac92f-c7a5-46df-a596-454412f565f0       231   AZ 4838          2
# 450  250299d8-a6e5-4627-9fff-6689e50ae5ce       231   TJ 7956          2
# 451  c02ad691-d56f-4a0c-876c-ddda8dc76234       231     ZC 78          2
#
#                      timestamp  speed_reading
# 448 2024-01-01 10:50:35.523700          142.1
# 449 2024-01-01 10:50:38.772365          135.4
# 450 2024-01-01 10:50:39.763960          130.5
# 451 2024-01-01 10:50:40.014807          162.2
#
# [INFO] Publishing batch #232 (3 records)...
# [INFO] Batch #232 sent. Sleeping 5s...
# [DATA] Batch #232:
#                                  event_id  batch_id car_plate  camera_id  \
# 452  fbbbafd3-4f7e-4f07-ab9f-3d99cafb6e07       232   TWE 048          2
# 453  f09c58dd-1441-419d-bc6e-064320ebcd5c       232   RF 9266          2
# 454  bc3fbf68-01da-4bc1-94f7-457f4de982a5       232     KM 88          2
#
#                      timestamp  speed_reading
# 452 2024-01-01 10:50:44.359150          120.6
# 453 2024-01-01 10:50:45.775945          106.5
# 454 2024-01-01 10:50:48.048405          108.6
#
# [INFO] Publishing batch #233 (1 records)...
# [INFO] Batch #233 sent. Sleeping 5s...
# [DATA] Batch #233:
#                                  event_id  batch_id car_plate  camera_id  \
# 455  4f66926d-659e-4dd1-aaca-b3792381a92b       233   RE 6923          2
#
#                      timestamp  speed_reading
# 455 2024-01-01 10:50:54.948009           87.0
#
# [INFO] Publishing batch #234 (5 records)...
# [INFO] Batch #234 sent. Sleeping 5s...
# [DATA] Batch #234:
#                                  event_id  batch_id car_plate  camera_id  \
# 456  4a18d6a2-9716-4f0b-8482-ee96fd976671       234    CV 321          2
# 457  ea37af51-0eac-4deb-b386-9c1751b0d640       234     OQ 78          2
# 458  5b70d7af-0afa-4bc4-a583-2b9be887ed5f       234      XG 7          2
# 459  361c7b81-d5da-4d52-8287-b147e1c54106       234      MO 1          2
# 460  ccd7bde8-630a-487e-991f-a3356afa53d8       234    JC 953          2
#
#                      timestamp  speed_reading
# 456 2024-01-01 10:59:01.017638          133.8
# 457 2024-01-01 10:59:03.995042          118.5
# 458 2024-01-01 10:59:04.401044          105.3
# 459 2024-01-01 10:59:05.502102          114.1
# 460 2024-01-01 10:59:05.894421          106.4
#
# [INFO] Publishing batch #235 (2 records)...
# [INFO] Batch #235 sent. Sleeping 5s...
# [DATA] Batch #235:
#                                  event_id  batch_id car_plate  camera_id  \
# 461  a4722dad-bc75-4dfb-9c3b-d99ed512a558       235     BI 56          2
# 462  866afac3-0d7a-4ae1-87f3-36676098a466       235    GE 248          2
#
#                      timestamp  speed_reading
# 461 2024-01-01 10:59:08.602615           95.5
# 462 2024-01-01 10:59:11.064002           95.3
#
# [INFO] Publishing batch #236 (2 records)...
# [INFO] Batch #236 sent. Sleeping 5s...
# [DATA] Batch #236:
#                                  event_id  batch_id car_plate  camera_id  \
# 463  220bc4c7-53ab-4d7c-b7c0-a85d0a5a5559       236    GA 596          2
# 464  7f072c07-5b76-4ae9-85cb-98903d2fa339       236     SS 78          2
#
#                      timestamp  speed_reading
# 463 2024-01-01 10:59:14.036138           90.1
# 464 2024-01-01 10:59:16.865645           82.9
#
# [INFO] Publishing batch #237 (2 records)...
# [INFO] Batch #237 sent. Sleeping 5s...
# [DATA] Batch #237:
#                                  event_id  batch_id car_plate  camera_id  \
# 465  6c6404a1-7af6-42f6-8364-23f76ef95632       237     VQ 75          2
# 466  dab11615-cc85-4304-877a-9db6b98c30b9       237   QF 7428          2
#
#                      timestamp  speed_reading
# 465 2024-01-01 10:59:25.402586           76.6
# 466 2024-01-01 10:59:25.838244           72.9
#
# [INFO] Publishing batch #238 (2 records)...
# [INFO] Batch #238 sent. Sleeping 5s...
# [DATA] Batch #238:
#                                  event_id  batch_id car_plate  camera_id  \
# 467  f55933fd-24ec-441a-8913-d778d0a78cec       238     RHC 5          2
# 468  74ccef1a-bb33-4253-bc75-974e7d40c961       238      NK 5          2
#
#                      timestamp  speed_reading
# 467 2024-01-01 10:50:39.832816          133.8
# 468 2024-01-01 10:50:42.784289          124.6
#
# [INFO] Publishing batch #239 (2 records)...
# [INFO] Batch #239 sent. Sleeping 5s...
# [DATA] Batch #239:
#                                  event_id  batch_id car_plate  camera_id  \
# 469  12a45668-61a2-49ff-ab3f-134a24944e44       239   IN 3520          2
# 470  92ca67f3-d89f-4f96-b225-3c58d980451a       239    CD 874          2
#
#                      timestamp  speed_reading
# 469 2024-01-01 10:51:06.968400           73.4
# 470 2024-01-01 10:51:11.590167           62.0
#
# [INFO] Publishing batch #240 (2 records)...
# [INFO] Batch #240 sent. Sleeping 5s...
# [DATA] Batch #240:
#                                  event_id  batch_id car_plate  camera_id  \
# 471  855e9322-43a9-46fb-9ae5-0d2fc3c15628       240     ZDJ 6          2
# 472  10d9632e-c5fb-4f99-a35c-b7a8583b8b4d       240  JDY 0286          2
#
#                      timestamp  speed_reading
# 471 2024-01-01 10:58:55.795427          150.8
# 472 2024-01-01 10:58:57.644965          155.9
#
# [INFO] Publishing batch #241 (4 records)...
# [INFO] Batch #241 sent. Sleeping 5s...
# [DATA] Batch #241:
#                                  event_id  batch_id car_plate  camera_id  \
# 473  7f940782-d8d2-4c05-9ffb-1f5b977b8742       241   NT 5127          2
# 474  466c6533-c028-487f-adbf-551363f4418c       241     PT 56          2
# 475  14695a36-a01d-4989-a258-04ab3b585115       241     DDS 5          2
# 476  f1f5ee5c-5c66-4415-82cf-ae38391db9ab       241    DY 990          2
#
#                      timestamp  speed_reading
# 473 2024-01-01 10:59:01.047893          124.5
# 474 2024-01-01 10:59:01.178649          117.1
# 475 2024-01-01 10:59:01.799438          130.3
# 476 2024-01-01 10:59:04.576496          117.3
#
# [INFO] Publishing batch #242 (1 records)...
# [INFO] Batch #242 sent. Sleeping 5s...
# [DATA] Batch #242:
#                                  event_id  batch_id car_plate  camera_id  \
# 477  ba6a8c6d-1ac5-4dea-a06b-4264f1878480       242   VZH 493          2
#
#                      timestamp  speed_reading
# 477 2024-01-01 10:59:08.079851          100.0
#
# [INFO] Publishing batch #243 (2 records)...
# [INFO] Batch #243 sent. Sleeping 5s...
# [DATA] Batch #243:
#                                  event_id  batch_id car_plate  camera_id  \
# 478  cb5a44c7-451a-427f-b2f0-790a6c42ccde       243    VND 07          2
# 479  2caabf38-b58d-42d5-acef-09a12b70ee31       243      MO 2          2
#
#                      timestamp  speed_reading
# 478 2024-01-01 11:06:54.937302          157.1
# 479 2024-01-01 11:06:57.450042          131.7
#
# [INFO] Publishing batch #244 (3 records)...
# [INFO] Batch #244 sent. Sleeping 5s...
# [DATA] Batch #244:
#                                  event_id  batch_id car_plate  camera_id  \
# 480  19b942a8-b286-4033-b1ad-b6b3ff5faad7       244   ZO 1603          2
# 481  7cc4d3ff-1145-42b3-98a8-235a01d07954       244    KT 360          2
# 482  96d0c5d5-b9da-463e-ba26-70c6e75c2c65       244      XA 4          2
#
#                      timestamp  speed_reading
# 480 2024-01-01 11:07:01.776203          105.0
# 481 2024-01-01 11:07:03.871561           96.6
# 482 2024-01-01 11:07:05.657641           96.4
#
# [INFO] Publishing batch #245 (1 records)...
# [INFO] Batch #245 sent. Sleeping 5s...
# [DATA] Batch #245:
#                                  event_id  batch_id car_plate  camera_id  \
# 483  edc13e24-f7ee-4f39-9acd-75e8ca6a02ff       245     DJL 1          2
#
#                      timestamp  speed_reading
# 483 2024-01-01 11:07:17.882908           68.9
#
# [INFO] Publishing batch #246 (1 records)...
# [INFO] Batch #246 sent. Sleeping 5s...
# [DATA] Batch #246:
#                                  event_id  batch_id car_plate  camera_id  \
# 484  06bfbbee-81df-40ac-ae7a-4cfd9bbd2327       246   NA 7659          2
#
#                      timestamp  speed_reading
# 484 2024-01-01 10:59:09.634283          102.3
#
# [INFO] Publishing batch #247 (1 records)...
# [INFO] Batch #247 sent. Sleeping 5s...
# [DATA] Batch #247:
#                                  event_id  batch_id car_plate  camera_id  \
# 485  5be01285-8308-4d43-8601-0be102f8f886       247    CLJ 52          2
#
#                      timestamp  speed_reading
# 485 2024-01-01 10:59:28.114287           65.4
#
# [INFO] Publishing batch #248 (1 records)...
# [INFO] Batch #248 sent. Sleeping 5s...
# [DATA] Batch #248:
#                                  event_id  batch_id car_plate  camera_id  \
# 486  4415754e-650b-48cd-9c79-14999cdcee9c       248     NKM 8          2
#
#                      timestamp  speed_reading
# 486 2024-01-01 11:07:13.429231           78.5
#
# [INFO] Publishing batch #249 (1 records)...
# [INFO] Batch #249 sent. Sleeping 5s...
# [DATA] Batch #249:
#                                  event_id  batch_id car_plate  camera_id  \
# 487  1105f661-3438-47b0-98ca-6abd8e776f23       249    PC 958          2
#
#                      timestamp  speed_reading
# 487 2024-01-01 11:13:33.748231          140.4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 batch_interval=5
#       8 producer = kafkaProducer(csv_path, kafka_server, producer_id, topic, batch_interval)
# ----> 9 producer.produce_batches()
#
# File ~/util.py:88, in kafkaProducer.produce_batches(self)
#      86     print(f"[INFO] Batch #{batch_id} sent. Sleeping {self.batch_interval}s...")
#      87     print(f"[DATA] Batch #{batch_id}:\n{batch_df}\n")
# ---> 88     time.sleep(self.batch_interval)
#      90 # Loop has finished
#      91 self.producer.flush()
#
# KeyboardInterrupt:
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
# Node 1 connection failed -- refreshing metadata
