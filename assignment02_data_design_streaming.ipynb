# %% [markdown]
# ### Importing camera.csv data into Camera

# %%
import pymongo
from pymongo import MongoClient
import csv

# ── Your starter connection ──
client = MongoClient("172.22.32.1", 27017) 
db = client.fit3182_db
camera_coll = db.Camera

# ── Skip if already imported ──
if camera_coll.estimated_document_count() > 0:
    print("Camera collection already contains data. Skipping import.")
else:
    idx_name = camera_coll.create_index(
        [("pos", pymongo.ASCENDING)],
        name="pos_idx"
    )
    print(f"Ensured index on 'pos': {idx_name}")
    
    # ── Load CSV and insert ──
    csv_path = 'data/camera.csv'
    docs = []
    with open(csv_path, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            docs.append({
                "_id":        int(row['camera_id']),
                "lat":        float(row['latitude']),
                "long":       float(row['longitude']),
                "pos":        float(row['position']),
                "speed_limit": int(row['speed_limit'])
            })

    if docs:
        result = camera_coll.insert_many(docs)
        print(f"Inserted {len(result.inserted_ids)} camera documents.")
        print("Current indexes on Camera:")
        for name, info in camera_coll.index_information().items():
            print(f" • {name}: {info['key']}")
    else:
        print("No camera records found in CSV.")
# Out:
# Camera collection already contains data. Skipping import.

# %% [markdown]
# ### Importing vehicle.csv data into Vehicle

# %%
import csv
from datetime import datetime
from pymongo import MongoClient

# ── Connection ──
client = MongoClient("172.22.32.1", 27017)
db = client.fit3182_db
vehicle_coll = db.Vehicle

if vehicle_coll.estimated_document_count() > 0:
    print("Vehicle collection already contains data. Skipping import.")
else:
    # ── Prepare sets & counters ──
    existing_ids = set(vehicle_coll.distinct('_id'))
    seen_in_file = set()
    docs_to_insert = []
    update_count = 0
    added_count = 0

    csv_path = 'data/vehicle.csv'
    with open(csv_path, newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            plate = row['car_plate']

            # Parse the incoming registration_date
            ts = row['registration_date'].rstrip("Z")
            reg_date = datetime.fromisoformat(ts)

            if plate in seen_in_file:
    #             print("Found duplicate:")
                # Plate already in DB → check whether to update
                existing = vehicle_coll.find_one(
                    {"_id": plate}
                )
    #             print(existing)
                if existing and reg_date > existing['registration_date']:
    #                 print("Registration is newer, updating...")
                    # Only update if the CSV date is newer
                    vehicle_coll.update_one(
                        {"_id": plate},
                        {"$set": {
                            "registration_date": reg_date,
                            "owner_name":        row['owner_name'],
                            "owner_addr":        row['owner_addr'],
                            "vehicle_type":      row['vehicle_type']
                        }}
                    )
                    update_count += 1
            else:
                seen_in_file.add(plate)
                # Brand-new plate → schedule for insert
                vehicle_coll.insert_one({
                    "_id":               plate,
                    "owner_name":        row['owner_name'],
                    "owner_addr":        row['owner_addr'],
                    "vehicle_type":      row['vehicle_type'],
                    "registration_date": reg_date
                })
                added_count += 1

    # ── Do the batch insert, if any ──
    if added_count > 0:
        print(f"Inserted {added_count} new vehicle documents.")
    else:
        print("No new vehicle records to insert.")

    # ── Report on any updates we made ──
    if update_count:
        print(f"Updated {update_count} existing vehicle document{'s' if update_count>1 else ''}.")

    # ── (Optional) show your indexes ──
    print("Current indexes on Vehicle:")
    for name, info in vehicle_coll.index_information().items():
        print(f" • {name}: {info['key']}")
# Out:
# Vehicle collection already contains data. Skipping import.

# %% [markdown]
# ### Data Design and Streaming using Apache Structured Streaming

# %%
import os
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-streaming-kafka-0-10_2.12:3.3.0,org.apache.spark:spark-sql-kafka-0-10_2.12:3.3.0,org.mongodb.spark:mongo-spark-connector_2.12:10.1.1 pyspark-shell'
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, element_at, when

from pyspark.sql.types import (
    StructType, StringType, IntegerType, DoubleType, TimestampType
)
from pyspark.sql.functions import (
    col, expr, from_json
)
import uuid

# %%
topic_name = 'camera_events'
hostip = "172.22.32.1" # change it to your IP

# %%
spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('Apache Spark Structured Streaming from Kafka for Violation Detection')
    .getOrCreate()
)

# %%
eventSchema = StructType() \
    .add("batch_id", IntegerType()) \
    .add("event_id", StringType()) \
    .add("car_plate", StringType()) \
    .add("camera_id", IntegerType()) \
    .add("timestamp", TimestampType()) \
    .add("speed_reading", DoubleType()) \
    .add("producer", StringType()) \
    .add("sent_at", TimestampType())

def read_camera_stream(suffix: str):
    return (
        spark.readStream
             .format("kafka")
             .option("kafka.bootstrap.servers", f"{hostip}:9092")
             .option("subscribe", f"{topic_name}_{suffix}")
             .load()
             .selectExpr("CAST(value AS STRING) as json")
             .select(from_json(col("json"), eventSchema).alias("data"))
             .select("data.*")
             # watermark on the event time to purge old state
             .withWatermark("sent_at", "10 minute")
    )

# %%
streamA = read_camera_stream("a")
streamB = read_camera_stream("b")
streamC = read_camera_stream("c")

A_vm = streamA.alias("A")
B_vm = streamB.alias("B")
C_vm = streamC.alias("C")

# %%
AB = A_vm.join(
    B_vm,
    on=[
        col("A.car_plate")==col("B.car_plate"),
        col("B.sent_at") >= col("A.sent_at") - expr("INTERVAL 300 SECONDS"),
        col("B.sent_at") <= col("A.sent_at") + expr("INTERVAL 300 SECONDS")
      ],
    how="inner"
).filter(
    (col("B.timestamp")  > col("A.timestamp"))
).select(
    # you can pick whichever columns you need downstream
    col("A.*"), 
    col("B.camera_id").alias("camera_id_B"),
    col("B.car_plate").alias("car_plate_B"),
    col("B.timestamp").alias("timestamp_B"),
    col("B.speed_reading").alias("speed_reading_B")
).alias("AB")

ABC = AB.join(
    C_vm,
    on=[
        col("AB.car_plate")==col("C.car_plate"),
        col("C.sent_at") >= col("AB.sent_at") - expr("INTERVAL 300 SECONDS"),
        col("C.sent_at") <= col("AB.sent_at") + expr("INTERVAL 300 SECONDS")
      ],
    how="inner"
).filter(
    (col("C.timestamp")  > col("AB.timestamp_B"))
).select(
    col("AB.*"), 
    col("C.camera_id").alias("camera_id_C"),
    col("C.car_plate").alias("car_plate_C"),
    col("C.timestamp").alias("timestamp_C"),
    col("C.speed_reading").alias("speed_reading_C")
).alias("ABC")

# %%
# for debugging, print on console
class ConsoleWriter:
    def open(self, partition_id, epoch_id):
        self.mongo_client = MongoClient(
            host=f'{hostip}',
            port=27017
        )
        self.db = self.mongo_client['fit3182_db']
        self.camera_coll = self.db.Camera
        return True
    
    def process(self, row):
        data = row.asDict()
        print(f"\ncurrent data: {data}")
#         currentCameraData = self.camera_coll.find_one(
#                     {"_id": data["camera_id"]}
#                 )
#         print(f'current camera: {currentCameraData["_id"]}')
#         if float(currentCameraData["speed_limit"]) < float(data["speed_reading"]):
#             print(f"instant speed violated: {currentCameraData['speed_limit']} vs {data['speed_reading']}")
# #             self.db["Violation"].insert_one(self.createJsonSchema(data)) 
#             print(f"Generated schema: {self.createJsonSchema(data, currentCameraData['speed_limit'])}")
        
    # called once all rows have been processed (possibly with error)
    def close(self, err):
        self.mongo_client.close()
        
    def createJsonSchema(self, data, speed_limit):
        # parse timestamp into a datetime if needed
        ts = data["timestamp"]
        if isinstance(ts, str):
            ts = datetime.fromisoformat(ts)

        # compute the “date” bucket = midnight on that day
        date_bucket = datetime(ts.year, ts.month, ts.day)

        # build the single-infraction subdoc
        violation = {
            "type":             "instantaneous",
            "camera_id_start":  data["camera_id"],
            "camera_id_end":    None,
            "timestamp_start":  ts,
            "timestamp_end":    None,
            "measured_speed":   float(data["speed_reading"]),
            "speed_limit":      float(speed_limit)
        }

        return {
            "violation_id": str(uuid.uuid4()),  # or f"{data['car_plate']}_{date_bucket.date()}"
            "car_plate":    data["car_plate"],
            "date":         date_bucket,
            "violations":   [violation]
        }

# %%
class DbWriter:
    def open(self, partition_id, epoch_id):
        self.mongo_client = MongoClient(
            host=f'{hostip}',
            port=27017
        )
        self.db = self.mongo_client['fit3182_db']
        self.camera_coll = self.db.Camera
        self.violation_coll = self.db.Violation
        return True
    
    def process(self, row):
        data = row.asDict()
        currentCameraData = self.camera_coll.find_one(
                    {"_id": data["camera_id"]}
                )
        if float(currentCameraData["speed_limit"]) < float(data["speed_reading"]):
            self.addViolation(data, currentCameraData["speed_limit"])
        
    # called once all rows have been processed (possibly with error)
    def close(self, err):
        self.mongo_client.close()
        
    def addViolation(self, data, speed_limit):
        # parse timestamp into a datetime if needed
        ts = data["timestamp"]
        if isinstance(ts, str):
            ts = datetime.fromisoformat(ts)

        # compute the “date” bucket = midnight on that day
        date_bucket = datetime(ts.year, ts.month, ts.day)

        # build the single-infraction subdoc
        violation = {
            "type":             "instantaneous",
            "camera_id_start":  data["camera_id"],
            "camera_id_end":    None,
            "timestamp_start":  ts,
            "timestamp_end":    None,
            "measured_speed":   float(data["speed_reading"]),
            "speed_limit":      float(speed_limit)
        }
        
        existing = self.violation_coll.find_one(
                    {"car_plate": data["car_plate"], "date": date_bucket}
                )
        
        if existing:
            print(existing)
            originalViolations = existing["violations"]
            originalViolations.append(violation)
            self.violation_coll.update_one(
                        {"car_plate": data["car_plate"], "date": date_bucket},
                        {"$set": {
                            "violations": originalViolations,
                        }}
                    )
            print(f"added violation to carplate {data['car_plate']} at {date_bucket}")
        else:
            self.violation_coll.insert_one(
                    {
                    "violation_id": str(uuid.uuid4()),  # or f"{data['car_plate']}_{date_bucket.date()}"
                    "car_plate":    data["car_plate"],
                    "date":         date_bucket,
                    "violations":   [violation]
                }
            )

# %%
writer_stream = (
    ABC.writeStream.format("Console")
    .option("checkpointLocation", "./stream_checkpoints_3")
    .outputMode('append').foreach(ConsoleWriter())
)
# writer_stream = (
#     ABC.writeStream.format("Console")
#     .option("checkpointLocation", "./streamA_checkpoints")
#     .outputMode('append').foreach(DbWriter())
# )

# %%
try:
    query = writer_stream.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopped query')
except StreamingQueryException as exc:
    print(exc)
finally:
    query.stop()

# %% [markdown]
# ### Consumer stuff

# %%
from kafka3 import KafkaConsumer
import datetime as dt
from json import loads
import statistics
import matplotlib.pyplot as plt
import statistics

topic = 'camera_events'
hostip = "172.22.32.1" # change it to your IP

def connect_kafka_consumer():
    _consumer = None
    try:
         _consumer = KafkaConsumer(topic,
                                   # consumer_timeout_ms=10000, # stop iteration if no message after 10 sec
                                   auto_offset_reset='earliest', # comment this if you don't want to consume earliest available message
                                   bootstrap_servers=[f'{hostip}:9092'],
                                   value_deserializer=lambda x: loads(x.decode('ascii')),
                                   api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka')
        print(str(ex))
    finally:
        return _consumer

def consume_messages(consumer):
    try:
        # container for x and y values
        # x4 and y4 holds the average values
        firstIteration = True
        print(consumer)
        # print('Waiting for messages')
        for message in consumer:
            message = message.value
            print(message)
    except Exception as ex:
        print(str(ex))
    
if __name__ == '__main__':
    consumer = connect_kafka_consumer()
    consume_messages(consumer)
# Out:
# WARNING:kafka3.coordinator.consumer:group_id is None: disabling auto-commit.
# <kafka3.consumer.group.KafkaConsumer object at 0x7f9ecffa56a0>
# {'event_id': 'd40c586c-5be6-4743-a1e3-2269d9edaa72', 'batch_id': 1, 'car_plate': 'KRN 7', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 77.2, 'producer': 'A'}
# {'event_id': '85c08e3c-a0b5-45d8-a70c-df8f9a6d5829', 'batch_id': 1, 'car_plate': 'ICE 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 103.7, 'producer': 'A'}
# {'event_id': 'f5834b79-771b-4931-8da2-a5ad7f4ccd02', 'batch_id': 1, 'car_plate': 'QE 1820', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 67.4, 'producer': 'A'}
# {'event_id': 'd0e547bb-c4a7-4750-b7b4-8076e9b47f4f', 'batch_id': 1, 'car_plate': 'CJW 924', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 148.3, 'producer': 'A'}
# {'event_id': 'f3162606-1b2e-407f-951d-61d14c0a7b09', 'batch_id': 1, 'car_plate': 'CJP 278', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:02', 'speed_reading': 125.2, 'producer': 'A'}
# {'event_id': 'c69852f7-cd9a-4892-b225-8f8a36ec017b', 'batch_id': 1, 'car_plate': 'ZPG 90', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 95.7, 'producer': 'A'}
# {'event_id': '5113d990-4da6-41d2-b292-2516e7d8dc07', 'batch_id': 1, 'car_plate': 'KKE 15', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:00', 'speed_reading': 150.3, 'producer': 'A'}
# {'event_id': '67ce0672-95b5-43bd-9940-2e16db5f747a', 'batch_id': 1, 'car_plate': 'WJX 2', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 97.4, 'producer': 'A'}
# {'event_id': '7c5c112b-7521-4bbc-90f8-3c3a85cc3fe1', 'batch_id': 1, 'car_plate': 'FO 32', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 99.7, 'producer': 'A'}
# {'event_id': '213f0627-2be4-409c-972b-669627ca0461', 'batch_id': 1, 'car_plate': 'FA 35', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 81.7, 'producer': 'A'}
# {'event_id': '5a4497c9-5e3b-4470-a20c-8ee1f619f732', 'batch_id': 1, 'car_plate': 'CZ 592', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:02', 'speed_reading': 154.9, 'producer': 'A'}
# {'event_id': 'b57e8e44-b6e5-4c1e-bb5b-a4e1bd24bac9', 'batch_id': 1, 'car_plate': 'UTT 229', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:00', 'speed_reading': 140.9, 'producer': 'A'}
# {'event_id': 'c6965fdc-07df-4008-a8d3-f60febcd9223', 'batch_id': 1, 'car_plate': 'AH 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 159.5, 'producer': 'A'}
# {'event_id': '3306546c-d263-43f2-9d8c-87732e1e0e99', 'batch_id': 1, 'car_plate': 'CX 6145', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 105.0, 'producer': 'A'}
# {'event_id': 'f108727e-e97d-4d8e-b109-e7e763b64398', 'batch_id': 1, 'car_plate': 'FZ 766', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 132.9, 'producer': 'A'}
# {'event_id': '7214629f-2fbb-4787-b953-e163720a6c61', 'batch_id': 1, 'car_plate': 'KZE 5', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 133.3, 'producer': 'A'}
# {'event_id': '3ca5e275-0cf6-43a0-8c28-65040c60b8b2', 'batch_id': 1, 'car_plate': 'HP 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 140.0, 'producer': 'A'}
# {'event_id': '562fee6c-d50b-4207-b2ea-e3b8a68f20f9', 'batch_id': 1, 'car_plate': 'WC 89', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 96.7, 'producer': 'A'}
# {'event_id': '25a3e2ad-502e-4273-9062-6f00ec63f62c', 'batch_id': 1, 'car_plate': 'EOT 00', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 142.6, 'producer': 'A'}
# {'event_id': '0abc5099-64d1-4b1a-b623-084b19ce9e4e', 'batch_id': 1, 'car_plate': 'WA 0712', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 142.1, 'producer': 'A'}
# {'event_id': 'be770f2f-e15a-463c-b4a7-955ee3e14924', 'batch_id': 2, 'car_plate': 'WB 418', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 148.7, 'producer': 'A'}
# {'event_id': '3930bb19-4837-4f01-a6b2-ce5757d1cc53', 'batch_id': 2, 'car_plate': 'QJ 53', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 82.6, 'producer': 'A'}
# {'event_id': '4b1633e2-8268-4c82-a509-7dfde90635aa', 'batch_id': 2, 'car_plate': 'EZ 6277', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 93.5, 'producer': 'A'}
# {'event_id': 'd1fcb87d-b48c-43ea-9697-8e6ee3b83cf7', 'batch_id': 2, 'car_plate': 'PI 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 154.0, 'producer': 'A'}
# {'event_id': '59e37658-17a9-41e6-8fd1-e65af3e271f9', 'batch_id': 2, 'car_plate': 'VWM 13', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 115.4, 'producer': 'A'}
# {'event_id': '013b5963-adc3-426b-b6f4-2c649aef7630', 'batch_id': 2, 'car_plate': 'VM 4837', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 104.7, 'producer': 'A'}
# {'event_id': '0352cb9f-fc86-4990-abf9-74cfbe287ec8', 'batch_id': 2, 'car_plate': 'JEJ 6', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:03', 'speed_reading': 117.6, 'producer': 'A'}
# {'event_id': '8017281b-a1a5-4d65-b0e4-7a522876d277', 'batch_id': 2, 'car_plate': 'UQV 232', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 154.4, 'producer': 'A'}
# {'event_id': 'be870773-5781-41b0-9d65-56383fa80385', 'batch_id': 2, 'car_plate': 'KV 17', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 86.7, 'producer': 'A'}
# {'event_id': 'abae5e9d-3d24-4e9a-b2cf-ab6915c397d7', 'batch_id': 2, 'car_plate': 'IFY 23', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:04', 'speed_reading': 107.8, 'producer': 'A'}
# {'event_id': '8449613c-fd13-4325-a030-4a1891d9aeaa', 'batch_id': 2, 'car_plate': 'DSD 320', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:06', 'speed_reading': 113.0, 'producer': 'A'}
# {'event_id': '5cb93acb-1b43-4370-98f9-a586086a2b22', 'batch_id': 2, 'car_plate': 'WPV 1456', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 78.1, 'producer': 'A'}
# {'event_id': '1e7c0e8d-5ebc-4869-9a0b-445c8e6d566e', 'batch_id': 2, 'car_plate': 'DWT 789', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 129.0, 'producer': 'A'}
# {'event_id': '6e662e88-2ece-46d5-b8f6-0c253b0c676a', 'batch_id': 2, 'car_plate': 'XYG 05', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:04', 'speed_reading': 114.2, 'producer': 'A'}
# {'event_id': '3a60cae5-3201-4d6f-8097-4db36725f3e5', 'batch_id': 2, 'car_plate': 'AJB 6689', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 64.1, 'producer': 'A'}
# {'event_id': 'a906d3ea-059c-4a12-932b-a42cb460fc68', 'batch_id': 2, 'car_plate': 'QZ 81', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:03', 'speed_reading': 60.5, 'producer': 'A'}
# {'event_id': 'a47e8660-36f5-4cdf-bc7d-b1d709c78974', 'batch_id': 2, 'car_plate': 'WZ 24', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 158.2, 'producer': 'A'}
# {'event_id': '04ca2c7e-47b6-4db2-8985-5348266f4cb6', 'batch_id': 2, 'car_plate': 'YRV 3', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 65.8, 'producer': 'A'}
# {'event_id': '701b86a2-5a29-4bc9-a078-d157fecc486c', 'batch_id': 2, 'car_plate': 'PKH 8115', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:03', 'speed_reading': 151.9, 'producer': 'A'}
# {'event_id': '41024bb3-3aa7-4ba6-817c-9dfac60e4b7c', 'batch_id': 2, 'car_plate': 'BS 03', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:06', 'speed_reading': 106.7, 'producer': 'A'}
# {'event_id': 'b05ac078-6f38-41f4-a126-a7616870029d', 'batch_id': 3, 'car_plate': 'CIY 810', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:08', 'speed_reading': 132.1, 'producer': 'A'}
# {'event_id': '8d513b56-0bf4-467c-add2-77381a36f231', 'batch_id': 3, 'car_plate': 'ARX 7573', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 121.2, 'producer': 'A'}
# {'event_id': '420c8cce-ca7d-48de-b99a-04dccf9d0b0b', 'batch_id': 3, 'car_plate': 'GI 029', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 60.8, 'producer': 'A'}
# {'event_id': '379c53ab-ab19-448e-833b-c894e90b8ace', 'batch_id': 3, 'car_plate': 'ZZ 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:08', 'speed_reading': 60.0, 'producer': 'A'}
# {'event_id': 'c14cd235-dd29-430d-8419-bd4e5e9c8b13', 'batch_id': 3, 'car_plate': 'ZQ 22', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 117.1, 'producer': 'A'}
# {'event_id': '833f950f-1108-47ea-acde-f3de4ebf7af2', 'batch_id': 3, 'car_plate': 'KWO 421', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 109.9, 'producer': 'A'}
# {'event_id': '82b14f5d-decc-47fa-925c-c63ca0862d8c', 'batch_id': 3, 'car_plate': 'VKZ 5377', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 78.0, 'producer': 'A'}
# {'event_id': '762873cc-b78d-4813-ba0f-19926f52f06d', 'batch_id': 3, 'car_plate': 'VJX 7', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 119.6, 'producer': 'A'}
# {'event_id': '5306eb46-4bee-4a8d-8800-ca93adfc499a', 'batch_id': 3, 'car_plate': 'ZV 2619', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 92.8, 'producer': 'A'}
# {'event_id': '32d8571e-be18-47c6-af6a-3dbc01061190', 'batch_id': 3, 'car_plate': 'DJ 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 85.9, 'producer': 'A'}
# {'event_id': '79995005-baea-42a5-b588-1bee1ac7d94a', 'batch_id': 3, 'car_plate': 'VZ 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 97.4, 'producer': 'A'}
# {'event_id': 'fb704780-229d-4d81-8afe-e766a61bf515', 'batch_id': 3, 'car_plate': 'RK 76', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 127.8, 'producer': 'A'}
# {'event_id': '2071717d-2db4-469c-b429-bde9741a5c16', 'batch_id': 3, 'car_plate': 'QBF 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 130.7, 'producer': 'A'}
# {'event_id': 'd7348b88-de55-461c-85bd-1ca9f83814e8', 'batch_id': 3, 'car_plate': 'GL 4', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 123.0, 'producer': 'A'}
# {'event_id': 'a0a61300-7bcb-4d68-9b75-856ed74d43e4', 'batch_id': 3, 'car_plate': 'MZ 242', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 143.3, 'producer': 'A'}
# {'event_id': 'd306cb22-bc82-4941-8311-9729f26137ab', 'batch_id': 3, 'car_plate': 'EC 40', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 140.7, 'producer': 'A'}
# {'event_id': 'f60a87ed-4636-46b8-8d09-35eb73cb559f', 'batch_id': 3, 'car_plate': 'SS 1621', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 151.8, 'producer': 'A'}
# {'event_id': '04cd9a63-9d02-450c-bb88-e0ac7c1a5f9f', 'batch_id': 3, 'car_plate': 'XCC 09', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 135.6, 'producer': 'A'}
# {'event_id': 'da890d08-51c5-4f80-af86-c9494dd84e75', 'batch_id': 3, 'car_plate': 'WVV 824', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:09', 'speed_reading': 107.3, 'producer': 'A'}
# {'event_id': '79a68ea7-182f-414b-ad9e-3ad21c2de074', 'batch_id': 3, 'car_plate': 'NGP 66', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 113.1, 'producer': 'A'}
# {'event_id': '1dd988c0-d000-489b-8cf0-2cd738fb0565', 'batch_id': 4, 'car_plate': 'BQN 88', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:48', 'speed_reading': 61.3, 'producer': 'A'}
# {'event_id': '9478323b-a2f6-4592-8c9f-a9de5bb984ab', 'batch_id': 4, 'car_plate': 'ZEA 3530', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:48', 'speed_reading': 153.3, 'producer': 'A'}
# {'event_id': '3e613964-b717-44a8-bf81-a1290ae07a35', 'batch_id': 4, 'car_plate': 'SJ 15', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:48', 'speed_reading': 146.2, 'producer': 'A'}
# {'event_id': '9f538681-69f0-4efd-a3e3-ef44ee2c1094', 'batch_id': 4, 'car_plate': 'PB 55', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:49', 'speed_reading': 111.2, 'producer': 'A'}
# {'event_id': '26e1dd39-29ec-4692-bca0-5705579ed316', 'batch_id': 4, 'car_plate': 'BU 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:47', 'speed_reading': 93.4, 'producer': 'A'}
# {'event_id': '865113cf-ff8a-41ea-b9f6-48a76b8dc3c4', 'batch_id': 4, 'car_plate': 'WX 49', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 78.2, 'producer': 'A'}
# {'event_id': '8217c776-2542-4494-851f-c603e4adaee1', 'batch_id': 4, 'car_plate': 'HLZ 1649', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:47', 'speed_reading': 85.2, 'producer': 'A'}
# {'event_id': 'f2deda9c-401b-4a0f-8d43-47c0871ff7d6', 'batch_id': 4, 'car_plate': 'YY 765', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:49', 'speed_reading': 76.4, 'producer': 'A'}
# {'event_id': 'f44716e8-a218-4484-8ffc-8aca0e5c3a04', 'batch_id': 4, 'car_plate': 'VLY 61', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 85.1, 'producer': 'A'}
# {'event_id': '2daa2630-7379-4d52-abc5-466ba64c3f33', 'batch_id': 4, 'car_plate': 'WOQ 4', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 69.4, 'producer': 'A'}
# {'event_id': '2df3e3fe-0abd-4be4-8386-7cbb6881b520', 'batch_id': 4, 'car_plate': 'YXA 7534', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 152.6, 'producer': 'A'}
# {'event_id': '27618bf3-5422-4d8e-bc89-a0bfaa094059', 'batch_id': 4, 'car_plate': 'ZCL 3', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:49', 'speed_reading': 107.2, 'producer': 'A'}
# {'event_id': '55747f07-49eb-4958-ac4d-46911bbfdbc6', 'batch_id': 4, 'car_plate': 'XYE 28', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 72.4, 'producer': 'A'}
# {'event_id': 'a342f327-e726-449c-84a2-3fa63f6c1bd4', 'batch_id': 4, 'car_plate': 'TZQ 7586', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:46', 'speed_reading': 137.7, 'producer': 'A'}
# {'event_id': 'e54bef88-8517-4925-966a-cf7b7e0e0b85', 'batch_id': 4, 'car_plate': 'CDC 5769', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 144.3, 'producer': 'A'}
# {'event_id': 'cff236e6-dcba-4e9e-b9aa-fbb70f96dd15', 'batch_id': 4, 'car_plate': 'KC 82', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:46', 'speed_reading': 90.8, 'producer': 'A'}
# {'event_id': '2cedaf61-3ecb-4c24-8c7a-0aa7b3d88f7e', 'batch_id': 4, 'car_plate': 'DOR 6', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 112.2, 'producer': 'A'}
# {'event_id': '8c42d2f9-8c1e-4dc3-9ab1-23e9df3dde27', 'batch_id': 4, 'car_plate': 'XY 025', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 149.0, 'producer': 'A'}
# {'event_id': '7e2c7380-bb0a-4237-a7b0-ada854450864', 'batch_id': 4, 'car_plate': 'CI 9861', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:47', 'speed_reading': 124.0, 'producer': 'A'}
# {'event_id': '9f976915-0387-42b7-963f-4e501358e48f', 'batch_id': 4, 'car_plate': 'QK 270', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 101.1, 'producer': 'A'}
# {'event_id': '7399dc47-301e-4fef-83b5-0fb99c533df8', 'batch_id': 5, 'car_plate': 'IMU 122', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 135.2, 'producer': 'A'}
# {'event_id': '654727a6-0002-46dd-ab19-8e468c001848', 'batch_id': 5, 'car_plate': 'GPR 4', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 149.3, 'producer': 'A'}
# {'event_id': 'f295cc40-0b9a-4c24-a2eb-fd53cf2901ee', 'batch_id': 5, 'car_plate': 'DAW 165', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 75.7, 'producer': 'A'}
# {'event_id': '7c667031-18db-4c16-bfe4-4d12b3abc54d', 'batch_id': 5, 'car_plate': 'WX 2585', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 101.6, 'producer': 'A'}
# {'event_id': '42132abc-2c2e-4624-ab61-0769297f177b', 'batch_id': 5, 'car_plate': 'OW 5', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:22', 'speed_reading': 137.3, 'producer': 'A'}
# {'event_id': 'e408f4bc-a7df-49bf-9523-1f5af6ec4627', 'batch_id': 5, 'car_plate': 'REP 98', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 129.9, 'producer': 'A'}
# {'event_id': '97638b79-22e5-4d9f-9a37-12618005014b', 'batch_id': 5, 'car_plate': 'AFS 0', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:20', 'speed_reading': 134.1, 'producer': 'A'}
# {'event_id': 'f302f720-927b-4c9e-b446-63000d364de8', 'batch_id': 5, 'car_plate': 'ZLY 15', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:22', 'speed_reading': 148.6, 'producer': 'A'}
# {'event_id': 'ce2eb21d-580f-48f6-85cb-2f83a8f1ea15', 'batch_id': 5, 'car_plate': 'TAD 5898', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 109.7, 'producer': 'A'}
# {'event_id': 'eb604110-7b16-4729-8aad-17fcc31bc056', 'batch_id': 5, 'car_plate': 'DGT 19', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 123.7, 'producer': 'A'}
# {'event_id': '2570710b-eb47-43d3-80f6-3e59e393e10d', 'batch_id': 5, 'car_plate': 'KOB 22', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:20', 'speed_reading': 71.9, 'producer': 'A'}
# {'event_id': '2d1f1862-8c71-4a67-b4be-a0be8b98716a', 'batch_id': 5, 'car_plate': 'JYA 82', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:23', 'speed_reading': 143.9, 'producer': 'A'}
# {'event_id': '261e1e49-07ad-49cc-b4a7-a418792be4a4', 'batch_id': 5, 'car_plate': 'ZBR 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 134.2, 'producer': 'A'}
# {'event_id': 'b8ba6caf-a47b-44dc-8cfd-51d206bdf4c7', 'batch_id': 5, 'car_plate': 'QQ 6161', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 126.1, 'producer': 'A'}
# {'event_id': '755a0905-5505-4829-9c12-4c4716cd5aa6', 'batch_id': 5, 'car_plate': 'VC 45', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:20', 'speed_reading': 84.2, 'producer': 'A'}
# {'event_id': 'd6b659fd-f2a3-41e2-afd3-3ace41aca481', 'batch_id': 5, 'car_plate': 'FQ 3', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 158.9, 'producer': 'A'}
# {'event_id': '2debc23e-c00c-438d-a2b2-4f01d3a0f367', 'batch_id': 5, 'car_plate': 'PW 7', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:25', 'speed_reading': 83.5, 'producer': 'A'}
# {'event_id': '255163b8-82ee-4658-b0e5-0607a95f5b28', 'batch_id': 5, 'car_plate': 'YE 6517', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:25', 'speed_reading': 126.7, 'producer': 'A'}
# {'event_id': 'beece8a5-5faf-46e3-91ca-c7e33d931f8e', 'batch_id': 5, 'car_plate': 'AW 965', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 127.6, 'producer': 'A'}
# {'event_id': '305032ef-d2ce-4edd-b620-c855e6a93128', 'batch_id': 5, 'car_plate': 'IU 033', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 78.7, 'producer': 'A'}
# {'event_id': '0b08e2f7-9b0d-4ce6-b846-105e39b80d77', 'batch_id': 6, 'car_plate': 'KNZ 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 133.8, 'producer': 'A'}
# {'event_id': '4fb23ec1-4956-466b-9ad9-07d534e0872b', 'batch_id': 6, 'car_plate': 'WK 223', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:22', 'speed_reading': 132.9, 'producer': 'A'}
# {'event_id': '8044f404-e5e5-496d-bd76-7e92fb9ad4ff', 'batch_id': 6, 'car_plate': 'IF 7805', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:25', 'speed_reading': 127.1, 'producer': 'A'}
# {'event_id': 'b668da0a-8cd1-4baa-90c8-078d2e979cfb', 'batch_id': 6, 'car_plate': 'ZCO 026', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 112.8, 'producer': 'A'}
# {'event_id': '2f1121c5-318b-41a0-a65d-9063dfa92ba2', 'batch_id': 6, 'car_plate': 'SAL 1597', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 141.1, 'producer': 'A'}
# {'event_id': 'cd52f3ec-c207-4e01-9505-29fdcf2ddd43', 'batch_id': 6, 'car_plate': 'FFG 22', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:21', 'speed_reading': 90.0, 'producer': 'A'}
# {'event_id': 'b7c015cf-dd89-4bad-89b3-e86440ffadcc', 'batch_id': 6, 'car_plate': 'WX 31', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 115.8, 'producer': 'A'}
# {'event_id': 'c85f6f47-007b-4590-87b8-29a6fe9415ad', 'batch_id': 6, 'car_plate': 'XSG 781', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 69.0, 'producer': 'A'}
# {'event_id': '01390557-1199-4930-9612-ed3fd51d2f1d', 'batch_id': 6, 'car_plate': 'IXF 6187', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:22', 'speed_reading': 84.8, 'producer': 'A'}
# {'event_id': 'e2dd36ff-5c13-4af8-a73d-0547f6224a85', 'batch_id': 6, 'car_plate': 'ZVK 10', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 125.0, 'producer': 'A'}
# {'event_id': '362cd5ec-4274-40ee-bbc4-6ce5d409edbf', 'batch_id': 6, 'car_plate': 'PS 93', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 106.5, 'producer': 'A'}
# {'event_id': 'd62f5e13-1055-40e7-86a8-ed8c697c4b84', 'batch_id': 6, 'car_plate': 'TB 5190', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 149.1, 'producer': 'A'}
# {'event_id': '78cb27b1-6cc6-4899-ae74-7297e8811ebf', 'batch_id': 6, 'car_plate': 'KNT 8153', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:25', 'speed_reading': 159.6, 'producer': 'A'}
# {'event_id': 'bddd39e0-9b35-4b89-89f8-7c664d69b36f', 'batch_id': 6, 'car_plate': 'KSH 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 102.0, 'producer': 'A'}
# {'event_id': 'dcc2f0f5-7de5-4563-b166-6967c54a0ad5', 'batch_id': 6, 'car_plate': 'HMU 040', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 117.1, 'producer': 'A'}
# {'event_id': '7d1f6eb8-1c83-443e-8fb7-c86e04e8f4f1', 'batch_id': 6, 'car_plate': 'MFH 37', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 120.5, 'producer': 'A'}
# {'event_id': '04e8dbb7-a0ab-4f03-9dea-97ecc31fc3fc', 'batch_id': 6, 'car_plate': 'NJN 8189', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 121.8, 'producer': 'A'}
# {'event_id': '8ed66d4a-c486-4f81-aba2-747ba57894e2', 'batch_id': 6, 'car_plate': 'GNU 052', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:24', 'speed_reading': 119.7, 'producer': 'A'}
# {'event_id': '508db83a-e1cb-4d4b-9c7b-156573739994', 'batch_id': 6, 'car_plate': 'VH 827', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 114.7, 'producer': 'A'}
# {'event_id': 'fd19aaf8-26f9-462c-9662-0a706b3a24f1', 'batch_id': 6, 'car_plate': 'HX 98', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 66.3, 'producer': 'A'}
# {'event_id': 'd40c586c-5be6-4743-a1e3-2269d9edaa72', 'batch_id': 1, 'car_plate': 'KRN 7', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 77.2, 'producer': 'A'}
# {'event_id': '85c08e3c-a0b5-45d8-a70c-df8f9a6d5829', 'batch_id': 1, 'car_plate': 'ICE 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 103.7, 'producer': 'A'}
# {'event_id': 'f5834b79-771b-4931-8da2-a5ad7f4ccd02', 'batch_id': 1, 'car_plate': 'QE 1820', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 67.4, 'producer': 'A'}
# {'event_id': 'd0e547bb-c4a7-4750-b7b4-8076e9b47f4f', 'batch_id': 1, 'car_plate': 'CJW 924', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 148.3, 'producer': 'A'}
# {'event_id': 'f3162606-1b2e-407f-951d-61d14c0a7b09', 'batch_id': 1, 'car_plate': 'CJP 278', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:02', 'speed_reading': 125.2, 'producer': 'A'}
# {'event_id': 'c69852f7-cd9a-4892-b225-8f8a36ec017b', 'batch_id': 1, 'car_plate': 'ZPG 90', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 95.7, 'producer': 'A'}
# {'event_id': '5113d990-4da6-41d2-b292-2516e7d8dc07', 'batch_id': 1, 'car_plate': 'KKE 15', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:00', 'speed_reading': 150.3, 'producer': 'A'}
# {'event_id': '67ce0672-95b5-43bd-9940-2e16db5f747a', 'batch_id': 1, 'car_plate': 'WJX 2', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 97.4, 'producer': 'A'}
# {'event_id': '7c5c112b-7521-4bbc-90f8-3c3a85cc3fe1', 'batch_id': 1, 'car_plate': 'FO 32', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 99.7, 'producer': 'A'}
# {'event_id': '213f0627-2be4-409c-972b-669627ca0461', 'batch_id': 1, 'car_plate': 'FA 35', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 81.7, 'producer': 'A'}
# {'event_id': '5a4497c9-5e3b-4470-a20c-8ee1f619f732', 'batch_id': 1, 'car_plate': 'CZ 592', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:02', 'speed_reading': 154.9, 'producer': 'A'}
# {'event_id': 'b57e8e44-b6e5-4c1e-bb5b-a4e1bd24bac9', 'batch_id': 1, 'car_plate': 'UTT 229', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:00', 'speed_reading': 140.9, 'producer': 'A'}
# {'event_id': 'c6965fdc-07df-4008-a8d3-f60febcd9223', 'batch_id': 1, 'car_plate': 'AH 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 159.5, 'producer': 'A'}
# {'event_id': '3306546c-d263-43f2-9d8c-87732e1e0e99', 'batch_id': 1, 'car_plate': 'CX 6145', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 105.0, 'producer': 'A'}
# {'event_id': 'f108727e-e97d-4d8e-b109-e7e763b64398', 'batch_id': 1, 'car_plate': 'FZ 766', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:05', 'speed_reading': 132.9, 'producer': 'A'}
# {'event_id': '7214629f-2fbb-4787-b953-e163720a6c61', 'batch_id': 1, 'car_plate': 'KZE 5', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:01', 'speed_reading': 133.3, 'producer': 'A'}
# {'event_id': '3ca5e275-0cf6-43a0-8c28-65040c60b8b2', 'batch_id': 1, 'car_plate': 'HP 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 140.0, 'producer': 'A'}
# {'event_id': '562fee6c-d50b-4207-b2ea-e3b8a68f20f9', 'batch_id': 1, 'car_plate': 'WC 89', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:03', 'speed_reading': 96.7, 'producer': 'A'}
# {'event_id': '25a3e2ad-502e-4273-9062-6f00ec63f62c', 'batch_id': 1, 'car_plate': 'EOT 00', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 142.6, 'producer': 'A'}
# {'event_id': '0abc5099-64d1-4b1a-b623-084b19ce9e4e', 'batch_id': 1, 'car_plate': 'WA 0712', 'camera_id': 1, 'timestamp': '2024-01-01T08:00:04', 'speed_reading': 142.1, 'producer': 'A'}
# {'event_id': 'be770f2f-e15a-463c-b4a7-955ee3e14924', 'batch_id': 2, 'car_plate': 'WB 418', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 148.7, 'producer': 'A'}
# {'event_id': '3930bb19-4837-4f01-a6b2-ce5757d1cc53', 'batch_id': 2, 'car_plate': 'QJ 53', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 82.6, 'producer': 'A'}
# {'event_id': '4b1633e2-8268-4c82-a509-7dfde90635aa', 'batch_id': 2, 'car_plate': 'EZ 6277', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 93.5, 'producer': 'A'}
# {'event_id': 'd1fcb87d-b48c-43ea-9697-8e6ee3b83cf7', 'batch_id': 2, 'car_plate': 'PI 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 154.0, 'producer': 'A'}
# {'event_id': '59e37658-17a9-41e6-8fd1-e65af3e271f9', 'batch_id': 2, 'car_plate': 'VWM 13', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 115.4, 'producer': 'A'}
# {'event_id': '013b5963-adc3-426b-b6f4-2c649aef7630', 'batch_id': 2, 'car_plate': 'VM 4837', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 104.7, 'producer': 'A'}
# {'event_id': '0352cb9f-fc86-4990-abf9-74cfbe287ec8', 'batch_id': 2, 'car_plate': 'JEJ 6', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:03', 'speed_reading': 117.6, 'producer': 'A'}
# {'event_id': '8017281b-a1a5-4d65-b0e4-7a522876d277', 'batch_id': 2, 'car_plate': 'UQV 232', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 154.4, 'producer': 'A'}
# {'event_id': 'be870773-5781-41b0-9d65-56383fa80385', 'batch_id': 2, 'car_plate': 'KV 17', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 86.7, 'producer': 'A'}
# {'event_id': 'abae5e9d-3d24-4e9a-b2cf-ab6915c397d7', 'batch_id': 2, 'car_plate': 'IFY 23', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:04', 'speed_reading': 107.8, 'producer': 'A'}
# {'event_id': '8449613c-fd13-4325-a030-4a1891d9aeaa', 'batch_id': 2, 'car_plate': 'DSD 320', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:06', 'speed_reading': 113.0, 'producer': 'A'}
# {'event_id': '5cb93acb-1b43-4370-98f9-a586086a2b22', 'batch_id': 2, 'car_plate': 'WPV 1456', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:01', 'speed_reading': 78.1, 'producer': 'A'}
# {'event_id': '1e7c0e8d-5ebc-4869-9a0b-445c8e6d566e', 'batch_id': 2, 'car_plate': 'DWT 789', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 129.0, 'producer': 'A'}
# {'event_id': '6e662e88-2ece-46d5-b8f6-0c253b0c676a', 'batch_id': 2, 'car_plate': 'XYG 05', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:04', 'speed_reading': 114.2, 'producer': 'A'}
# {'event_id': '3a60cae5-3201-4d6f-8097-4db36725f3e5', 'batch_id': 2, 'car_plate': 'AJB 6689', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 64.1, 'producer': 'A'}
# {'event_id': 'a906d3ea-059c-4a12-932b-a42cb460fc68', 'batch_id': 2, 'car_plate': 'QZ 81', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:03', 'speed_reading': 60.5, 'producer': 'A'}
# {'event_id': 'a47e8660-36f5-4cdf-bc7d-b1d709c78974', 'batch_id': 2, 'car_plate': 'WZ 24', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:02', 'speed_reading': 158.2, 'producer': 'A'}
# {'event_id': '04ca2c7e-47b6-4db2-8985-5348266f4cb6', 'batch_id': 2, 'car_plate': 'YRV 3', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:05', 'speed_reading': 65.8, 'producer': 'A'}
# {'event_id': '701b86a2-5a29-4bc9-a078-d157fecc486c', 'batch_id': 2, 'car_plate': 'PKH 8115', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:03', 'speed_reading': 151.9, 'producer': 'A'}
# {'event_id': '41024bb3-3aa7-4ba6-817c-9dfac60e4b7c', 'batch_id': 2, 'car_plate': 'BS 03', 'camera_id': 1, 'timestamp': '2024-01-01T08:08:06', 'speed_reading': 106.7, 'producer': 'A'}
# {'event_id': 'b05ac078-6f38-41f4-a126-a7616870029d', 'batch_id': 3, 'car_plate': 'CIY 810', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:08', 'speed_reading': 132.1, 'producer': 'A'}
# {'event_id': '8d513b56-0bf4-467c-add2-77381a36f231', 'batch_id': 3, 'car_plate': 'ARX 7573', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 121.2, 'producer': 'A'}
# {'event_id': '420c8cce-ca7d-48de-b99a-04dccf9d0b0b', 'batch_id': 3, 'car_plate': 'GI 029', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 60.8, 'producer': 'A'}
# {'event_id': '379c53ab-ab19-448e-833b-c894e90b8ace', 'batch_id': 3, 'car_plate': 'ZZ 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:08', 'speed_reading': 60.0, 'producer': 'A'}
# {'event_id': 'c14cd235-dd29-430d-8419-bd4e5e9c8b13', 'batch_id': 3, 'car_plate': 'ZQ 22', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 117.1, 'producer': 'A'}
# {'event_id': '833f950f-1108-47ea-acde-f3de4ebf7af2', 'batch_id': 3, 'car_plate': 'KWO 421', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 109.9, 'producer': 'A'}
# {'event_id': '82b14f5d-decc-47fa-925c-c63ca0862d8c', 'batch_id': 3, 'car_plate': 'VKZ 5377', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 78.0, 'producer': 'A'}
# {'event_id': '762873cc-b78d-4813-ba0f-19926f52f06d', 'batch_id': 3, 'car_plate': 'VJX 7', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 119.6, 'producer': 'A'}
# {'event_id': '5306eb46-4bee-4a8d-8800-ca93adfc499a', 'batch_id': 3, 'car_plate': 'ZV 2619', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 92.8, 'producer': 'A'}
# {'event_id': '32d8571e-be18-47c6-af6a-3dbc01061190', 'batch_id': 3, 'car_plate': 'DJ 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:10', 'speed_reading': 85.9, 'producer': 'A'}
# {'event_id': '79995005-baea-42a5-b588-1bee1ac7d94a', 'batch_id': 3, 'car_plate': 'VZ 8', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 97.4, 'producer': 'A'}
# {'event_id': 'fb704780-229d-4d81-8afe-e766a61bf515', 'batch_id': 3, 'car_plate': 'RK 76', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 127.8, 'producer': 'A'}
# {'event_id': '2071717d-2db4-469c-b429-bde9741a5c16', 'batch_id': 3, 'car_plate': 'QBF 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 130.7, 'producer': 'A'}
# {'event_id': 'd7348b88-de55-461c-85bd-1ca9f83814e8', 'batch_id': 3, 'car_plate': 'GL 4', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 123.0, 'producer': 'A'}
# {'event_id': 'a0a61300-7bcb-4d68-9b75-856ed74d43e4', 'batch_id': 3, 'car_plate': 'MZ 242', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:11', 'speed_reading': 143.3, 'producer': 'A'}
# {'event_id': 'd306cb22-bc82-4941-8311-9729f26137ab', 'batch_id': 3, 'car_plate': 'EC 40', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 140.7, 'producer': 'A'}
# {'event_id': 'f60a87ed-4636-46b8-8d09-35eb73cb559f', 'batch_id': 3, 'car_plate': 'SS 1621', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 151.8, 'producer': 'A'}
# {'event_id': '04cd9a63-9d02-450c-bb88-e0ac7c1a5f9f', 'batch_id': 3, 'car_plate': 'XCC 09', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:12', 'speed_reading': 135.6, 'producer': 'A'}
# {'event_id': 'da890d08-51c5-4f80-af86-c9494dd84e75', 'batch_id': 3, 'car_plate': 'WVV 824', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:09', 'speed_reading': 107.3, 'producer': 'A'}
# {'event_id': '79a68ea7-182f-414b-ad9e-3ad21c2de074', 'batch_id': 3, 'car_plate': 'NGP 66', 'camera_id': 1, 'timestamp': '2024-01-01T08:13:07', 'speed_reading': 113.1, 'producer': 'A'}
# {'event_id': '1dd988c0-d000-489b-8cf0-2cd738fb0565', 'batch_id': 4, 'car_plate': 'BQN 88', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:48', 'speed_reading': 61.3, 'producer': 'A'}
# {'event_id': '9478323b-a2f6-4592-8c9f-a9de5bb984ab', 'batch_id': 4, 'car_plate': 'ZEA 3530', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:48', 'speed_reading': 153.3, 'producer': 'A'}
# {'event_id': '3e613964-b717-44a8-bf81-a1290ae07a35', 'batch_id': 4, 'car_plate': 'SJ 15', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:48', 'speed_reading': 146.2, 'producer': 'A'}
# {'event_id': '9f538681-69f0-4efd-a3e3-ef44ee2c1094', 'batch_id': 4, 'car_plate': 'PB 55', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:49', 'speed_reading': 111.2, 'producer': 'A'}
# {'event_id': '26e1dd39-29ec-4692-bca0-5705579ed316', 'batch_id': 4, 'car_plate': 'BU 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:47', 'speed_reading': 93.4, 'producer': 'A'}
# {'event_id': '865113cf-ff8a-41ea-b9f6-48a76b8dc3c4', 'batch_id': 4, 'car_plate': 'WX 49', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 78.2, 'producer': 'A'}
# {'event_id': '8217c776-2542-4494-851f-c603e4adaee1', 'batch_id': 4, 'car_plate': 'HLZ 1649', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:47', 'speed_reading': 85.2, 'producer': 'A'}
# {'event_id': 'f2deda9c-401b-4a0f-8d43-47c0871ff7d6', 'batch_id': 4, 'car_plate': 'YY 765', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:49', 'speed_reading': 76.4, 'producer': 'A'}
# {'event_id': 'f44716e8-a218-4484-8ffc-8aca0e5c3a04', 'batch_id': 4, 'car_plate': 'VLY 61', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 85.1, 'producer': 'A'}
# {'event_id': '2daa2630-7379-4d52-abc5-466ba64c3f33', 'batch_id': 4, 'car_plate': 'WOQ 4', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 69.4, 'producer': 'A'}
# {'event_id': '2df3e3fe-0abd-4be4-8386-7cbb6881b520', 'batch_id': 4, 'car_plate': 'YXA 7534', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 152.6, 'producer': 'A'}
# {'event_id': '27618bf3-5422-4d8e-bc89-a0bfaa094059', 'batch_id': 4, 'car_plate': 'ZCL 3', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:49', 'speed_reading': 107.2, 'producer': 'A'}
# {'event_id': '55747f07-49eb-4958-ac4d-46911bbfdbc6', 'batch_id': 4, 'car_plate': 'XYE 28', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 72.4, 'producer': 'A'}
# {'event_id': 'a342f327-e726-449c-84a2-3fa63f6c1bd4', 'batch_id': 4, 'car_plate': 'TZQ 7586', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:46', 'speed_reading': 137.7, 'producer': 'A'}
# {'event_id': 'e54bef88-8517-4925-966a-cf7b7e0e0b85', 'batch_id': 4, 'car_plate': 'CDC 5769', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 144.3, 'producer': 'A'}
# {'event_id': 'cff236e6-dcba-4e9e-b9aa-fbb70f96dd15', 'batch_id': 4, 'car_plate': 'KC 82', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:46', 'speed_reading': 90.8, 'producer': 'A'}
# {'event_id': '2cedaf61-3ecb-4c24-8c7a-0aa7b3d88f7e', 'batch_id': 4, 'car_plate': 'DOR 6', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:44', 'speed_reading': 112.2, 'producer': 'A'}
# {'event_id': '8c42d2f9-8c1e-4dc3-9ab1-23e9df3dde27', 'batch_id': 4, 'car_plate': 'XY 025', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 149.0, 'producer': 'A'}
# {'event_id': '7e2c7380-bb0a-4237-a7b0-ada854450864', 'batch_id': 4, 'car_plate': 'CI 9861', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:47', 'speed_reading': 124.0, 'producer': 'A'}
# {'event_id': '9f976915-0387-42b7-963f-4e501358e48f', 'batch_id': 4, 'car_plate': 'QK 270', 'camera_id': 1, 'timestamp': '2024-01-01T08:19:45', 'speed_reading': 101.1, 'producer': 'A'}
# {'event_id': '7399dc47-301e-4fef-83b5-0fb99c533df8', 'batch_id': 5, 'car_plate': 'IMU 122', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 135.2, 'producer': 'A'}
# {'event_id': '654727a6-0002-46dd-ab19-8e468c001848', 'batch_id': 5, 'car_plate': 'GPR 4', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 149.3, 'producer': 'A'}
# {'event_id': 'f295cc40-0b9a-4c24-a2eb-fd53cf2901ee', 'batch_id': 5, 'car_plate': 'DAW 165', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 75.7, 'producer': 'A'}
# {'event_id': '7c667031-18db-4c16-bfe4-4d12b3abc54d', 'batch_id': 5, 'car_plate': 'WX 2585', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 101.6, 'producer': 'A'}
# {'event_id': '42132abc-2c2e-4624-ab61-0769297f177b', 'batch_id': 5, 'car_plate': 'OW 5', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:22', 'speed_reading': 137.3, 'producer': 'A'}
# {'event_id': 'e408f4bc-a7df-49bf-9523-1f5af6ec4627', 'batch_id': 5, 'car_plate': 'REP 98', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 129.9, 'producer': 'A'}
# {'event_id': '97638b79-22e5-4d9f-9a37-12618005014b', 'batch_id': 5, 'car_plate': 'AFS 0', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:20', 'speed_reading': 134.1, 'producer': 'A'}
# {'event_id': 'f302f720-927b-4c9e-b446-63000d364de8', 'batch_id': 5, 'car_plate': 'ZLY 15', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:22', 'speed_reading': 148.6, 'producer': 'A'}
# {'event_id': 'ce2eb21d-580f-48f6-85cb-2f83a8f1ea15', 'batch_id': 5, 'car_plate': 'TAD 5898', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 109.7, 'producer': 'A'}
# {'event_id': 'eb604110-7b16-4729-8aad-17fcc31bc056', 'batch_id': 5, 'car_plate': 'DGT 19', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 123.7, 'producer': 'A'}
# {'event_id': '2570710b-eb47-43d3-80f6-3e59e393e10d', 'batch_id': 5, 'car_plate': 'KOB 22', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:20', 'speed_reading': 71.9, 'producer': 'A'}
# {'event_id': '2d1f1862-8c71-4a67-b4be-a0be8b98716a', 'batch_id': 5, 'car_plate': 'JYA 82', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:23', 'speed_reading': 143.9, 'producer': 'A'}
# {'event_id': '261e1e49-07ad-49cc-b4a7-a418792be4a4', 'batch_id': 5, 'car_plate': 'ZBR 9', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 134.2, 'producer': 'A'}
# {'event_id': 'b8ba6caf-a47b-44dc-8cfd-51d206bdf4c7', 'batch_id': 5, 'car_plate': 'QQ 6161', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 126.1, 'producer': 'A'}
# {'event_id': '755a0905-5505-4829-9c12-4c4716cd5aa6', 'batch_id': 5, 'car_plate': 'VC 45', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:20', 'speed_reading': 84.2, 'producer': 'A'}
# {'event_id': 'd6b659fd-f2a3-41e2-afd3-3ace41aca481', 'batch_id': 5, 'car_plate': 'FQ 3', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 158.9, 'producer': 'A'}
# {'event_id': '2debc23e-c00c-438d-a2b2-4f01d3a0f367', 'batch_id': 5, 'car_plate': 'PW 7', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:25', 'speed_reading': 83.5, 'producer': 'A'}
# {'event_id': '255163b8-82ee-4658-b0e5-0607a95f5b28', 'batch_id': 5, 'car_plate': 'YE 6517', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:25', 'speed_reading': 126.7, 'producer': 'A'}
# {'event_id': 'beece8a5-5faf-46e3-91ca-c7e33d931f8e', 'batch_id': 5, 'car_plate': 'AW 965', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:21', 'speed_reading': 127.6, 'producer': 'A'}
# {'event_id': '305032ef-d2ce-4edd-b620-c855e6a93128', 'batch_id': 5, 'car_plate': 'IU 033', 'camera_id': 1, 'timestamp': '2024-01-01T08:25:24', 'speed_reading': 78.7, 'producer': 'A'}
# {'event_id': '0b08e2f7-9b0d-4ce6-b846-105e39b80d77', 'batch_id': 6, 'car_plate': 'KNZ 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 133.8, 'producer': 'A'}
# {'event_id': '4fb23ec1-4956-466b-9ad9-07d534e0872b', 'batch_id': 6, 'car_plate': 'WK 223', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:22', 'speed_reading': 132.9, 'producer': 'A'}
# {'event_id': '8044f404-e5e5-496d-bd76-7e92fb9ad4ff', 'batch_id': 6, 'car_plate': 'IF 7805', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:25', 'speed_reading': 127.1, 'producer': 'A'}
# {'event_id': 'b668da0a-8cd1-4baa-90c8-078d2e979cfb', 'batch_id': 6, 'car_plate': 'ZCO 026', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 112.8, 'producer': 'A'}
# {'event_id': '2f1121c5-318b-41a0-a65d-9063dfa92ba2', 'batch_id': 6, 'car_plate': 'SAL 1597', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 141.1, 'producer': 'A'}
# {'event_id': 'cd52f3ec-c207-4e01-9505-29fdcf2ddd43', 'batch_id': 6, 'car_plate': 'FFG 22', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:21', 'speed_reading': 90.0, 'producer': 'A'}
# {'event_id': 'b7c015cf-dd89-4bad-89b3-e86440ffadcc', 'batch_id': 6, 'car_plate': 'WX 31', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 115.8, 'producer': 'A'}
# {'event_id': 'c85f6f47-007b-4590-87b8-29a6fe9415ad', 'batch_id': 6, 'car_plate': 'XSG 781', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 69.0, 'producer': 'A'}
# {'event_id': '01390557-1199-4930-9612-ed3fd51d2f1d', 'batch_id': 6, 'car_plate': 'IXF 6187', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:22', 'speed_reading': 84.8, 'producer': 'A'}
# {'event_id': 'e2dd36ff-5c13-4af8-a73d-0547f6224a85', 'batch_id': 6, 'car_plate': 'ZVK 10', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 125.0, 'producer': 'A'}
# {'event_id': '362cd5ec-4274-40ee-bbc4-6ce5d409edbf', 'batch_id': 6, 'car_plate': 'PS 93', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 106.5, 'producer': 'A'}
# {'event_id': 'd62f5e13-1055-40e7-86a8-ed8c697c4b84', 'batch_id': 6, 'car_plate': 'TB 5190', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 149.1, 'producer': 'A'}
# {'event_id': '78cb27b1-6cc6-4899-ae74-7297e8811ebf', 'batch_id': 6, 'car_plate': 'KNT 8153', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:25', 'speed_reading': 159.6, 'producer': 'A'}
# {'event_id': 'bddd39e0-9b35-4b89-89f8-7c664d69b36f', 'batch_id': 6, 'car_plate': 'KSH 1', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:23', 'speed_reading': 102.0, 'producer': 'A'}
# {'event_id': 'dcc2f0f5-7de5-4563-b166-6967c54a0ad5', 'batch_id': 6, 'car_plate': 'HMU 040', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 117.1, 'producer': 'A'}
# {'event_id': '7d1f6eb8-1c83-443e-8fb7-c86e04e8f4f1', 'batch_id': 6, 'car_plate': 'MFH 37', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 120.5, 'producer': 'A'}
# {'event_id': '04e8dbb7-a0ab-4f03-9dea-97ecc31fc3fc', 'batch_id': 6, 'car_plate': 'NJN 8189', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 121.8, 'producer': 'A'}
# {'event_id': '8ed66d4a-c486-4f81-aba2-747ba57894e2', 'batch_id': 6, 'car_plate': 'GNU 052', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:24', 'speed_reading': 119.7, 'producer': 'A'}
# {'event_id': '508db83a-e1cb-4d4b-9c7b-156573739994', 'batch_id': 6, 'car_plate': 'VH 827', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 114.7, 'producer': 'A'}
# {'event_id': 'fd19aaf8-26f9-462c-9662-0a706b3a24f1', 'batch_id': 6, 'car_plate': 'HX 98', 'camera_id': 1, 'timestamp': '2024-01-01T08:35:20', 'speed_reading': 66.3, 'producer': 'A'}
# {'event_id': '3b552227-5141-4478-ae2f-3290e69a10c9', 'batch_id': 7, 'car_plate': 'IMC 6788', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:38', 'speed_reading': 87.6, 'producer': 'A'}
# {'event_id': 'b80e1666-e54c-408d-bd13-31907f32beb8', 'batch_id': 7, 'car_plate': 'UQ 07', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:40', 'speed_reading': 143.9, 'producer': 'A'}
# {'event_id': 'd4a1869f-2472-4b79-99b9-aff566122d5a', 'batch_id': 7, 'car_plate': 'CXD 617', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:41', 'speed_reading': 75.0, 'producer': 'A'}
# {'event_id': '738b20ae-27b2-421f-aac6-7b85939e1371', 'batch_id': 7, 'car_plate': 'PJ 35', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:39', 'speed_reading': 115.9, 'producer': 'A'}
# {'event_id': '4224f70a-54a9-45b8-b2b2-6f79d2444837', 'batch_id': 7, 'car_plate': 'MC 2760', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:41', 'speed_reading': 70.6, 'producer': 'A'}
# {'event_id': '04dd7f5f-914f-4b8c-9bf3-f69a0cce85ff', 'batch_id': 7, 'car_plate': 'XY 7365', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:37', 'speed_reading': 158.6, 'producer': 'A'}
# {'event_id': 'aa02b3a9-3b9f-4d4d-a949-ae86141bae38', 'batch_id': 7, 'car_plate': 'DBF 451', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:41', 'speed_reading': 60.9, 'producer': 'A'}
# {'event_id': 'fcab5df7-0db3-4964-a63e-a2e28f34cb3d', 'batch_id': 7, 'car_plate': 'YTE 8888', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:39', 'speed_reading': 94.5, 'producer': 'A'}
# {'event_id': '2969de1a-a07d-40f5-9d69-0ccf451a94ac', 'batch_id': 7, 'car_plate': 'XWC 903', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:40', 'speed_reading': 132.5, 'producer': 'A'}
# {'event_id': '0a3616df-761a-42f2-bda8-696fbc78d57b', 'batch_id': 7, 'car_plate': 'CU 131', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:39', 'speed_reading': 81.6, 'producer': 'A'}
# {'event_id': 'c62392e4-5195-435f-aa8e-aae0b615543d', 'batch_id': 7, 'car_plate': 'OH 2', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:37', 'speed_reading': 72.8, 'producer': 'A'}
# {'event_id': '6320e279-cab5-4847-aac2-674081a9d50c', 'batch_id': 7, 'car_plate': 'BUB 647', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:42', 'speed_reading': 60.1, 'producer': 'A'}
# {'event_id': '1dc969e9-6ef3-48aa-92a9-3dc1868f3bd8', 'batch_id': 7, 'car_plate': 'ZG 714', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:38', 'speed_reading': 145.1, 'producer': 'A'}
# {'event_id': '89d873dc-efad-426c-a929-c99518af8c05', 'batch_id': 7, 'car_plate': 'EX 2', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:40', 'speed_reading': 117.0, 'producer': 'A'}
# {'event_id': 'ca0cd37c-684d-4a50-88fe-f740a61eaa1b', 'batch_id': 7, 'car_plate': 'QAR 0', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:37', 'speed_reading': 149.7, 'producer': 'A'}
# {'event_id': 'a409fc8b-6061-40b4-a900-87fcb9669979', 'batch_id': 7, 'car_plate': 'UMZ 673', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:41', 'speed_reading': 84.6, 'producer': 'A'}
# {'event_id': '8cfeb217-02b2-4d86-b09d-30f7f095dddb', 'batch_id': 7, 'car_plate': 'CKI 86', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:41', 'speed_reading': 67.0, 'producer': 'A'}
# {'event_id': '20ee8261-d847-4815-bb0e-8b2ecf05aca6', 'batch_id': 7, 'car_plate': 'BPV 0250', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:41', 'speed_reading': 81.2, 'producer': 'A'}
# {'event_id': '1c84a6b2-1537-4095-8ffe-17f56d871ab5', 'batch_id': 7, 'car_plate': 'YO 3272', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:39', 'speed_reading': 101.6, 'producer': 'A'}
# {'event_id': 'bd4837eb-248b-498a-be75-00bb885f00a1', 'batch_id': 7, 'car_plate': 'ZHC 847', 'camera_id': 1, 'timestamp': '2024-01-01T08:42:42', 'speed_reading': 73.2, 'producer': 'A'}
# ...
# {'event_id': 'ee787113-eb0d-49d6-9cf9-054569625449', 'batch_id': 4, 'car_plate': 'HP 1', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:28.740321', 'speed_reading': 142.8, 'producer': 'B', 'sent_at': '2025-05-13T11:31:21.124099'}
# {'event_id': 'cada35fc-33a8-4bf0-a640-e0d6fc2a73df', 'batch_id': 4, 'car_plate': 'KZE 5', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:29.186382', 'speed_reading': 135.2, 'producer': 'B', 'sent_at': '2025-05-13T11:31:21.124427'}
# {'event_id': 'ac84bb22-32be-4993-a655-49874adeecc4', 'batch_id': 4, 'car_plate': 'CJP 278', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:31.515912', 'speed_reading': 117.6, 'producer': 'B', 'sent_at': '2025-05-13T11:31:21.124623'}
# {'event_id': '68ffa68c-a083-4a30-a123-9464521462bb', 'batch_id': 5, 'car_plate': 'WJX 2', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:38.751677', 'speed_reading': 94.8, 'producer': 'B', 'sent_at': '2025-05-13T11:31:26.140016'}
# {'event_id': '0fac4c5a-7793-4993-97b3-169d41b57680', 'batch_id': 5, 'car_plate': 'ZPG 90', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:39.898370', 'speed_reading': 98.4, 'producer': 'B', 'sent_at': '2025-05-13T11:31:26.141937'}
# {'event_id': '2b797755-2cb6-449f-b580-1dd691334076', 'batch_id': 5, 'car_plate': 'CX 6145', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:40.382453', 'speed_reading': 110.5, 'producer': 'B', 'sent_at': '2025-05-13T11:31:26.142562'}
# {'event_id': '7b90e93f-714a-46c9-b6b7-9bbcf07cceb1', 'batch_id': 5, 'car_plate': 'ICE 8', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:40.838661', 'speed_reading': 103.2, 'producer': 'B', 'sent_at': '2025-05-13T11:31:26.142972'}
# {'event_id': '8916338e-f0f5-4fac-8d8d-cdb6c03d1d07', 'batch_id': 6, 'car_plate': 'KRN 7', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:52.541902', 'speed_reading': 75.5, 'producer': 'B', 'sent_at': '2025-05-13T11:31:31.154052'}
# {'event_id': '6626efb2-32f3-4bda-8a34-d79eedf615c8', 'batch_id': 6, 'car_plate': 'QE 1820', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:57.368642', 'speed_reading': 66.1, 'producer': 'B', 'sent_at': '2025-05-13T11:31:31.155539'}
# {'event_id': '7dff112a-d3ce-4ebb-841f-ea3e03662ead', 'batch_id': 7, 'car_plate': 'WB 418', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:24.091422', 'speed_reading': 138.8, 'producer': 'B', 'sent_at': '2025-05-13T11:31:36.168047'}
# {'event_id': '1f739fcb-8e46-4c92-a69b-9a18533cb646', 'batch_id': 7, 'car_plate': 'PI 9', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:26.478501', 'speed_reading': 140.9, 'producer': 'B', 'sent_at': '2025-05-13T11:31:36.169513'}
# {'event_id': '756a47f3-7f81-4e17-88fa-b2bbed9aa29e', 'batch_id': 7, 'car_plate': 'PKH 8115', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:28.027669', 'speed_reading': 143.8, 'producer': 'B', 'sent_at': '2025-05-13T11:31:36.169992'}
# {'event_id': 'eb9614ad-ee22-4001-835f-4242e362be01', 'batch_id': 8, 'car_plate': 'JEJ 6', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:34.116409', 'speed_reading': 111.2, 'producer': 'B', 'sent_at': '2025-05-13T11:31:41.182932'}
# {'event_id': 'be049d21-395f-4d4d-9b6d-b9abf442219b', 'batch_id': 9, 'car_plate': 'EZ 6277', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:39.920072', 'speed_reading': 94.3, 'producer': 'B', 'sent_at': '2025-05-13T11:31:46.196622'}
# {'event_id': 'ac68fd91-60d4-4120-8f5a-2a0f2984549f', 'batch_id': 9, 'car_plate': 'KV 17', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:44.552593', 'speed_reading': 86.9, 'producer': 'B', 'sent_at': '2025-05-13T11:31:46.197975'}
# {'event_id': '58588fd9-1fd6-4b52-929b-406731bbce2b', 'batch_id': 10, 'car_plate': 'WPV 1456', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:45.845657', 'speed_reading': 75.1, 'producer': 'B', 'sent_at': '2025-05-13T11:31:51.212072'}
# {'event_id': '274dffed-ed69-4f56-8a2e-5c017d27adc1', 'batch_id': 10, 'car_plate': 'QJ 53', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:46.302895', 'speed_reading': 82.8, 'producer': 'B', 'sent_at': '2025-05-13T11:31:51.213470'}
# {'event_id': '7012857e-8060-4291-8c2d-0a8601c258d8', 'batch_id': 11, 'car_plate': 'YRV 3', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:58.749711', 'speed_reading': 63.8, 'producer': 'B', 'sent_at': '2025-05-13T11:31:56.226024'}
# {'event_id': '42b0938d-6524-40b5-99cc-b71e26aa30f3', 'batch_id': 12, 'car_plate': 'KKE 15', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:23.896476', 'speed_reading': 138.3, 'producer': 'B', 'sent_at': '2025-05-13T11:32:01.240590'}
# {'event_id': '7dba46aa-77b5-47f5-9801-d30e5ddff0d7', 'batch_id': 13, 'car_plate': 'FO 32', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:39.240776', 'speed_reading': 94.8, 'producer': 'B', 'sent_at': '2025-05-13T11:32:06.253660'}
# {'event_id': '3f9d8d31-718b-4021-b3f0-1f5aed75009b', 'batch_id': 14, 'car_plate': 'FA 35', 'camera_id': 2, 'timestamp': '2024-01-01T08:00:48.370527', 'speed_reading': 84.2, 'producer': 'B', 'sent_at': '2025-05-13T11:32:11.268688'}
# {'event_id': 'cbafd132-a61f-4713-b2f9-76f08141c70e', 'batch_id': 15, 'car_plate': 'WZ 24', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:25.481310', 'speed_reading': 160.2, 'producer': 'B', 'sent_at': '2025-05-13T11:32:16.286226'}
# {'event_id': '9dd51204-9367-4369-8575-611b817ce296', 'batch_id': 15, 'car_plate': 'UQV 232', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:25.620770', 'speed_reading': 157.6, 'producer': 'B', 'sent_at': '2025-05-13T11:32:16.287173'}
# {'event_id': '340aef07-48be-44d0-aeb8-b08df2023f7e', 'batch_id': 16, 'car_plate': 'VWM 13', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:31.623998', 'speed_reading': 117.3, 'producer': 'B', 'sent_at': '2025-05-13T11:32:21.302052'}
# {'event_id': 'd3051697-4d90-4d15-8802-b34bd9436732', 'batch_id': 16, 'car_plate': 'XYG 05', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:33.906703', 'speed_reading': 109.6, 'producer': 'B', 'sent_at': '2025-05-13T11:32:21.303463'}
# {'event_id': 'd33a1a67-4f54-47d9-a3c1-f9fbcd5751a9', 'batch_id': 17, 'car_plate': 'IFY 23', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:38.633820', 'speed_reading': 111.1, 'producer': 'B', 'sent_at': '2025-05-13T11:32:26.317672'}
# {'event_id': 'b8762345-0b31-4cc6-b35c-e99e5168c7b7', 'batch_id': 18, 'car_plate': 'QZ 81', 'camera_id': 2, 'timestamp': '2024-01-01T08:09:01.211939', 'speed_reading': 62.0, 'producer': 'B', 'sent_at': '2025-05-13T11:32:31.333976'}
# {'event_id': '315c64ac-0f96-4a67-98c4-7d7b85cfa455', 'batch_id': 19, 'car_plate': 'CIY 810', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:34.334415', 'speed_reading': 136.3, 'producer': 'B', 'sent_at': '2025-05-13T11:32:36.350707'}
# {'event_id': 'd40dc066-ba11-4d44-a4e5-48f7038544a7', 'batch_id': 19, 'car_plate': 'ZQ 22', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:36.902545', 'speed_reading': 113.0, 'producer': 'B', 'sent_at': '2025-05-13T11:32:36.352059'}
# {'event_id': '40d72911-cdde-4af8-9a18-68aa908a46a5', 'batch_id': 19, 'car_plate': 'EC 40', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:37.027065', 'speed_reading': 144.7, 'producer': 'B', 'sent_at': '2025-05-13T11:32:36.352459'}
# {'event_id': '1622ac4e-d0d1-4713-85fe-e5b5f01d1c28', 'batch_id': 19, 'car_plate': 'NGP 66', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:38.833509', 'speed_reading': 107.2, 'producer': 'B', 'sent_at': '2025-05-13T11:32:36.352699'}
# {'event_id': '2ae298d2-5496-4732-95ef-82f4b57ef4b7', 'batch_id': 20, 'car_plate': 'KWO 421', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:44.248324', 'speed_reading': 115.4, 'producer': 'B', 'sent_at': '2025-05-13T11:32:41.367864'}
# {'event_id': '61ffc37e-73c0-4fa9-a604-e2596e8f6289', 'batch_id': 20, 'car_plate': 'ZV 2619', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:48.703774', 'speed_reading': 96.8, 'producer': 'B', 'sent_at': '2025-05-13T11:32:41.369822'}
# {'event_id': 'd86e8cdb-c387-4ccb-b35a-346302238824', 'batch_id': 1, 'car_plate': 'UTT 229', 'camera_id': 3, 'timestamp': '2024-01-01T08:00:54.958092', 'speed_reading': 130.8, 'producer': 'C', 'sent_at': '2025-05-13T11:32:45.163342'}
# {'event_id': 'b8bea07f-235c-4ce0-9b27-fb2f524fb331', 'batch_id': 21, 'car_plate': 'VKZ 5377', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:57.545422', 'speed_reading': 75.9, 'producer': 'B', 'sent_at': '2025-05-13T11:32:46.381499'}
# {'event_id': 'f804c4e8-022d-4243-b43e-9ec0860ce6ff', 'batch_id': 2, 'car_plate': 'CJW 924', 'camera_id': 3, 'timestamp': '2024-01-01T08:00:47.168827', 'speed_reading': 164.5, 'producer': 'C', 'sent_at': '2025-05-13T11:32:50.185462'}
# {'event_id': '3d5110f0-2eb0-4ff6-8319-53677a95fb5c', 'batch_id': 22, 'car_plate': 'DWT 789', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:34.407062', 'speed_reading': 135.4, 'producer': 'B', 'sent_at': '2025-05-13T11:32:51.395122'}
# {'event_id': 'a5cea7f7-ffa2-497d-9ae2-305343afa884', 'batch_id': 22, 'car_plate': 'VM 4837', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:34.840158', 'speed_reading': 101.6, 'producer': 'B', 'sent_at': '2025-05-13T11:32:51.396560'}
# {'event_id': '6eff696a-810d-40ab-99b0-860b8eb43e97', 'batch_id': 22, 'car_plate': 'DSD 320', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:36.677773', 'speed_reading': 117.8, 'producer': 'B', 'sent_at': '2025-05-13T11:32:51.396970'}
# {'event_id': 'a246b391-fb7c-44a3-8f8b-ddf40bba3d05', 'batch_id': 3, 'car_plate': 'WA 0712', 'camera_id': 3, 'timestamp': '2024-01-01T08:00:53.815270', 'speed_reading': 134.4, 'producer': 'C', 'sent_at': '2025-05-13T11:32:55.202264'}
# {'event_id': 'e0dae388-6036-4b7d-ba58-bed0808c1611', 'batch_id': 3, 'car_plate': 'KZE 5', 'camera_id': 3, 'timestamp': '2024-01-01T08:00:57.613888', 'speed_reading': 125.3, 'producer': 'C', 'sent_at': '2025-05-13T11:32:55.203570'}
# {'event_id': '60aca271-dd79-410e-9ca5-2bac6057b293', 'batch_id': 23, 'car_plate': 'BS 03', 'camera_id': 2, 'timestamp': '2024-01-01T08:08:40.094285', 'speed_reading': 104.1, 'producer': 'B', 'sent_at': '2025-05-13T11:32:56.409962'}
# {'event_id': '55a60e1c-818e-4e55-bc02-0627765629b2', 'batch_id': 4, 'car_plate': 'ICE 8', 'camera_id': 3, 'timestamp': '2024-01-01T08:01:16.405088', 'speed_reading': 108.0, 'producer': 'C', 'sent_at': '2025-05-13T11:33:00.216906'}
# {'event_id': 'daafd000-91fa-4ff7-a9bf-896ee74b35ad', 'batch_id': 4, 'car_plate': 'WC 89', 'camera_id': 3, 'timestamp': '2024-01-01T08:01:18.835653', 'speed_reading': 94.5, 'producer': 'C', 'sent_at': '2025-05-13T11:33:00.218200'}
# {'event_id': 'f1a7e4bc-e95f-45a3-87f2-bb62bff7b3e1', 'batch_id': 24, 'car_plate': 'AJB 6689', 'camera_id': 2, 'timestamp': '2024-01-01T08:09:01.958624', 'speed_reading': 62.8, 'producer': 'B', 'sent_at': '2025-05-13T11:33:01.423994'}
# {'event_id': '8d6827a6-5ca3-49ac-8d67-f01b64a31c4f', 'batch_id': 5, 'car_plate': 'KRN 7', 'camera_id': 3, 'timestamp': '2024-01-01T08:01:42.077427', 'speed_reading': 76.2, 'producer': 'C', 'sent_at': '2025-05-13T11:33:05.232645'}
# {'event_id': 'c6a47514-5b97-4347-adfd-ba7a756615d5', 'batch_id': 25, 'car_plate': 'MZ 242', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:34.452533', 'speed_reading': 152.6, 'producer': 'B', 'sent_at': '2025-05-13T11:33:06.435173'}
# {'event_id': '9f2babdd-5d6d-4d44-a682-0bd264135fb2', 'batch_id': 25, 'car_plate': 'XCC 09', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:37.428884', 'speed_reading': 138.7, 'producer': 'B', 'sent_at': '2025-05-13T11:33:06.437031'}
# {'event_id': '052e725b-3098-4f7d-9670-ebcdf30f022c', 'batch_id': 6, 'car_plate': 'QE 1820', 'camera_id': 3, 'timestamp': '2024-01-01T08:01:50.367291', 'speed_reading': 65.6, 'producer': 'C', 'sent_at': '2025-05-13T11:33:10.246977'}
# {'event_id': '97de7ab2-ba78-4c85-9606-2529a89c37d2', 'batch_id': 26, 'car_plate': 'QBF 1', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:40.716844', 'speed_reading': 123.4, 'producer': 'B', 'sent_at': '2025-05-13T11:33:11.451840'}
# {'event_id': 'ab8a8200-a871-4c97-8728-e3a4affdec46', 'batch_id': 26, 'car_plate': 'VJX 7', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:42.566126', 'speed_reading': 116.8, 'producer': 'B', 'sent_at': '2025-05-13T11:33:11.453291'}
# {'event_id': 'de1adf7e-7e71-4bc2-bef4-5eed33d8843f', 'batch_id': 27, 'car_plate': 'VZ 8', 'camera_id': 2, 'timestamp': '2024-01-01T08:13:48.051570', 'speed_reading': 100.3, 'producer': 'B', 'sent_at': '2025-05-13T11:33:16.467298'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 41
#      39 if __name__ == '__main__':
#      40     consumer = connect_kafka_consumer()
# ---> 41     consume_messages(consumer)
#
# Cell In[26], line 33, in consume_messages(consumer)
#      31 print(consumer)
#      32 # print('Waiting for messages')
# ---> 33 for message in consumer:
#      34     message = message.value
#      35     print(message)
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:1197, in KafkaConsumer.__next__(self)
#    1195     return self.next_v1()
#    1196 else:
# -> 1197     return self.next_v2()
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:1205, in KafkaConsumer.next_v2(self)
#    1203     self._iterator = self._message_generator_v2()
#    1204 try:
# -> 1205     return next(self._iterator)
#    1206 except StopIteration:
#    1207     self._iterator = None
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:1120, in KafkaConsumer._message_generator_v2(self)
#    1118 def _message_generator_v2(self):
#    1119     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1120     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1121     for tp, records in six.iteritems(record_map):
#    1122         # Generators are stateful, and it is possible that the tp / records
#    1123         # here may become stale during iteration -- i.e., we seek to a
#    1124         # different offset, pause consumption, or lose assignment.
#    1125         for record in records:
#    1126             # is_fetchable(tp) should handle assignment changes and offset
#    1127             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1128             # outer function destroying the existing iterator/generator
#    1129             # via self._iterator = None
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:657, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     655 remaining = timeout_ms
#     656 while not self._closed:
# --> 657     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     658     if records:
#     659         return records
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/consumer/group.py:706, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     703     self._client.poll(timeout_ms=0)
#     705 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 706 self._client.poll(timeout_ms=timeout_ms)
#     707 # after the long poll, we should check whether the group needs to rebalance
#     708 # prior to returning data so that the group can stabilize faster
#     709 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.8/site-packages/kafka3/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.8/selectors.py:468, in EpollSelector.select(self, timeout)
#     466 ready = []
#     467 try:
# --> 468     fd_event_list = self._selector.poll(timeout, max_ev)
#     469 except InterruptedError:
#     470     return ready
#
# KeyboardInterrupt:
