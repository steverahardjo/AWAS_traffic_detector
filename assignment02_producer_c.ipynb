# %%
# Imported libraries
import time
import json
import pandas as pd
from kafka3 import KafkaProducer
from datetime import datetime as dt

# %%
# CONFIGURATION:
# Path to the CSV file
CSV_PATH      = 'data/camera_event_C.csv'
# Kafka bootstrap server
KAFKA_SERVER  = '172.22.32.1'
# Kafka topic
TOPIC         = 'camera_events_c'
# Interval between batches, in seconds
BATCH_INTERVAL = 5
# Identifier to tag each message with the producer name
PRODUCER_ID    = 'C'

# %%
def connect_kafka_producer(bootstrap_server: str) -> KafkaProducer:
    """
    Create and return a KafkaProducer instance.
    We set api_version to match your broker (here 0.10.x+).
    Also set a value_serializer so we can send dicts directly.
    """
    try:
        producer = KafkaProducer(
            bootstrap_servers=[bootstrap_server],
            api_version=(0, 10),
            value_serializer=lambda v: json.dumps(v).encode('utf-8'),
            key_serializer=lambda k: k.encode('utf-8')
        )
        return producer
    except Exception as e:
        print(f"[ERROR] Failed to connect to Kafka at {bootstrap_server}: {e}")
        raise

# %%
def load_events(csv_path: str) -> pd.DataFrame:
    """
    Load the camera events CSV into a DataFrame.
    We parse the timestamp column so we can convert it back to ISO.
    """
    df = pd.read_csv(
        csv_path,
        sep=',',
        parse_dates=['timestamp'],
        dtype={'batch_id': int}
    )
    return df

# %%
def produce_batches(df: pd.DataFrame,
                    producer: KafkaProducer,
                    topic: str,
                    interval: float,
                    producer_id: str):
    """
    Iterate through each batch_id in order, wrap each record
    as a dict + producer tag, and send to Kafka. Then sleep.
    """
    for batch_id in sorted(df['batch_id'].unique()):
        batch_df = df[df['batch_id'] == batch_id]
        print(f"[INFO] Publishing batch #{batch_id} ({len(batch_df)} records)...")
        for _, row in batch_df.iterrows():
            event = row.to_dict()
            # Ensure timestamp is serializable
            event['timestamp'] = event['timestamp'].isoformat()
            # Tag with producer identity
            event['producer_id'] = producer_id
            # Record when the batch is sent exactly
            event['sent_at'] = dt.now().isoformat()

            try:
                producer.send(
                    topic, 
                    key=event['car_plate'],
                    value=event,
                    timestamp_ms=int(time.time()*1000)
                )
            except Exception as e:
                print(f"[WARN] Failed to send event {event['event_id']}: {e}")

        # Force all buffered messages out
        producer.flush()
        print(f"[INFO] Batch #{batch_id} sent. Sleeping {interval}s...")
        # can comment the below line if you don't need to see the output
        print(f"[DATA] Batch #{batch_id}:\n{batch_df}\n")
        time.sleep(interval)
        
    # Loop has finished
    producer.flush()
    producer.close()

# %%
def main():
    # 1) Connect to Kafka broker
    producer = connect_kafka_producer(KAFKA_SERVER)

    # 2) Load all events from CSV
    df = load_events(CSV_PATH)

    # 3) Produce them in time-spaced batches
    produce_batches(df, producer, TOPIC, BATCH_INTERVAL, PRODUCER_ID)

    print("[DONE] All batches published.")

if __name__ == '__main__':
    main()
# Out:
# [INFO] Publishing batch #1 (1 records)...
# [INFO] Batch #1 sent. Sleeping 5s...
# [DATA] Batch #1:
#                                event_id  batch_id car_plate  camera_id  \
# 0  d86e8cdb-c387-4ccb-b35a-346302238824         1   UTT 229          3
#
#                    timestamp  speed_reading
# 0 2024-01-01 08:00:54.958092          130.8
#
# [INFO] Publishing batch #2 (1 records)...
# [INFO] Batch #2 sent. Sleeping 5s...
# [DATA] Batch #2:
#                                event_id  batch_id car_plate  camera_id  \
# 1  f804c4e8-022d-4243-b43e-9ec0860ce6ff         2   CJW 924          3
#
#                    timestamp  speed_reading
# 1 2024-01-01 08:00:47.168827          164.5
#
# [INFO] Publishing batch #3 (2 records)...
# [INFO] Batch #3 sent. Sleeping 5s...
# [DATA] Batch #3:
#                                event_id  batch_id car_plate  camera_id  \
# 2  a246b391-fb7c-44a3-8f8b-ddf40bba3d05         3   WA 0712          3
# 3  e0dae388-6036-4b7d-ba58-bed0808c1611         3     KZE 5          3
#
#                    timestamp  speed_reading
# 2 2024-01-01 08:00:53.815270          134.4
# 3 2024-01-01 08:00:57.613888          125.3
#
# [INFO] Publishing batch #4 (2 records)...
# [INFO] Batch #4 sent. Sleeping 5s...
# [DATA] Batch #4:
#                                event_id  batch_id car_plate  camera_id  \
# 4  55a60e1c-818e-4e55-bc02-0627765629b2         4     ICE 8          3
# 5  daafd000-91fa-4ff7-a9bf-896ee74b35ad         4     WC 89          3
#
#                    timestamp  speed_reading
# 4 2024-01-01 08:01:16.405088          108.0
# 5 2024-01-01 08:01:18.835653           94.5
#
# [INFO] Publishing batch #5 (1 records)...
# [INFO] Batch #5 sent. Sleeping 5s...
# [DATA] Batch #5:
#                                event_id  batch_id car_plate  camera_id  \
# 6  8d6827a6-5ca3-49ac-8d67-f01b64a31c4f         5     KRN 7          3
#
#                    timestamp  speed_reading
# 6 2024-01-01 08:01:42.077427           76.2
#
# [INFO] Publishing batch #6 (1 records)...
# [INFO] Batch #6 sent. Sleeping 5s...
# [DATA] Batch #6:
#                                event_id  batch_id car_plate  camera_id  \
# 7  052e725b-3098-4f7d-9670-ebcdf30f022c         6   QE 1820          3
#
#                    timestamp  speed_reading
# 7 2024-01-01 08:01:50.367291           65.6
#
# [INFO] Publishing batch #7 (2 records)...
# [INFO] Batch #7 sent. Sleeping 5s...
# [DATA] Batch #7:
#                                event_id  batch_id car_plate  camera_id  \
# 8  cc084bd6-f680-43cf-9d6e-15bc481038b2         7  PKH 8115          3
# 9  676fa9f2-4a5b-4d1b-a63e-a59b1f2e5c26         7      PI 9          3
#
#                    timestamp  speed_reading
# 8 2024-01-01 08:08:52.583094          153.8
# 9 2024-01-01 08:08:53.620450          134.3
#
# [INFO] Publishing batch #8 (1 records)...
# [INFO] Batch #8 sent. Sleeping 5s...
# [DATA] Batch #8:
#                                 event_id  batch_id car_plate  camera_id  \
# 10  3f49174b-d0fe-4dd6-8cca-cab50d37a21f         8   EZ 6277          3
#
#                     timestamp  speed_reading
# 10 2024-01-01 08:09:18.931021           89.8
#
# [INFO] Publishing batch #9 (2 records)...
# [INFO] Batch #9 sent. Sleeping 5s...
# [DATA] Batch #9:
#                                 event_id  batch_id car_plate  camera_id  \
# 11  65cf39ff-73dc-4873-9a4d-aa0626848af9         9     KV 17          3
# 12  94fd563d-0df1-4b35-a89c-db72f3874b30         9     QJ 53          3
#
#                     timestamp  speed_reading
# 11 2024-01-01 08:09:25.802177           86.0
# 12 2024-01-01 08:09:29.843998           82.6
#
# [INFO] Publishing batch #10 (2 records)...
# [INFO] Batch #10 sent. Sleeping 5s...
# [DATA] Batch #10:
#                                 event_id  batch_id car_plate  camera_id  \
# 13  2f38e970-5042-4d91-8ef3-f8e4bed9908f        10    CZ 592          3
# 14  fa9e3b2a-de4e-48be-b97b-1c01e95e437a        10      AH 8          3
#
#                     timestamp  speed_reading
# 13 2024-01-01 08:00:47.453301          161.4
# 14 2024-01-01 08:00:49.247531          165.5
#
# [INFO] Publishing batch #11 (1 records)...
# [INFO] Batch #11 sent. Sleeping 5s...
# [DATA] Batch #11:
#                                 event_id  batch_id car_plate  camera_id  \
# 15  9a22f424-6c61-4e38-ad58-40c4bde9dfea        11    FZ 766          3
#
#                     timestamp  speed_reading
# 15 2024-01-01 08:01:00.555089          143.2
#
# [INFO] Publishing batch #12 (1 records)...
# [INFO] Batch #12 sent. Sleeping 5s...
# [DATA] Batch #12:
#                                 event_id  batch_id car_plate  camera_id  \
# 16  033183dc-45d4-4cab-98cf-a4f05088c76b        12    ZPG 90          3
#
#                     timestamp  speed_reading
# 16 2024-01-01 08:01:16.062056          101.4
#
# [INFO] Publishing batch #13 (1 records)...
# [INFO] Batch #13 sent. Sleeping 5s...
# [DATA] Batch #13:
#                                 event_id  batch_id car_plate  camera_id  \
# 17  49500aa0-39b9-4dc2-8e4d-69c8519b5983        13     JEJ 6          3
#
#                     timestamp  speed_reading
# 17 2024-01-01 08:09:06.369311          109.3
#
# [INFO] Publishing batch #14 (1 records)...
# [INFO] Batch #14 sent. Sleeping 5s...
# [DATA] Batch #14:
#                                 event_id  batch_id car_plate  camera_id  \
# 18  dfc12ef9-a6d4-48ab-8dab-47eae3e90e1c        14    IFY 23          3
#
#                     timestamp  speed_reading
# 18 2024-01-01 08:09:12.383098          115.7
#
# [INFO] Publishing batch #15 (1 records)...
# [INFO] Batch #15 sent. Sleeping 5s...
# [DATA] Batch #15:
#                                 event_id  batch_id car_plate  camera_id  \
# 19  645454f9-4d9e-4cc9-accc-7048fe7c010a        15     YRV 3          3
#
#                     timestamp  speed_reading
# 19 2024-01-01 08:09:53.655566           65.3
#
# [INFO] Publishing batch #16 (1 records)...
# [INFO] Batch #16 sent. Sleeping 5s...
# [DATA] Batch #16:
#                                 event_id  batch_id car_plate  camera_id  \
# 20  97f44470-dbf6-4c9c-94e9-5fb5b4a9bfb0        16   KWO 421          3
#
#                     timestamp  speed_reading
# 20 2024-01-01 08:14:17.095156          118.9
#
# [INFO] Publishing batch #17 (1 records)...
# [INFO] Batch #17 sent. Sleeping 5s...
# [DATA] Batch #17:
#                                 event_id  batch_id car_plate  camera_id  \
# 21  a012900c-1624-41f9-ae9d-c4ce3f07f061        17   ZV 2619          3
#
#                     timestamp  speed_reading
# 21 2024-01-01 08:14:27.485637           93.6
#
# [INFO] Publishing batch #18 (2 records)...
# [INFO] Batch #18 sent. Sleeping 5s...
# [DATA] Batch #18:
#                                 event_id  batch_id car_plate  camera_id  \
# 22  0a5c01b4-7019-4ab3-86fb-1b10bef30e8f        18    EOT 00          3
# 23  9cd09f0f-7c06-46db-b91e-683b7b9e7547        18      HP 1          3
#
#                     timestamp  speed_reading
# 22 2024-01-01 08:00:54.302613          137.8
# 23 2024-01-01 08:00:54.634856          144.3
#
# [INFO] Publishing batch #19 (1 records)...
# [INFO] Batch #19 sent. Sleeping 5s...
# [DATA] Batch #19:
#                                 event_id  batch_id car_plate  camera_id  \
# 24  9f0d72a2-a98b-4053-b65c-d88baf2571ff        19   CJP 278          3
#
#                     timestamp  speed_reading
# 24 2024-01-01 08:01:02.795526          118.6
#
# [INFO] Publishing batch #20 (1 records)...
# [INFO] Batch #20 sent. Sleeping 5s...
# [DATA] Batch #20:
#                                 event_id  batch_id car_plate  camera_id  \
# 25  283f4049-e9e6-46aa-8f25-94107f08f888        20   CX 6145          3
#
#                     timestamp  speed_reading
# 25 2024-01-01 08:01:11.368657          105.0
#
# [INFO] Publishing batch #21 (1 records)...
# [INFO] Batch #21 sent. Sleeping 5s...
# [DATA] Batch #21:
#                                 event_id  batch_id car_plate  camera_id  \
# 26  332a8fb7-77d6-44c2-a52b-b37b2f3777d2        21     WJX 2          3
#
#                     timestamp  speed_reading
# 26 2024-01-01 08:01:17.876767           99.2
#
# [INFO] Publishing batch #22 (1 records)...
# [INFO] Batch #22 sent. Sleeping 5s...
# [DATA] Batch #22:
#                                 event_id  batch_id car_plate  camera_id  \
# 27  250a7caf-f858-4a3b-8553-ce3ff0dd2c2b        22     FA 35          3
#
#                     timestamp  speed_reading
# 27 2024-01-01 08:01:29.666333           86.3
# [INFO] Publishing batch #23 (2 records)...
# [INFO] Batch #23 sent. Sleeping 5s...
# [DATA] Batch #23:
#                                 event_id  batch_id car_plate  camera_id  \
# 28  4154c60d-205c-4b9a-b6f5-3fce0de4602f        23    WB 418          3
# 29  81b00cc5-6329-4799-a1ef-90084142d5c7        23   UQV 232          3
#
#                     timestamp  speed_reading
# 28 2024-01-01 08:08:49.468866          135.5
# 29 2024-01-01 08:08:49.576904          169.8
#
# [INFO] Publishing batch #24 (2 records)...
# [INFO] Batch #24 sent. Sleeping 5s...
# [DATA] Batch #24:
#                                 event_id  batch_id car_plate  camera_id  \
# 30  6929adcc-9074-432d-b802-2bff7bc183eb        24   DWT 789          3
# 31  a47f07b1-cf3e-45a5-8ce9-fe6457c4d960        24    VWM 13          3
#
#                     timestamp  speed_reading
# 30 2024-01-01 08:09:00.148574          130.4
# 31 2024-01-01 08:09:01.054869          110.9
#
# [INFO] Publishing batch #25 (2 records)...
# [INFO] Batch #25 sent. Sleeping 5s...
# [DATA] Batch #25:
#                                 event_id  batch_id car_plate  camera_id  \
# 32  91189d3c-380e-4797-8fde-46c4431d7265        25    XYG 05          3
# 33  949e891a-4559-4589-9087-9314df3dc1a0        25   DSD 320          3
#
#                     timestamp  speed_reading
# 32 2024-01-01 08:09:07.354396          103.0
# 33 2024-01-01 08:09:08.960588          121.3
#
# [INFO] Publishing batch #26 (1 records)...
# [INFO] Batch #26 sent. Sleeping 5s...
# [DATA] Batch #26:
#                                 event_id  batch_id car_plate  camera_id  \
# 34  1ecf1920-14b1-4607-bc4f-a09f1c1c7a2f        26     BS 03          3
#
#                     timestamp  speed_reading
# 34 2024-01-01 08:09:13.293701           98.3
#
# [INFO] Publishing batch #27 (1 records)...
# [INFO] Batch #27 sent. Sleeping 5s...
# [DATA] Batch #27:
#                                 event_id  batch_id car_plate  camera_id  \
# 35  7973c256-0f8e-49cc-bf1d-76b4711e1ef7        27  WPV 1456          3
#
#                     timestamp  speed_reading
# 35 2024-01-01 08:09:32.626411           73.6
#
# [INFO] Publishing batch #28 (2 records)...
# [INFO] Batch #28 sent. Sleeping 5s...
# [DATA] Batch #28:
#                                 event_id  batch_id car_plate  camera_id  \
# 36  2d30d12f-21a9-4f9e-ba8a-96e535da6a0c        28   CIY 810          3
# 37  96d81dd6-ed32-403d-a3e4-4c3f4a2194a6        28     EC 40          3
#
#                     timestamp  speed_reading
# 36 2024-01-01 08:13:59.546855          135.4
# 37 2024-01-01 08:14:03.495092          154.7
#
# [INFO] Publishing batch #29 (2 records)...
# [INFO] Batch #29 sent. Sleeping 5s...
# [DATA] Batch #29:
#                                 event_id  batch_id car_plate  camera_id  \
# 38  1e68bb1d-f6e3-40a8-b24b-6c733061409d        29     QBF 1          3
# 39  12b0a280-758f-42e5-b616-550f7bae7fd2        29    NGP 66          3
#
#                     timestamp  speed_reading
# 38 2024-01-01 08:14:08.709918          128.9
# 39 2024-01-01 08:14:11.741826          109.8
#
# [INFO] Publishing batch #30 (1 records)...
# [INFO] Batch #30 sent. Sleeping 5s...
# [DATA] Batch #30:
#                                 event_id  batch_id car_plate  camera_id  \
# 40  f03b097a-462e-4963-996e-8e38994e61ce        30  VKZ 5377          3
#
#                     timestamp  speed_reading
# 40 2024-01-01 08:14:43.211632           75.4
#
# [INFO] Publishing batch #31 (2 records)...
# [INFO] Batch #31 sent. Sleeping 5s...
# [DATA] Batch #31:
#                                 event_id  batch_id car_plate  camera_id  \
# 41  b939fa8b-5abe-478f-b225-d3a541465d0b        31  YXA 7534          3
# 42  53002012-0061-401e-83a3-553a78035867        31    XY 025          3
#
#                     timestamp  speed_reading
# 41 2024-01-01 08:20:33.121746          164.9
# 42 2024-01-01 08:20:35.773241          138.1
#
# [INFO] Publishing batch #32 (1 records)...
# [INFO] Batch #32 sent. Sleeping 5s...
# [DATA] Batch #32:
#                                 event_id  batch_id car_plate  camera_id  \
# 43  43c9bb24-b749-46f4-9f5e-b6d5191e038a        32    QK 270          3
#
#                     timestamp  speed_reading
# 43 2024-01-01 08:20:54.851073          101.2
#
# [INFO] Publishing batch #33 (1 records)...
# [INFO] Batch #33 sent. Sleeping 5s...
# [DATA] Batch #33:
#                                 event_id  batch_id car_plate  camera_id  \
# 44  ce1a7295-709c-4788-99f2-0f89cc4ba580        33     KC 82          3
#
#                     timestamp  speed_reading
# 44 2024-01-01 08:21:05.725636           90.1
#
# [INFO] Publishing batch #34 (1 records)...
# [INFO] Batch #34 sent. Sleeping 5s...
# [DATA] Batch #34:
#                                 event_id  batch_id car_plate  camera_id  \
# 45  3390b101-e2e8-41d1-b262-e406911086e1        34    KKE 15          3
#
#                     timestamp  speed_reading
# 45 2024-01-01 08:00:50.542651          141.3
#
# [INFO] Publishing batch #35 (1 records)...
# [INFO] Batch #35 sent. Sleeping 5s...
# [DATA] Batch #35:
#                                 event_id  batch_id car_plate  camera_id  \
# 46  f0be3539-15eb-45e4-85cc-320d4db50d8d        35     FO 32          3
#
#                     timestamp  speed_reading
# 46 2024-01-01 08:01:15.640881           95.8
#
# [INFO] Publishing batch #36 (1 records)...
# [INFO] Batch #36 sent. Sleeping 5s...
# [DATA] Batch #36:
#                                 event_id  batch_id car_plate  camera_id  \
# 47  64f98c41-88b7-49d1-b956-b7772c30b8fa        36     WZ 24          3
#
#                     timestamp  speed_reading
# 47 2024-01-01 08:08:48.526751          150.7
#
# [INFO] Publishing batch #37 (1 records)...
# [INFO] Batch #37 sent. Sleeping 5s...
# [DATA] Batch #37:
#                                 event_id  batch_id car_plate  camera_id  \
# 48  01a4864b-46ad-4eb2-a911-43727c6c9c36        37   VM 4837          3
#
#                     timestamp  speed_reading
# 48 2024-01-01 08:09:11.510265           97.0
#
# [INFO] Publishing batch #38 (2 records)...
# [INFO] Batch #38 sent. Sleeping 5s...
# [DATA] Batch #38:
#                                 event_id  batch_id car_plate  camera_id  \
# 49  fe6c7545-0844-492d-a0ae-6e1ba9ba45fe        38     QZ 81          3
# 50  a4ef0b9a-0a3a-4ed5-86c7-83c83f7848b3        38  AJB 6689          3
#
#                     timestamp  speed_reading
# 49 2024-01-01 08:09:58.988288           63.3
# 50 2024-01-01 08:09:59.513428           62.5
#
# [INFO] Publishing batch #39 (2 records)...
# [INFO] Batch #39 sent. Sleeping 5s...
# [DATA] Batch #39:
#                                 event_id  batch_id car_plate  camera_id  \
# 51  0d3b2edd-a679-4aba-8812-ff8645204071        39     RK 76          3
# 52  b67f032a-4a8f-4886-aa70-8f0a85bad105        39    XCC 09          3
#
#                     timestamp  speed_reading
# 51 2024-01-01 08:14:00.882270          132.7
# 52 2024-01-01 08:14:03.976783          144.8
#
# [INFO] Publishing batch #40 (2 records)...
# [INFO] Batch #40 sent. Sleeping 5s...
# [DATA] Batch #40:
#                                 event_id  batch_id car_plate  camera_id  \
# 53  ca4fcb17-29db-4e74-a1c7-0b4293c925eb        40      GL 4          3
# 54  b53daf92-a04b-470b-b7f6-a664986fec12        40     ZQ 22          3
#
#                     timestamp  speed_reading
# 53 2024-01-01 08:14:08.564138          114.5
# 54 2024-01-01 08:14:09.023200          111.4
#
# [INFO] Publishing batch #41 (1 records)...
# [INFO] Batch #41 sent. Sleeping 5s...
# [DATA] Batch #41:
#                                 event_id  batch_id car_plate  camera_id  \
# 55  1a77d4c1-63fa-4ca9-b599-af0f9f6e106e        41      VZ 8          3
#
#                     timestamp  speed_reading
# 55 2024-01-01 08:14:23.762903           95.7
#
# [INFO] Publishing batch #42 (1 records)...
# [INFO] Batch #42 sent. Sleeping 5s...
# [DATA] Batch #42:
#                                 event_id  batch_id car_plate  camera_id  \
# 56  f81d9f5b-5ba9-407c-9809-612de212c06a        42  ZEA 3530          3
#
#                     timestamp  speed_reading
# 56 2024-01-01 08:20:35.365308          143.5
#
# [INFO] Publishing batch #43 (1 records)...
# [INFO] Batch #43 sent. Sleeping 5s...
# [DATA] Batch #43:
#                                 event_id  batch_id car_plate  camera_id  \
# 57  91a3bab8-fa70-4613-852c-634bce2984b6        43     DOR 6          3
#
#                     timestamp  speed_reading
# 57 2024-01-01 08:20:48.867512          110.1
# [INFO] Publishing batch #44 (1 records)...
# [INFO] Batch #44 sent. Sleeping 5s...
# [DATA] Batch #44:
#                                 event_id  batch_id car_plate  camera_id  \
# 58  78858d73-7233-4d39-8c20-2891278930a9        44      BU 9          3
#
#                     timestamp  speed_reading
# 58 2024-01-01 08:21:01.968054           92.8
#
# [INFO] Publishing batch #45 (2 records)...
# [INFO] Batch #45 sent. Sleeping 5s...
# [DATA] Batch #45:
#                                 event_id  batch_id car_plate  camera_id  \
# 59  b4cba9e5-4be3-4a81-a70f-f78372052199        45    VLY 61          3
# 60  f7791bb7-92e6-4842-9c83-0512cda7f529        45  HLZ 1649          3
#
#                     timestamp  speed_reading
# 59 2024-01-01 08:21:08.699219           80.9
# 60 2024-01-01 08:21:10.109678           89.3
#
# [INFO] Publishing batch #46 (1 records)...
# [INFO] Batch #46 sent. Sleeping 5s...
# [DATA] Batch #46:
#                                 event_id  batch_id car_plate  camera_id  \
# 61  b1a191f8-65e5-4284-8eaf-e1358240c9c8        46     WX 49          3
#
#                     timestamp  speed_reading
# 61 2024-01-01 08:21:14.975844           74.4
#
# [INFO] Publishing batch #47 (1 records)...
# [INFO] Batch #47 sent. Sleeping 5s...
# [DATA] Batch #47:
#                                 event_id  batch_id car_plate  camera_id  \
# 62  320bc122-d866-487e-9267-2f804ff939fa        47    BQN 88          3
#
#                     timestamp  speed_reading
# 62 2024-01-01 08:21:43.579488           61.7
#
# [INFO] Publishing batch #48 (1 records)...
# [INFO] Batch #48 sent. Sleeping 5s...
# [DATA] Batch #48:
#                                 event_id  batch_id car_plate  camera_id  \
# 63  0f30aa31-610b-4df0-9215-4789735d0bfa        48    DGT 19          3
#
#                     timestamp  speed_reading
# 63 2024-01-01 08:26:19.150336          130.6
#
# [INFO] Publishing batch #49 (1 records)...
# [INFO] Batch #49 sent. Sleeping 5s...
# [DATA] Batch #49:
#                                 event_id  batch_id car_plate  camera_id  \
# 64  9a5d0e8b-24af-44a9-bc31-d01c354fada8        49    MZ 242          3
#
#                     timestamp  speed_reading
# 64 2024-01-01 08:13:56.886282          160.8
#
# [INFO] Publishing batch #50 (2 records)...
# [INFO] Batch #50 sent. Sleeping 5s...
# [DATA] Batch #50:
#                                 event_id  batch_id car_plate  camera_id  \
# 65  a3d27ed2-acff-4e77-b209-d939d423d0d2        50     VJX 7          3
# 66  bcbc2400-fea4-4f4e-aa9f-285ebee4ca2b        50   WVV 824          3
#
#                     timestamp  speed_reading
# 65 2024-01-01 08:14:14.721078          119.7
# 66 2024-01-01 08:14:16.669783          110.2
